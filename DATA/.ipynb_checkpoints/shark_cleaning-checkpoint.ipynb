# %% [markdown]
# # 1. Cleaning

# %% [markdown]
# ### importing data

# %%
import pandas as pd
import numpy as np
import openpyxl
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_file = "D:\\ironhack\\proyectos\\SharkAttack_proy1\DATA\\attacks_1.csv"
shark_attack = pd.read_csv(csv_file, encoding="cp1252")

# %%
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
shark_attack.sample(3)
# Out:
#       Case Number         Date    Year        Type Country     Area  \
# 1521   2005.11.27  27-Nov-2005  2005.0  Unprovoked     USA  Florida
# 22900         NaN          NaN     NaN         NaN     NaN      NaN
# 6385            0          NaN     NaN         NaN     NaN      NaN
#
#                                             Location Activity         Name  \
# 1521   Ponce Inlet, New Smyrna Beach, Volusia County  Surfing  Blake Perry
# 22900                                            NaN      NaN          NaN
# 6385                                             NaN      NaN          NaN
#
#       Sex   ...  Species  Investigator or Source                   pdf  \
# 1521     M  ...  4' shark     S. Petersohn, GSAF  2005.11.27-Perry.pdf
# 22900  NaN  ...       NaN                    NaN                   NaN
# 6385   NaN  ...       NaN                    NaN                   NaN
#
#                                             href formula  \
# 1521   http://sharkattackfile.net/spreadsheets/pdf_di...
# 22900                                                NaN
# 6385                                                 NaN
#
#                                                     href Case Number.1  \
# 1521   http://sharkattackfile.net/spreadsheets/pdf_di...    2005.11.27
# 22900                                                NaN           NaN
# 6385                                                 NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 1521     2005.11.27         4782.0         NaN         NaN
# 22900           NaN            NaN         NaN         NaN
# 6385            NaN            NaN         NaN         NaN
#
# [3 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 25723

# %%
shark_attack.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %% [markdown]
# ### Null values

# %%
shark_attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
#revisar si necesito eliminar los NaN
#puedo meterme directo a explorar la columna a ver como se ven con los NaN
#llamando el key y poniendole .isna()

# %%
#pd.isnull(shark_attack).sum() same formula
shark_attack.isna().sum()
#for NaN, un promedio de 18000NaNs en una lista de 19803
#conclucion, demasiados NaN tendre que eliminar
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
shark_attack.notnull().sum()
# Out:
# Case Number               8702
# Date                      6302
# Year                      6300
# Type                      6298
# Country                   6252
# Area                      5847
# Location                  5762
# Activity                  5758
# Name                      6092
# Sex                       5737
# Age                       3471
# Injury                    6274
# Fatal (Y/N)               5763
# Time                      2948
# Species                   3464
# Investigator or Source    6285
# pdf                       6302
# href formula              6301
# href                      6302
# Case Number.1             6302
# Case Number.2             6302
# original order            6309
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %% [markdown]
# After this filter we can see that it has tons of null data, from 25723 original rows we can see that it will let us with almos 6,000 rows. Not much information and we can clean it.

# %% [markdown]
# next step it will be to drop (errase) the rows that dont apport nothing to the data.
# If we throw the formula od dropna with the fuction "any" its not an option, every single row has even one missed cell, we will be applying the function "all"

# %%
shark_attack.dropna(how="all",inplace=True)
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 8698               NaN                             NaN          NaN
# 8699               NaN                             NaN          NaN
# 8700               NaN                             NaN          NaN
# 8701               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 8698               NaN  NaN  ...              NaN
# 8699               NaN  NaN  ...              NaN
# 8700               NaN  NaN  ...              NaN
# 8701               NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 8698                              NaN                       NaN
# 8699                              NaN                       NaN
# 8700                              NaN                       NaN
# 8701                              NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 8698                                                 NaN
# 8699                                                 NaN
# 8700                                                 NaN
# 8701                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 8698                                                 NaN           NaN
# 8699                                                 NaN           NaN
# 8700                                                 NaN           NaN
# 8701                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 8698            NaN            NaN         NaN         NaN
# 8699            NaN            NaN         NaN         NaN
# 8700            NaN            NaN         NaN         NaN
# 8701            NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [8703 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 8703

# %% [markdown]
# it let us with only 8703 rows. But we still have some missing values in the cells thats wy apears in the formula below that we still have a lot of them, probably half of the columns have NANs.

# %%
shark_attack.isna().sum()
# Out:
# Case Number                  1
# Date                      2401
# Year                      2403
# Type                      2405
# Country                   2451
# Area                      2856
# Location                  2941
# Activity                  2945
# Name                      2611
# Sex                       2966
# Age                       5232
# Injury                    2429
# Fatal (Y/N)               2940
# Time                      5755
# Species                   5239
# Investigator or Source    2418
# pdf                       2401
# href formula              2402
# href                      2401
# Case Number.1             2401
# Case Number.2             2401
# original order            2394
# Unnamed: 22               8702
# Unnamed: 23               8701
# dtype: int64

# %% [markdown]
# ### Duplicated

# %%
shark_attack.shape[0]
# Out:
# 8703

# %%
shark_attack.duplicated().sum()
# Out:
# 2392

# %% [markdown]
# This tell us that we have 2,392 raws that are duplicated and will have to be removed, otherwise it will leave us with some false information.

# %%
shark_attack.drop_duplicates(inplace=True)
shark_attack.tail(5)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6306            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6307            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6308            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 6306   ...      NaN                    NaN  NaN          NaN  NaN
# 6307   ...      NaN                    NaN  NaN          NaN  NaN
# 6308   ...      NaN                    NaN  NaN          NaN  NaN
# 6309   ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 6306            NaN           NaN         6308.0         NaN         NaN
# 6307            NaN           NaN         6309.0         NaN         NaN
# 6308            NaN           NaN         6310.0         NaN         NaN
# 6309            NaN           NaN            NaN         NaN         NaN
# 25722           NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 6311

# %% [markdown]
# This leave us with only 6,311 rows that are not duplicated and have minimum 1 real value.
# Because I can notice that there are still some rows that looks preatty empty and the few values that could have it might not be important to us and our investigation.

# %% [markdown]
# ### columns

# %% [markdown]
# passing throw the Data frame I notice that theres some columns that are not relevant to our investigation, that doesnt apport anything of value that we could could benefit

# %%
shark_attack.sample()
# Out:
#      Case Number         Date    Year        Type       Country  \
# 2682  1989.06.05  05-Jun-1989  1989.0  Unprovoked  SOUTH AFRICA
#
#                        Area      Location Activity           Name Sex   ...  \
# 2682  Eastern Cape Province  Jeffreys Bay  Surfing  Roniel Jacobs    M  ...
#
#                    Species                   Investigator or Source  \
# 2682  3 m [10'] white shark  R. Jacobs, R. Joseph; M. Levine, GSAF
#
#                         pdf  \
# 2682  1989.06.05-Jacobs.pdf
#
#                                            href formula  \
# 2682  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 2682  http://sharkattackfile.net/spreadsheets/pdf_di...    1989.06.05
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 2682    1989.06.05         3621.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
shark_attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# There are some columns that makes me have some interest, in wich ones we could errase because of our lak of information for us, for example the las 2 columns 'Unnamed: 22', 'Unnamed: 23', seen the samples we could see that theres only non values and actually the tittle doesn´t give us any explanetion.
# We will erase them.

# %%
shark_attack[['Unnamed: 22', "Unnamed: 23"]].sample(5)
# Out:
#      Unnamed: 22 Unnamed: 23
# 3395         NaN         NaN
# 5672         NaN         NaN
# 5176         NaN         NaN
# 1258         NaN         NaN
# 6233         NaN         NaN

# %%
shark_attack.drop(columns =['Unnamed: 22', "Unnamed: 23"], inplace=True, axis=1)

# %%
shark_attack.sample()
# Out:
#      Case Number         Date    Year        Type       Country  \
# 3031  1981.05.10  10-May-1981  1981.0  Unprovoked  SOUTH AFRICA
#
#                        Area      Location Activity         Name Sex   ...  \
# 3031  Eastern Cape Province  King’s Beach  Surfing  John Dunser    M  ...
#
#      Fatal (Y/N)   Time                           Species   \
# 3031           N  14h45  Raggedtooth shark, 2.5 m [8.25']
#
#      Investigator or Source                    pdf  \
# 3031    M. Smale, PE Museum  1981.05.10-Dunser.pdf
#
#                                            href formula  \
# 3031  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 3031  http://sharkattackfile.net/spreadsheets/pdf_di...    1981.05.10
#
#      Case Number.2 original order
# 3031    1981.05.10         3272.0
#
# [1 rows x 22 columns]

# %% [markdown]
# more research in columns: lets see if the internet links could help us with our research.

# %%
shark_attack['href formula'].sample(5)
# Out:
# 1963    http://sharkattackfile.net/spreadsheets/pdf_di...
# 6102    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4202    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4609    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2305    http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href formula, dtype: object

# %%
shark_attack['href'].sample(5)
# Out:
# 4942    http://sharkattackfile.net/spreadsheets/pdf_di...
# 5900    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2207    http://sharkattackfile.net/spreadsheets/pdf_di...
# 434     http://sharkattackfile.net/spreadsheets/pdf_di...
# 559     http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href, dtype: object

# %% [markdown]
# Exploring this 2 columns 'href formula' and 'href' we can realice that they apporr some internet links, but going throw them they the pages dont exist amymore.

# %%
shark_attack['Case Number.1'].sample(5)
# Out:
# 669     2013.06.06.b
# 2578      1991.11.00
# 4109      1959.02.02
# 2874      1984.10.21
# 4915      1935.03.20
# Name: Case Number.1, dtype: object

# %% [markdown]
# other columns that dont apport anything of value are 'Case Number.1', 'Case Number.2'  we can see that the information there is actually the same and its the date of the attack that we do have it already in other columns at the beginning, and 'original order' dont aport us anything.
# we´ll pass to some more drop cleaning.
# we also dont count with any extra file from the data page like the pdf files, so we could erase thata one to.

# %%
shark_attack.drop(columns =['Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order'], inplace=True, axis=1)

# %%
shark_attack.drop(columns =['Case Number'], inplace=True, axis=1)

# %%
shark_attack.sample()
# Out:
#              Date    Year        Type Country            Area  \
# 2109  16-Aug-1999  1999.0  Unprovoked     USA  South Carolina
#
#                                       Location                    Activity  \
# 2109  Grand Strand, Myrtle Beach, Horry County  Lying prone in 2' of water
#
#                              Name Sex  Age  \
# 2109  Christopher (Will)  Handley    M  10
#
#                                                  Injury Fatal (Y/N)   Time  \
# 2109  Ear lacerated, cuts on scalp, back, arm & shou...           N  17h40
#
#               Species
# 2109  1.8 m [6'] shark

# %%
shark_attack.columns = [i.capitalize().replace(" ", "_") for i in list(shark_attack.columns)]
shark_attack.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex_', 'Age', 'Injury', 'Fatal_(y/n)', 'Time', 'Species_'],
#       dtype='object')

# %%
shark_attack.dropna(how="all",inplace=True)
shark_attack.tail(5)
# Out:
#              Date  Year        Type             Country               Area  \
# 6297  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 6300    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 6301    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 6297                          Roebuck Bay        Diving
# 6298                                  NaN  Pearl diving
# 6299                       Ocracoke Inlet      Swimming
# 6300                 Panama Bay 8ºN, 79ºW           NaN
# 6301  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex_  Age  \
# 6297                   male    M  NaN
# 6298                  Ahmun    M  NaN
# 6299  Coast Guard personnel    M  NaN
# 6300        Jules Patterson    M  NaN
# 6301                   male    M   15
#
#                                                  Injury Fatal_(y/n) Time  \
# 6297                                              FATAL           Y  NaN
# 6298                                              FATAL           Y  NaN
# 6299                                              FATAL           Y  NaN
# 6300                                              FATAL           Y  NaN
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y  NaN
#
#      Species_
# 6297      NaN
# 6298      NaN
# 6299      NaN
# 6300      NaN
# 6301      NaN

# %%
#for i in list(shark_attack.columns):
#    for e in range(len(i)):
#        if e == "_":
#            list(shark_attack.columns).append(e.replace("_", ""))
#shark_attack.columns

# %%
#for i in list(shark_attack.columns):
#    for e in len(i)if i[-1] == " ":
#        list(shark_attack.columns).append(i.replace(" ", ""))
#shark_attack.columns

# %%
shark_attack.head()
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex_  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal_(y/n)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species_
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# 3            NaN        2 m shark
# 4            NaN  Tiger shark, 3m

# %% [markdown]
# For this analysis Im interested in some of the columns, I will need the 'Date', 'Country', 'Injury', 'Fatal_(y/n)', 'Time' and 'Species_', I will have to go throw them and cleaning them more deep so we would not have any bias.

# %% [markdown]
# ### Cleaning "Date"

# %% [markdown]
# For "Date" i will need to clean it and have it more organized, will nedd to make all data the same information, so i can calculate it the same way. will need to separate tin different columns the day, in another de month and in another the year, that we already have it.
# in this case I will need to create 2 more columns or just one and modified the others.

# %%
shark_attack['Date'].value_counts()
# Out:
# 1957                          11
# 1942                           9
# 1956                           8
# 1958                           7
# 1950                           7
#                               ..
# 01-Dec-1994                    1
# Reported      10-Dec-1994      1
# 11-Dec-1994                    1
# 13-Dec-1994                    1
# 1845-1853                      1
# Name: Date, Length: 5433, dtype: int64

# %%
shark_attack.dtypes
# Out:
# Date            object
# Year           float64
# Type            object
# Country         object
# Area            object
# Location        object
# Activity        object
# Name            object
# Sex_            object
# Age             object
# Injury          object
# Fatal_(y/n)     object
# Time            object
# Species_        object
# dtype: object

# %% [markdown]
# Se hizo el cambio de type de Date, aunque ya estaba como objeto, no me reconocia algunos cambios por que el error me aventaba que eran floats.

# %% [markdown]
# Crear nueva columna

# %%
shark_attack["Months"] = shark_attack["Date"]

# %% [markdown]
# Create alll elements of column Months to strings.

# %%
for i in shark_attack["Months"]:
    i = str(i)

# %%
shark_attack["Months"] = shark_attack["Months"].astype("str")

# %%
shark_attack["Months"].dtype
# Out:
# dtype('O')

# %% [markdown]
# Filter and clean objects to make more readable the strings

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace(r'\d', "").replace("-", "")
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_11712\3293145955.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   shark_attack['Months'] = shark_attack['Months'].str.replace(r'\d', "").replace("-", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("-", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("or", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("Reported", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("Repted", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("Late", "").replace("Early", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace(" ", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("Mid", "")

# %%
shark_attack['Months'].value_counts()
# Out:
# Jul                                            650
# Aug                                            597
# Sep                                            547
# Jan                                            513
# Jun                                            491
#                                               ...
# SometimebetweenApr&Nov                           1
# Between&Dec                                      1
# Mar"Bittenlastweekend                            1
# MarApr                                           1
# Nodate(daysafterprecedingincident)&pritoJul      1
# Name: Months, Length: 114, dtype: int64

# %% [markdown]
# Creating a loop to choose me the only strings that I want, after it is clean it works better.
# First have to make the column a list so I can work and iterate it.

# %%
Months_lst = list(shark_attack['Months'])

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
x = []
for i in Months_lst:
    if i in months:
        x.append(i)
    else:
        x.append("NaN")

# %% [markdown]
# Change the result that is in type list to a Panda Serie so I can add it to the data frame, that is what i whant.

# %%
mySeries = pd.Series(x)

# %%
shark_attack["Months"] = mySeries

# %%
list(shark_attack['Months'])
# Out:
# ['Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'NaN',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Jun',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'NaN',
#  'NaN',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'NaN',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'NaN',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  ...]

# %%
sns.countplot(x = shark_attack.Months);

# %%
shark_attack.sample(50)
# Out:
#                       Date    Year          Type        Country  \
# 5835           10-Mar-1879  1879.0       Invalid      AUSTRALIA
# 3851           11-Jan-1962  1962.0    Unprovoked    NEW ZEALAND
# 3560           23-Aug-1966  1966.0    Unprovoked    NEW BRITAIN
# 1992           06-Nov-2000  2000.0    Unprovoked      AUSTRALIA
# 6018              Aug-1852  1852.0    Unprovoked            USA
# 976            23-Oct-2010  2010.0    Unprovoked            USA
# 3927           22-Jan-1961  1961.0    Unprovoked   SOUTH AFRICA
# 1419           09-Nov-2006  2006.0      Provoked   SOUTH AFRICA
# 2498              May 1993  1993.0    Unprovoked        SOMALIA
# 4610           05-Jan-1946  1946.0    Unprovoked      AUSTRALIA
# 512   Reported 25-Aug-2014  2014.0      Provoked            USA
# 1215           27-Aug-2008  2008.0    Unprovoked            USA
# 5412           05-Dec-1909  1909.0      Provoked      AUSTRALIA
# 3046                  1981  1981.0    Unprovoked      AUSTRALIA
# 5643           15-Mar-1895  1895.0    Unprovoked      AUSTRALIA
# 2705           07-Nov-1988  1988.0  Sea Disaster      AUSTRALIA
# 1417           25-Nov-2006  2006.0  Sea Disaster    PHILIPPINES
# 1567           17-Jul-2005  2005.0       Invalid        LIBERIA
# 1057           05-Jan-2010  2010.0    Unprovoked   SOUTH AFRICA
# 540            18-Jun-2014  2014.0    Unprovoked      AUSTRALIA
# 5776           18-Aug-1884  1884.0       Invalid            USA
# 1700           23-Jan-2004  2004.0    Unprovoked        URUGUAY
# 4039           11-Dec-1959  1959.0      Provoked      AUSTRALIA
# 1260           07-May-2008  2008.0    Unprovoked  NEW CALEDONIA
# 2360           10-Aug-1995  1995.0    Unprovoked            USA
# 1752           08-Aug-2003  2003.0    Unprovoked   SOUTH AFRICA
# 5909           Before 1871  1871.0    Unprovoked      AUSTRALIA
# 4008           28-Mar-1960  1960.0    Unprovoked           GUAM
# 1480           21-May-2006  2006.0    Unprovoked         BRAZIL
# 4918           09-Mar-1935  1935.0    Unprovoked      AUSTRALIA
# 2457           09-Jan-1994  1994.0    Unprovoked      AUSTRALIA
# 5195           23-Nov-1923  1923.0    Unprovoked      AUSTRALIA
# 6296           Before 1906     0.0    Unprovoked      AUSTRALIA
# 5541           19-Jan-1902  1902.0    Unprovoked      AUSTRALIA
# 3859                  1962  1962.0    Unprovoked          SPAIN
# 4820  Reported 21-Mar-1938  1938.0    Unprovoked           FIJI
# 3395              Apr-1970  1970.0      Provoked            NaN
# 4327           04-Sep-1954  1954.0    Unprovoked      AUSTRALIA
# 5154           26-Jan-1926  1926.0    Unprovoked   SOUTH AFRICA
# 2187           29-May-1998  1998.0    Unprovoked   SOUTH AFRICA
# 5720              Jan-1889  1889.0    Unprovoked   SIERRA LEONE
# 106            31-Jul-2017  2017.0    Unprovoked            USA
# 1927           04-Aug-2001  2001.0    Unprovoked        BAHAMAS
# 1106           24-Jul-2009  2009.0    Unprovoked            USA
# 6005            Circa 1855  1855.0       Invalid      AUSTRALIA
# 2606           24-Feb-1991  1991.0    Unprovoked            USA
# 3192           13-Jan-1976  1976.0      Provoked   SOUTH AFRICA
# 2278           03-Oct-1996  1996.0    Unprovoked            USA
# 5946              Apr-1864  1864.0    Unprovoked      MAURITIUS
# 3667           21-Aug-1964  1964.0    Unprovoked            USA
#
#                        Area  \
# 5835        New South Wales
# 3851           South Island
# 3560   Duke of York Islands
# 1992      Western Australia
# 6018               Virginia
# 976                   Maine
# 3927          KwaZulu-Natal
# 1419  Eastern Cape Province
# 2498        Banaadir Region
# 4610        New South Wales
# 512                 Florida
# 1215                Florida
# 5412        New South Wales
# 3046        New South Wales
# 5643             Queensland
# 2705             Queensland
# 1417      Surigao del Norte
# 1567                    NaN
# 1057       Eastern Province
# 540         South Australia
# 5776               New York
# 1700                  Rocha
# 4039               Victoria
# 1260         North Province
# 2360         South Carolina
# 1752  Eastern Cape Province
# 5909             Queensland
# 4008                    NaN
# 1480             Pernambuco
# 4918        New South Wales
# 2457             Queensland
# 5195      Western Australia
# 6296        New South Wales
# 5541             Queensland
# 3859              Catalonia
# 4820              Viti Levu
# 3395                    NaN
# 4327          Torres Strait
# 5154  Eastern Cape Province
# 2187  Eastern Cape Province
# 5720           Western Area
# 106                 Florida
# 1927    Grand Bahama Island
# 1106                  Texas
# 6005        New South Wales
# 2606                 Oregon
# 3192  Western Cape Province
# 2278             California
# 5946                    NaN
# 3667                Florida
#
#                                                Location  \
# 5835                                       Near Sydney
# 3851          Fairdown Beach, 5 miles north of Westport
# 3560         Butliwan Village, 15 miles north of Rabaul
# 1992                             Cottesloe Beach, Perth
# 6018                                            Norfolk
# 976         Burnt Cove near Eastport, Washington County
# 3927                                        Amanzimtoti
# 1419                                Nahoon, East London
# 2498                            Arroyo Beach, Mogadishu
# 4610               Oatley Bay near Como, George’s River
# 512                                   Apalachicola Bay
# 1215                   New Smyrna Beach, Volusia County
# 5412                                              Bondi
# 3046                                          Byron Bay
# 5643                                      Burnett River
# 2705               Off North Keppel Island, off Yeppoon
# 1417                Off Bilisan Point, Hinatuarn Island
# 1567                                                NaN
# 1057                                Nahoon, East London
# 540                 Middleton Point, Fleurieu Peninsula
# 5776                                        Jamaica Bay
# 1700                           Ensenada de la Coronilla
# 4039                                  Altona, Melbourne
# 1260                                          Hienghène
# 2360  Ocean Lakes Campground, south of Myrtle Beach,...
# 1752                                      Jeffrey’s Bay
# 5909                                     Brisbane River
# 4008                                                NaN
# 1480                           Boa Viagem Beach, Recife
# 4918                                     Maroubra Beach
# 2457                 Katana Downs Reach, Brisbane River
# 5195                   Condon, 88 km NE of Port Hedland
# 6296
# 5541                                           Brisbane
# 3859                                        Aigua Blava
# 4820                                    Singatoka River
# 3395                                                NaN
# 4327                      Darnley Island, Torres Strait
# 5154                                            Hamburg
# 2187                                       Jeffreys Bay
# 5720                                           Freetown
# 106                           Jacksonvlle, Duval County
# 1927                                           Freeport
# 1106                                 South Padre Island
# 6005                                      Sydney Harbor
# 2606                         Neskowin, Tillamook County
# 3192                                          Hartenbos
# 2278            North Salmon Creek Beach, Sonoma County
# 5946                                                NaN
# 3667                            Panama City, Bay County
#
#                                                Activity  \
# 5835      The steamship Bonnie Dundee lost in collision
# 3851                                       Surf fishing
# 3560                                  Diving into water
# 1992                                           Swimming
# 6018                                           Swimming
# 976                                        Scuba diving
# 3927                                           Swimming
# 1419                                           Canoeing
# 2498                                           Swimming
# 4610                                           Swimming
# 512                                  Fishing for sharks
# 1215                                            Surfing
# 5412                                            Fishing
# 3046                                        Surf-skiing
# 5643                                           Swimming
# 2705  The Christie V sank on 11/6/1988, survivors we...
# 1417                                       Sea Disaster
# 1567                                           Swimming
# 1057                                            Surfing
# 540                                             Surfing
# 5776                                           Clamming
# 1700                                            Surfing
# 4039  Spearfishing, Smith  & Walker touched shark wi...
# 1260                                            Fishing
# 2360                          "Riding waves on a board"
# 1752                               Sitting on surfboard
# 5909                                                NaN
# 4008                Spearfishing, carrying fish on belt
# 1480                                            Surfing
# 4918                                           Swimming
# 2457        Swimming, after falling off towed kneeboard
# 5195                                       Dry shelling
# 6296                                           Swimming
# 5541                                           Swimming
# 3859                         Dangling feet in the water
# 4820                                             Wading
# 3395                                         Freediving
# 4327                     Spearfishing, hunting crayfish
# 5154                                           Swimming
# 2187                                      Body boarding
# 5720                        Cleaning the side of a ship
# 106                                        Skimboarding
# 1927                                           Swimming
# 1106                                             Wading
# 6005                                          Swimming
# 2606                                            Surfing
# 3192                                      Shark fishing
# 2278                                            Surfing
# 5946                                     Fell overboard
# 3667                                           Swimming
#
#                                                    Name Sex_      Age  \
# 5835                     Cabin boy of the Bonnie Dundee    M      NaN
# 3851                                   Mrs. Beryl Grant    F       54
# 3560                              Loding Etwat (female)    F        9
# 1992                                         Dirk Avery    M       52
# 6018              a deserter from the U.S. Pennsylvania    M      NaN
# 976                                     Scott MacNichol    M       30
# 3927                                     Michael Murphy    M       15
# 1419                                     Richard Tebutt    M      NaN
# 2498                                      French female    F      NaN
# 4610                                        Valma Tegel    F       14
# 512                                          John Wiley    M      NaN
# 1215                                    Alexander Zgura    M       26
# 5412                                               male    M      NaN
# 3046                                        Warren Rowe    M       27
# 5643                                      Nicol Pringle    M       13
# 2705                                      Cedric Coucom    M       62
# 1417                         Sinking of the m.v.Leonida  NaN      NaN
# 1567                                      Valentyn Onuk    M      NaN
# 1057                                               male    M      NaN
# 540                                      Max Longhurst     M      NaN
# 5776                                      Stephen Rylor    M      NaN
# 1700                         Marcos González Selayaran     M       21
# 4039                        Barry Smith & Harold Walker    M  17 & 35
# 1260                                               male    M       40
# 2360                                    Venus  Lindsey     F       14
# 1752                                       Joseph Krone    M       16
# 5909                                               male    M      NaN
# 4008                                      Enrique Matao    M       44
# 1480                        Rogério Antônio de Carvalho    M       33
# 4918                                   Ernest MacDonald    M       27
# 2457                                      Gary Cochrane    M       23
# 5195             Selim and Dea Opre,  Koepang Islanders    M      NaN
# 6296                                           Arab boy    M      NaN
# 5541                                      Charles Jones    M       16
# 3859                                             female    F      NaN
# 4820                                               male    M      NaN
# 3395                                      Lionel Jarvis    M      NaN
# 4327                                      Kapua Gutchen    M       35
# 5154                                        Mr. Bennett    M      NaN
# 2187                               Jan-Henrick Opperman    M       16
# 5720                                     English sailor    M      NaN
# 106                                      Colton McCarty    M       15
# 1927                                   Krishna Thompson    M       36
# 1106                                       Deidre Casas    F       14
# 6005                                         C.T. Clark    M      NaN
# 2606                                   Tony Franciscone    M       38
# 3192  6 m catamaran, occupants: Peter Robertson, Bea...  NaN      NaN
# 2278                                      Kennon Cahill    M       31
# 5946                           cook from the Charleston    M      NaN
# 3667                                       Ron Kopenski    M      NaN
#
#                                                  Injury Fatal_(y/n)  \
# 5835                    Partial  remains found in shark         NaN
# 3851                              Right foot lacerated            N
# 3560                                              FATAL           Y
# 1992                               Leg & feet lacerated           N
# 6018                                              FATAL           Y
# 976      No injury to diver, shark bit his video camera           N
# 3927                                 Left thigh bitten            N
# 1419  Left arm lacerated when he grabbed shark by it...           N
# 2498                                              FATAL           Y
# 4610       FATAL, left leg severed, right leg injured             Y
# 512   Lacerations to forearm from hooked shark PROVO...           N
# 1215                      Lacerations to lower left leg           N
# 5412  3 fingers bitten by hooked shark PROVOKED INCI...           N
# 3046                              No injury, ski bitten           N
# 5643                            Lower leg & foot bitten           N
# 2705                                              FATAL           Y
# 1417  15 perished but shark involvement prior to dea...           Y
# 1567  Presumed to have drowned until his body washed...         NaN
# 1057  No injury, reportedly knocked of his board by ...           N
# 540                     No injury, surfboard 'attacked'           N
# 5776  Unclear if he sustained any injury from the 7'...         NaN
# 1700            Puncture wounds to dorsum of right foot           N
# 4039  Smith hit by tail of shark, Walker sustained c...           N
# 1260                                  Lower legs bitten           N
# 2360                                   Left foot bitten           N
# 1752             No injury, wetsuit torn & board bitten           N
# 5909                                           Survived           N
# 4008                                       Thigh bitten           N
# 1480                Injuries to left thigh, calf & foot           N
# 4918  FATAL, left thigh, buttock, left forearm bitte...           Y
# 2457                                   Hamstring bitten           N
# 5195  FATAL, disappeared, partial remains of Selim w...           Y
# 6296                                              FATAL           Y
# 5541                                        Legs bitten           N
# 3859                                       Feet severed           N
# 4820                                            unknown           N
# 3395  Arm abraded & lacerated. Recorded as PROVOKED ...           N
# 4327  FATAL, after being bitten by shark, he was pic...           Y
# 5154                                    Thigh lacerated           N
# 2187                                         Leg bitten           N
# 5720                                              FATAL           Y
# 106                            Lacerations to lower leg           N
# 1927  Leg bitten, later surgically amputated above t...           N
# 1106             Lacerations to anterior left lower leg           N
# 6005  No injury & although reported as an attack, it...         NaN
# 2606                      Calf lacerated & board bitten           N
# 3192  No injury to occupants, After shark was harpoo...           N
# 2278                  No Injury, shark struck his board           N
# 5946                                              FATAL           Y
# 3667                      No injury,  bumped repeatedly           N
#
#                  Time                                           Species_  \
# 5835              NaN       Shark involvement prior to death unconfirmed
# 3851            18h00                                         36"  shark
# 3560           Midday                                 A pack of 6 sharks
# 1992            06h30                          White shark, 4.9 m [16']
# 6018              NaN                                                NaN
# 976         Afternoon                               Porbeagle shark, 8'
# 3927            14h20                                        White shark
# 1419        Afternoon                                  Bull shark, 1.5m
# 2498              NaN                                                NaN
# 4610              NaN                                                NaN
# 512               NaN                                  Bull shark, 4.5'
# 1215            11h00                                           6' shark
# 5412              NaN                                           7' shark
# 3046            07h00                                Tiger shark, 2.5 m
# 5643              NaN                                                NaN
# 2705        Nightfall                                                NaN
# 1417            14h20                                                NaN
# 1567              NaN  Shark involvement prior to death was not confi...
# 1057              NaN                                                NaN
# 540             17h01                                                NaN
# 5776              NaN                                       Questionable
# 1700              NaN            Possibily a  1.5 to 2 m sandtiger shark
# 4039              NaN                                  2.7 m [9']  shark
# 1260            14h00                                2 small bull sharks
# 2360              NaN                                     Blacktip shark
# 1752            08h00                          3.5 m [11.5'] white shark
# 5909              NaN                                                NaN
# 4008            12h00                                   1.2 m [4'] shark
# 1480            11h30                                                NaN
# 4918            12h30                            White shark, 4 m [13']
# 2457              NaN                                        1.5 m shark
# 5195              NaN                                                NaN
# 6296              NaN  Said to involve a grey nurse shark that leapt ...
# 5541            12h00                                                NaN
# 3859              NaN                                                NaN
# 4820              NaN                                                NaN
# 3395              NaN                                   Wobbegong shark
# 4327              NaN                                           9' shark
# 5154              NaN                                     "a blue shark"
# 2187  Early afternoon                                       Unidentified
# 5720              NaN                                                NaN
# 106             18h30                                                NaN
# 1927            10h20                                                NaN
# 1106        Afternoon                                                NaN
# 6005              NaN                                            Invalid
# 2606            09h30                            5.5 m [18'] white shark
# 3192              NaN                                    4 m [13'] shark
# 2278            07h19                            5 m [16.5'] white shark
# 5946              NaN                                                NaN
# 3667            11h30                                           3' shark
#
#      Months
# 5835    Mar
# 3851    Jan
# 3560    Aug
# 1992    Nov
# 6018    Aug
# 976     Oct
# 3927    Jan
# 1419    Nov
# 2498    May
# 4610    Jan
# 512     Aug
# 1215    Aug
# 5412    Dec
# 3046    NaN
# 5643    Mar
# 2705    Nov
# 1417    Nov
# 1567    Jul
# 1057    Jan
# 540     Jun
# 5776    Aug
# 1700    Jan
# 4039    Dec
# 1260    May
# 2360    Aug
# 1752    Aug
# 5909    NaN
# 4008    Mar
# 1480    May
# 4918    Mar
# 2457    Jan
# 5195    Nov
# 6296    NaN
# 5541    Jan
# 3859    NaN
# 4820    Mar
# 3395    Apr
# 4327    Sep
# 5154    Jan
# 2187    May
# 5720    Jan
# 106     Jul
# 1927    Aug
# 1106    Jul
# 6005    NaN
# 2606    Feb
# 3192    Jan
# 2278    Oct
# 5946    Apr
# 3667    Aug

# %%
#condition_1 = shark_attack["Date"] == "Jan"
#condition_2 = shark_attack["Date"] == "Feb"
#condition_3 = shark_attack["Date"] == "Mar"
#condition_4 = shark_attack["Date"] == "Apr"
#condition_5 = shark_attack["Date"] == "May"
#condition_6 = shark_attack["Date"] == "Jun"
#condition_7 = shark_attack["Date"] == "Jul"
#condition_8 = shark_attack["Date"] == "Aug"
#condition_9 = shark_attack["Date"] == "Sep"
#condition_10 = shark_attack["Date"] == "Oct"
#condition_11 = shark_attack["Date"] == "Nov"
#condition_12 = shark_attack["Date"] == "Dec"

# %%
#condis = shark_attack.loc[(shark_attack["Date"] == "Jan") & (shark_attack["Date"] == "Apr")]
#condis.head()
# Out:
# Empty DataFrame
# Columns: [Case_number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex_, Age, Injury, Fatal_(y/n), Time, Species_]
# Index: []

# %%
shark_attack.sample()
# Out:
#     Case_number Date    Year        Type Country    Area  \
# 477  2014.11.13  Nov  2014.0  Unprovoked     USA  Hawaii
#
#                               Location    Activity         Name Sex_ Age  \
# 477  Airplane Beach, Lahina, West Maui  Snorkeling  Andrew Haas    M  53
#
#                            Injury Fatal_(y/n)   Time     Species_
# 477  Laceration to left upper leg           N  13h30  1.5 m shark

# %%
shark_attack["Months"].value_counts()
# Out:
# Jul    650
# NaN    598
# Aug    597
# Sep    547
# Jan    513
# Jun    491
# Apr    450
# Oct    441
# Dec    435
# Mar    406
# Nov    403
# May    392
# Feb    379
# Name: Months, dtype: int64

# %% [markdown]
# ### Cleaning "Species_"

# %%
shark_attack['Species_'].value_counts().sample(5)
# Out:
# accordingbenjaintheinjurywasinflictedbyabarracudanotashark    1
# notauthenticated                                              1
# []whiteshark(othrecoveredfroboat)                             1
# spinnersharkfeet                                              1
# sharkprobablyasoothhound                                      1
# Name: Species_, dtype: int64

# %% [markdown]
# Create a new copy of the column Species_

# %%
shark_attack["Species"] = shark_attack["Species_"]

# %%
Create all the elements inside the column strings.

# %%
for i in shark_attack["Species"]:
    i = str(i)

# %%
shark_attack["Species"] = shark_attack["Species"].astype("str")

# %%
shark_attack["Species"].dtype
# Out:
# dtype('O')

# %%
list(shark_attack["Species"])
# Out:
# ['whiteshark',
#  nan,
#  nan,
#  'shark',
#  'tigershark',
#  nan,
#  'tigershark',
#  'leonshark',
#  'bullshark',
#  nan,
#  'greyreefshark',
#  nan,
#  nan,
#  'invalidincident',
#  'tawnynurseshark',
#  nan,
#  'sharkinvolveentnotconfired',
#  nan,
#  'tigershark',
#  nan,
#  'questionable',
#  'shark',
#  'whiteshark',
#  'tigershark',
#  'whiteshark',
#  'shark',
#  'bullshark',
#  nan,
#  nan,
#  nan,
#  'tigershark',
#  'sharkinvolveentnotconfired',
#  'shark',
#  'bullshark',
#  'whiteshark',
#  'tigershark',
#  'wobbegongshark',
#  'shark',
#  'shark',
#  'blacktipshark',
#  'whiteshark',
#  nan,
#  'bullshark',
#  'possiblyawobbegong',
#  'injurybelievedcausedbyaneelnotashark',
#  'galapagosshark?',
#  'shark',
#  'bullshark',
#  'bullshark',
#  'greyreefshark',
#  'whiteshark',
#  'sallshark',
#  'wobbegongshark?',
#  'tigershark',
#  nan,
#  'nurseshark',
#  'nurseshark',
#  'tigersharkfeale',
#  'tigersharkfeale',
#  'soedrownedbutherayhavebeenkilledbybluesharks',
#  'whiteshark',
#  nan,
#  nan,
#  'shark',
#  'tigershark',
#  'cookiecuttershark',
#  'wobbegongshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'shark',
#  'spinnersharkfeet',
#  'tigersharkfeet',
#  'shark',
#  'deathayhavebeenduedrowning',
#  'shark',
#  'whiteshark',
#  'questionable',
#  'shark',
#  nan,
#  'porbeagle',
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'shark',
#  nan,
#  'whiteshark',
#  nan,
#  nan,
#  nan,
#  'nurseshark',
#  nan,
#  nan,
#  'whiteshark',
#  nan,
#  'sharkinvolveentquestionable',
#  nan,
#  'whiteshark',
#  'shark',
#  'possiblyablacktipshark',
#  'oceanicwhitetipshark',
#  'shark',
#  'whiteshark',
#  nan,
#  'asallshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'sandtigershark',
#  'blueshark',
#  'asallshark',
#  'sharkinvolveentnotconfired',
#  'whiteshark',
#  'whiteshark',
#  'whiteshark',
#  nan,
#  'whiteshark',
#  'bullshark',
#  'tigersharkkg',
#  'whiteshark',
#  'sharkinvolveentpriordeathnotconfired',
#  'nosharkinvovleent',
#  nan,
#  nan,
#  'bullshark',
#  'bullshark',
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'seven-gillshark',
#  nan,
#  'sharkprobablyasoothhound',
#  'shark',
#  'tigershark',
#  'shark',
#  'tigershark',
#  nan,
#  nan,
#  'shark',
#  nan,
#  'sharkinvolveenthighlydoubtful',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nosharkinvovleent-itwsapublicitystunt',
#  nan,
#  'sharkinvolveentnotconfired',
#  nan,
#  'whiteshark',
#  'tigershark',
#  nan,
#  nan,
#  'sharkinvolveentpriordeathnotconfired',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'bullshark',
#  nan,
#  nan,
#  'whiteshark',
#  'shark',
#  'leonshark',
#  'bullshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'leonsharkpup',
#  'tigershark',
#  'whitesharkfeale',
#  'caribbeanreefshark',
#  nan,
#  nan,
#  'bullshark',
#  nan,
#  nan,
#  'bullshark',
#  'bullshark',
#  nan,
#  'sharkinvolveentnotconfired',
#  nan,
#  'asallshark',
#  'whiteshark',
#  nan,
#  nan,
#  'sharkinvolveentnotconfired',
#  'wobbegongshark',
#  'whiteshark',
#  'broadnosesevengillshark',
#  'tigershark',
#  nan,
#  nan,
#  nan,
#  'shark',
#  nan,
#  nan,
#  'whiteshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'shark',
#  nan,
#  'shark',
#  'tigershark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'invalid',
#  'bullshark',
#  nan,
#  'bullshark',
#  nan,
#  nan,
#  'tigershark',
#  'blacktipshark',
#  'blueshark',
#  nan,
#  'whiteshark',
#  'nurseshark',
#  nan,
#  nan,
#  nan,
#  'bullshark',
#  'reefshark',
#  'tigershark',
#  nan,
#  nan,
#  'whiteshark',
#  nan,
#  'leonshark',
#  'angelshark',
#  'whiteshark',
#  'dogfishshark',
#  'whiteshark',
#  nan,
#  'tawnynurseshark',
#  'shark',
#  nan,
#  'caribbeanreefshark',
#  'whiteshark',
#  'shark',
#  nan,
#  'shark',
#  'shark',
#  'shark',
#  'shark',
#  'saidinvolveansharkburelikelydaagecausedbydebris',
#  nan,
#  '+shark',
#  'akoshark',
#  'bronzewhalersharksx',
#  'shark',
#  'whiteshark',
#  nan,
#  'shark',
#  nan,
#  'bullshark',
#  nan,
#  'blacktipshark',
#  'nurseshark',
#  nan,
#  'akoshark[]',
#  'bullshark',
#  nan,
#  'whiteshark',
#  'wobbegongshark',
#  'greyreefshark',
#  'greyreefshark',
#  'bullshark',
#  'tigershark',
#  'sharkinvolveentnotconfired',
#  'shark',
#  nan,
#  nan,
#  nan,
#  'sharkinvolveentnotconfired',
#  nan,
#  'nurseshark-ft',
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  nan,
#  'bronzewhaler',
#  'sandtigershark',
#  nan,
#  nan,
#  nan,
#  'nosharkinvolveent',
#  'nosharkinvolveent',
#  nan,
#  nan,
#  'sandtigershark',
#  nan,
#  'reefshark',
#  nan,
#  'bullsharksx',
#  'akoshark',
#  'tigershark',
#  'wobbegongshark',
#  'blacktipshark',
#  'shark',
#  'whiteshark',
#  'silkyshark',
#  'shark',
#  'bronzewhalershark',
#  'tigershark',
#  nan,
#  'whiteshark',
#  'bullshark',
#  nan,
#  'galapagosshark',
#  nan,
#  nan,
#  'spinnershark',
#  'bullshark',
#  'sharkinvolveentnotconfired',
#  nan,
#  'shark',
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'shark',
#  'spinnershark',
#  nan,
#  'nosharkinvolveent',
#  'tigershark',
#  'haerheadsp',
#  nan,
#  'tigershark',
#  nan,
#  nan,
#  nan,
#  'shark',
#  'blacktipshark',
#  'blacktipshark',
#  nan,
#  'whiteshark',
#  'shark',
#  'tigershark',
#  'shark',
#  nan,
#  'haerheadshark',
#  nan,
#  nan,
#  'shark',
#  'whiteshark',
#  'haerheadshark',
#  'whiteshark',
#  'shark?',
#  'sallshark',
#  'tigershark',
#  'whiteshark',
#  'whiteshark',
#  'sharkinvolveentnotconfired',
#  nan,
#  'shark',
#  'shark',
#  'whiteshark',
#  'sharkinvolveentnotconfired',
#  'haerheadshark',
#  'whiteshark',
#  nan,
#  nan,
#  'blacktiporspinnershark',
#  'thoughtinvolveasharkbutsharkinvolveentnotconfired',
#  'whiteshark',
#  'akoshark-lb',
#  'bronzewhalershark',
#  'bullshark',
#  'whiteshark',
#  'whiteshark',
#  'sharkinvolveentnotcofired',
#  'nosharkinvolveent',
#  'shark',
#  nan,
#  'whiteshark',
#  'whiteshark',
#  'shark',
#  nan,
#  'shark',
#  'bullshark',
#  'whiteshark',
#  'sharkinvolveentnotconfired',
#  'whiteshark',
#  'shark',
#  'wobbegongshark',
#  nan,
#  'sandtigershark',
#  'whiteshark',
#  'sallshark',
#  nan,
#  nan,
#  'bullshark',
#  'bullshark',
#  'akoshark',
#  'shark',
#  'bullshark',
#  'sallnurseshark',
#  'bullshark',
#  nan,
#  nan,
#  'shark',
#  nan,
#  'shark',
#  'shark',
#  'bullshark',
#  nan,
#  'whiteshark',
#  'whiteshark',
#  nan,
#  '--footshark',
#  'whiteshark',
#  'whiteshark',
#  'bluesharkfeet',
#  'bullshark',
#  nan,
#  'bullshark',
#  'sharkinvolveentnotcofired',
#  'nosharkinvolveent',
#  'whiteshark',
#  'akoshark',
#  'tigersharkfeet',
#  'blacktipshark',
#  nan,
#  nan,
#  'blacktipreefshark',
#  'whiteshark',
#  'tigershark',
#  'shark',
#  'shark',
#  'shark',
#  'bullshark',
#  'shark',
#  nan,
#  nan,
#  'whiteshark',
#  'sharkinvolveentnotconfired',
#  'shark',
#  'shark',
#  'nosharkinvolveent',
#  'whitesharkoroceanicwhitetipshark',
#  'raggedothshark',
#  'asallshark',
#  'shark',
#  'whiteshark',
#  'sharkinvolveentpriordeathstillbedeterined',
#  'sharkinvolveentnotconfired&highlyunlikely',
#  'whiteshark',
#  'shark',
#  'goblinshark',
#  'tigershark',
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'whiteshark',
#  'shark',
#  'shark',
#  nan,
#  nan,
#  'tigershark',
#  nan,
#  'tigershark',
#  nan,
#  nan,
#  'shark',
#  'shark',
#  'bullshark',
#  nan,
#  nan,
#  'blacktipshark',
#  nan,
#  'blacktipshark',
#  'whiteshark',
#  'whiteshark',
#  'shark',
#  'whiteshark:&',
#  nan,
#  'blacktipshark',
#  'nosharkinvolveent',
#  'shark',
#  'bullshark',
#  'whiteshark',
#  'shark',
#  nan,
#  'spinnershark',
#  'spinnersharkorblacktipshark',
#  'sharkinvolveentnotconfired',
#  nan,
#  'sallshark',
#  'shark',
#  nan,
#  'bullshark',
#  'shark',
#  'reefshark',
#  'bullshark',
#  nan,
#  'bullshark',
#  nan,
#  'bullshark',
#  'tpshark',
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'sharkinvolveentnotconfired',
#  'possiblytigershark',
#  'etreshark',
#  nan,
#  'angelshark',
#  'shark',
#  'shark',
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  'whiteshark',
#  nan,
#  'shark',
#  'oceanicwhitetipshark',
#  'caribbeanreefshark',
#  nan,
#  nan,
#  'leonshark',
#  nan,
#  'sandbarshark',
#  'bronzewhalershark',
#  nan,
#  nan,
#  'bullshark',
#  nan,
#  'blacktipreefshark',
#  'bullshark',
#  'shark',
#  'tawneynurseshark',
#  nan,
#  'whiteshark',
#  nan,
#  'sharkinvolveentnotconfired',
#  'nosharkinvolveent',
#  'shark',
#  'cowshark',
#  'shark',
#  'reefshark?',
#  nan,
#  nan,
#  'whiteshark',
#  'raggedothshark',
#  nan,
#  nan,
#  'whiteshark',
#  'sharkinvolveentpriordeathnotconfired',
#  'shark',
#  'shark',
#  nan,
#  nan,
#  nan,
#  'nosharkinvolveent',
#  'wobbegongshark',
#  'invalid',
#  'blacktiporspinnershark?',
#  'blacktipreefshark',
#  nan,
#  nan,
#  nan,
#  '-gillshark?',
#  'shark',
#  '-gillshark',
#  nan,
#  'oceanicwhitetipshark',
#  'whiteshark',
#  'reportedinvolveabullshark',
#  'whiteshark',
#  nan,
#  'tigershark',
#  'shark',
#  'wobbegongshark',
#  nan,
#  'tigershark',
#  nan,
#  'thoughtinvolveawhiteshark',
#  'whiteshark',
#  'reportedinvolveawhiteshark',
#  nan,
#  nan,
#  nan,
#  'tigershark',
#  'blacktipreefshark',
#  'thoughtinvolveabullshark',
#  'reportedinvolveawhiteshark',
#  'wobbegongshark',
#  'whitetipreefshark',
#  'tigershark',
#  'nurseshark?',
#  'whiteshark',
#  'whiteshark',
#  'whiteshark',
#  'sallbullshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'bullshark',
#  'shark',
#  nan,
#  'shark',
#  'shark',
#  nan,
#  'nurseshark',
#  nan,
#  'shark',
#  'blacktipshark',
#  'salonshark',
#  'nosharkinvolveent',
#  'akoshark',
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'tigershark?',
#  nan,
#  'bullshark',
#  'blacktipshark',
#  'bullshark',
#  nan,
#  nan,
#  'shark',
#  nan,
#  'tigershark',
#  'nurseshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  'sharkinvolveentpriordeathnotconfired',
#  'whiteshark',
#  'possiblyabullshark',
#  'shark',
#  'tigershark',
#  nan,
#  nan,
#  nan,
#  'shark',
#  'leonshark',
#  'shark',
#  'galapagosshark',
#  nan,
#  nan,
#  nan,
#  'galapagosshark',
#  'invalid',
#  'bullshark',
#  'asallshark',
#  'wobbegong',
#  'tigershark',
#  'greynurseshark',
#  'shark',
#  'blueshark',
#  'bullshark',
#  nan,
#  'possiblyablacktipreefshark',
#  nan,
#  'sharkinvolveentnotconfired',
#  'shark',
#  'nosharkinvolveent',
#  nan,
#  'nurseshark',
#  nan,
#  'raggedothshark',
#  nan,
#  'tigershark',
#  'bronzewhalershark',
#  'sallsharks',
#  nan,
#  'whiteshark',
#  'reefshark?',
#  'reefshark?',
#  'blacktipshark',
#  'leonshark',
#  nan,
#  'whiteshark',
#  nan,
#  nan,
#  'tigershark',
#  'bronzewhalershark',
#  nan,
#  nan,
#  'shark',
#  'bullshark',
#  'tigershark',
#  'tigershark',
#  'shark',
#  'sandtigershark',
#  'seven-gillshark',
#  'tigershark',
#  'nosharkinvolveent',
#  'shark',
#  'shark',
#  'tigershark',
#  'tigershark',
#  'whiteshark',
#  'tigershark',
#  'whiteshark',
#  nan,
#  nan,
#  'shark',
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  'shark',
#  'shark',
#  'shark',
#  nan,
#  'possiblyabullshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'shark',
#  'tigershark',
#  'shark',
#  'porbeagleshark',
#  nan,
#  nan,
#  nan,
#  'shark',
#  'leonshark',
#  'bullshark',
#  'leonshark',
#  nan,
#  'whitesharkorbronzewhaler',
#  nan,
#  'thoughtinvolveawhiteshark',
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  'salonsharksuspectedbutunlikely',
#  'whiteshark',
#  nan,
#  nan,
#  nan,
#  'shark',
#  'shark',
#  'nosharkinvolveent',
#  'possiblyabullshark',
#  nan,
#  'asallreefshark',
#  nan,
#  nan,
#  'shark',
#  'nosharkinvolveent',
#  nan,
#  'nurseshark',
#  'sallblacktipshark?',
#  'sharkinvolveentnotconfired',
#  'sallblacktipshark?',
#  'blacktipshark',
#  'shark',
#  'blueshark',
#  'whiteshark',
#  nan,
#  nan,
#  'shark',
#  'bullshark',
#  'shark',
#  'tigershark',
#  nan,
#  'whiteshark',
#  nan,
#  'whiteshark',
#  'shark',
#  'whiteshark',
#  'whiteshark',
#  'tigershark',
#  'asallshark',
#  'whiteshark',
#  nan,
#  'whiteshark',
#  'possiblyabullshark',
#  'possiblyabullshark',
#  'shark',
#  'shark',
#  nan,
#  'tawnynursesharkc',
#  nan,
#  'shark',
#  nan,
#  nan,
#  'spinnershark',
#  'greynurseshark',
#  'whiteshark',
#  nan,
#  'shark',
#  'tigershark',
#  'tigershark',
#  'blueshark-kgblueshark',
#  'whiteshark',
#  'thoughtinvolveabullshark',
#  'whiteshark',
#  'shark',
#  'allegedlyatigershark',
#  nan,
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  'shark',
#  nan,
#  'whiteshark',
#  'sharkinvolveentnotconfired',
#  'wobbegongshark',
#  nan,
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  'wobbegongshark?',
#  'whiteshark',
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'shark',
#  'raggedothshark',
#  'whiteshark',
#  'whiteshark',
#  'portjacksonshark',
#  'shark',
#  'shark',
#  nan,
#  'shark',
#  nan,
#  nan,
#  'nosharkinvolveent',
#  nan,
#  'whiteshark',
#  'bullshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'shark',
#  nan,
#  'tigershark',
#  nan,
#  'whiteshark',
#  'sharkpossiblyablactiporspinnershark',
#  'shark',
#  'sharkinvolveentpriordeathnotconfired',
#  nan,
#  nan,
#  nan,
#  nan,
#  'whiteshark>',
#  nan,
#  'possiblyasandtigershark',
#  'sharkinvolveentnotconfired',
#  'shark',
#  'greyreefshark',
#  nan,
#  'bullshark',
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  'sharkinvolveentpriordeathnotconfired',
#  nan,
#  nan,
#  'whiteshark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'bullsharkfeale',
#  'bullshark',
#  'whitesharkk',
#  nan,
#  'shark',
#  nan,
#  nan,
#  'oceanicwhitetipshark',
#  'blacktipshark',
#  nan,
#  'sevengillshark',
#  'shark',
#  'blacktipreefshark',
#  nan,
#  'whiteshark',
#  'tigershark',
#  'tigershark',
#  'zabesishark',
#  nan,
#  'tigershark',
#  nan,
#  'sandbarshark',
#  'invalid',
#  nan,
#  'bullshark',
#  'reefshark',
#  'shark',
#  'possiblyabronzewhalershark',
#  'bullshark',
#  nan,
#  'blacktipsharkpup',
#  'bullshark',
#  'bullshark',
#  nan,
#  nan,
#  'shark',
#  nan,
#  nan,
#  'bullshark',
#  'shark',
#  nan,
#  'whitesharkx',
#  'shark',
#  nan,
#  nan,
#  nan,
#  'shark',
#  nan,
#  'caribbeanreefshark',
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  'whiteshark',
#  'shark',
#  nan,
#  nan,
#  'oceanicwhitetipshark',
#  nan,
#  'akoshark',
#  'akoshark',
#  'oceanicwhitetipsharkfeale',
#  'oceanicwhitetipsharkfeale',
#  nan,
#  'sharkinvolveentnotconfired',
#  nan,
#  nan,
#  nan,
#  'whiteshark',
#  'whiteshark',
#  nan,
#  nan,
#  nan,
#  'porbeagleshark',
#  nan,
#  'whiteshark',
#  nan,
#  'bullshark',
#  'leonshark',
#  'possiblyaleonshark',
#  nan,
#  'whiteshark',
#  nan,
#  'whiteshark',
#  'shark',
#  'shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'sharkinvolveentpriordeathwasnotconfired',
#  nan,
#  'whiteshark',
#  'whiteshark',
#  nan,
#  nan,
#  ...]

# %% [markdown]
# Start making a cleanning of the strings, making some filters to be easier after.

# %%
shark_attack['Species'] = shark_attack['Species'].str.lower()

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace(" ", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace(".", "")
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_11712\2112098186.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   shark_attack['Species_'] = shark_attack['Species_'].str.replace(".", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace("to", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace(",", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace("'", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace('"', "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace("m", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace("juvenile", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace(r'\d', "").replace("-", "")
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_11712\2025326055.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   shark_attack['Species_'] = shark_attack['Species_'].str.replace(r'\d', "").replace("-", "")

# %%
shark_attack['Species'].value_counts()
# Out:
# nan                                                                                                  2838
# shark                                                                                                 465
# whiteshark                                                                                            312
# []shark                                                                                               293
# tigershark                                                                                            138
#                                                                                                      ...
# thoughinvolveatigershark                                                                                1
# tigershark-kg[-lb]                                                                                      1
# possiblyatigershark                                                                                     1
# cc[]blacktiporspinnershark                                                                              1
# saidinvolveagreynursesharkthatleapufthewaterandseizedtheboybutspeciesidentificationisquestionable       1
# Name: Species, Length: 686, dtype: int64

# %% [markdown]
# Create a loop to change all the elements in the column for the ones that i really need.
# Have to change the column into a list so i can work with them.

# %%
species_lst = list(shark_attack['Species'])

# %%
spc = ["whiteshark", "tigershark", "bullshark", "wobbegongshark", "blacktipshark", "nurseshark", "spinnershark", "reefshark", "galapagosshark", "blueshark", "porbeagleshark", "goblinshark"]
x = []
for i in species_lst:
    if i in spc:
        x.append(i)
    else:
        x.append("NaN")

# %% [markdown]
# Result is saved as a list, have to change it to a panda series so it can be added to the data frame.

# %%
spc_serie = pd.Series(x)

# %%
shark_attack['Species'] = spc_serie

# %%
shark_attack["Species"].value_counts()
# Out:
# NaN               5593
# whiteshark         312
# tigershark         138
# bullshark          114
# wobbegongshark      33
# blacktipshark       30
# nurseshark          27
# blueshark           24
# spinnershark        12
# reefshark            8
# galapagosshark       5
# porbeagleshark       4
# goblinshark          2
# Name: Species, dtype: int64

# %%
sns.countplot(y = shark_attack.Species);

# %% [markdown]
# will go to eliminate the columns copied columns, we dont need them anymore and they were kept dirty

# %%
shark_attack.drop(columns =['Species_', 'Date'], inplace=True, axis=1)

# %%
shark_attack.sample()
# Out:
#         Year        Type    Country Area Location  \
# 2459  1994.0  Unprovoked  HONG KONG  NaN      NaN
#
#                              Activity    Name Sex_  Age               Injury  \
# 2459  Playing volleyball with friends  female    F  NaN  Both legs lacerated
#
#      Fatal_(y/n) Time Months Species
# 2459           N  NaN    NaN     NaN
