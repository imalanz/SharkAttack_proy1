# %% [markdown]
# # 1. Cleaning

# %% [markdown]
# ### importing data

# %%
import pandas as pd
import numpy as np
import openpyxl
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_file = "D:\\ironhack\\proyectos\\SharkAttack_proy1\DATA\\attacks_1.csv"
shark_attack = pd.read_csv(csv_file, encoding="cp1252")

# %%
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
shark_attack.sample(3)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 23500         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 17320         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 21099         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 23500  ...      NaN                    NaN  NaN          NaN  NaN
# 17320  ...      NaN                    NaN  NaN          NaN  NaN
# 21099  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 23500           NaN           NaN            NaN         NaN         NaN
# 17320           NaN           NaN            NaN         NaN         NaN
# 21099           NaN           NaN            NaN         NaN         NaN
#
# [3 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 25723

# %%
shark_attack.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %% [markdown]
# ### Null values

# %%
shark_attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
#revisar si necesito eliminar los NaN
#puedo meterme directo a explorar la columna a ver como se ven con los NaN
#llamando el key y poniendole .isna()

# %%
#pd.isnull(shark_attack).sum() same formula
shark_attack.isna().sum()
#for NaN, un promedio de 18000NaNs en una lista de 19803
#conclucion, demasiados NaN tendre que eliminar
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
shark_attack.notnull().sum()
# Out:
# Case Number               8702
# Date                      6302
# Year                      6300
# Type                      6298
# Country                   6252
# Area                      5847
# Location                  5762
# Activity                  5758
# Name                      6092
# Sex                       5737
# Age                       3471
# Injury                    6274
# Fatal (Y/N)               5763
# Time                      2948
# Species                   3464
# Investigator or Source    6285
# pdf                       6302
# href formula              6301
# href                      6302
# Case Number.1             6302
# Case Number.2             6302
# original order            6309
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %% [markdown]
# After this filter we can see that it has tons of null data, from 25723 original rows we can see that it will let us with almos 6,000 rows. Not much information and we can clean it.

# %% [markdown]
# next step it will be to drop (errase) the rows that dont apport nothing to the data.
# If we throw the formula od dropna with the fuction "any" its not an option, every single row has even one missed cell, we will be applying the function "all"

# %%
shark_attack.dropna(how="all",inplace=True)
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 8698               NaN                             NaN          NaN
# 8699               NaN                             NaN          NaN
# 8700               NaN                             NaN          NaN
# 8701               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 8698               NaN  NaN  ...              NaN
# 8699               NaN  NaN  ...              NaN
# 8700               NaN  NaN  ...              NaN
# 8701               NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 8698                              NaN                       NaN
# 8699                              NaN                       NaN
# 8700                              NaN                       NaN
# 8701                              NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 8698                                                 NaN
# 8699                                                 NaN
# 8700                                                 NaN
# 8701                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 8698                                                 NaN           NaN
# 8699                                                 NaN           NaN
# 8700                                                 NaN           NaN
# 8701                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 8698            NaN            NaN         NaN         NaN
# 8699            NaN            NaN         NaN         NaN
# 8700            NaN            NaN         NaN         NaN
# 8701            NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [8703 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 8703

# %% [markdown]
# it let us with only 8703 rows. But we still have some missing values in the cells thats wy apears in the formula below that we still have a lot of them, probably half of the columns have NANs.

# %%
shark_attack.isna().sum()
# Out:
# Case Number                  1
# Date                      2401
# Year                      2403
# Type                      2405
# Country                   2451
# Area                      2856
# Location                  2941
# Activity                  2945
# Name                      2611
# Sex                       2966
# Age                       5232
# Injury                    2429
# Fatal (Y/N)               2940
# Time                      5755
# Species                   5239
# Investigator or Source    2418
# pdf                       2401
# href formula              2402
# href                      2401
# Case Number.1             2401
# Case Number.2             2401
# original order            2394
# Unnamed: 22               8702
# Unnamed: 23               8701
# dtype: int64

# %% [markdown]
# ### Duplicated

# %%
shark_attack.shape[0]
# Out:
# 8703

# %%
shark_attack.duplicated().sum()
# Out:
# 2392

# %% [markdown]
# This tell us that we have 2,392 raws that are duplicated and will have to be removed, otherwise it will leave us with some false information.

# %%
shark_attack.drop_duplicates(inplace=True)
shark_attack.sample(5)
# Out:
#          Case Number                  Date    Year        Type  \
# 1030      2010.05.01           01-May-2010  2010.0  Unprovoked
# 5661  1894.04.28.a.R  Reported 28-Apr-1894  1894.0  Unprovoked
# 2308    1996.04.25.b           25-Apr-1996  1996.0  Unprovoked
# 1616      2005.01.14           14-Jan-2005  2005.0    Provoked
# 4645      1944.06.23           23-Jun-1944  1944.0     Invalid
#
#                   Country             Area  \
# 1030                  USA          Florida
# 5661                BURMA          Rangoon
# 2308            AUSTRALIA  New South Wales
# 1616            AUSTRALIA         Victoria
# 4645  NORTH PACIFIC OCEAN              NaN
#
#                                                Location  \
# 1030                                   New Smyrna Beach
# 5661                                            Amherst
# 2308                                          Mona Vale
# 1616                                        Blairgowrie
# 4645  Aircraft went down on 6/12/1944. He survived o...
#
#                                                Activity             Name Sex   \
# 1030                                             Wading   Caitlin Dubois    F
# 5661                                            Bathing      Lucy Stone     F
# 2308                                           Swimming       Luke Baker    M
# 1616  Attempting to drive shark away from sailing re...           dinghy  NaN
# 4645                                                NaN  Lt. Cmdr. Price    M
#
#       ...                                          Species   \
# 1030  ...                                          4' shark
# 5661  ...                                               NaN
# 2308  ...                                   Wobbegong shark
# 1616  ...  Bronze whaler shark, 2 m to 3 m [6.75' to 10']
# 4645  ...                                           Invalid
#
#                           Investigator or Source  \
# 1030  S. Petersohn;J. Wheeler, 13 News, 5/4/2010
# 5661                     Bruce Herald, 8/24/1894
# 2308             Daily Telegraph, 4/26/1996, p.9
# 1616                             Herald Sun News
# 4645                            USS Boyd archive
#
#                                         pdf  \
# 1030                  2010.05.01-Dubois.pdf
# 5661           1894.04.28.a.R-LucyStone.pdf
# 2308                 1996.04.25.b-Baker.pdf
# 1616                2005.01.14-raceboat.pdf
# 4645  1944.06.23-Boyd-Rescue-incomplete.pdf
#
#                                            href formula  \
# 1030  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5661  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2308  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1616  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4645  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   Case Number.1  \
# 1030  http://sharkattackfile.net/spreadsheets/pdf_di...      2010.05.01
# 5661  http://sharkattackfile.net/spreadsheets/pdf_di...  1894.04.28.a.R
# 2308  http://sharkattackfile.net/spreadsheets/pdf_di...    1996.04.25.b
# 1616  http://sharkattackfile.net/spreadsheets/pdf_di...      2005.01.14
# 4645  http://sharkattackfile.net/spreadsheets/pdf_di...      1944.06.23
#
#        Case Number.2 original order Unnamed: 22 Unnamed: 23
# 1030      2010.05.01         5273.0         NaN         NaN
# 5661  1894.04.28.a.R          642.0         NaN         NaN
# 2308    1996.04.25.b         3995.0         NaN         NaN
# 1616      2005.01.14         4687.0         NaN         NaN
# 4645      1944.06.23         1658.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 6311

# %% [markdown]
# This leave us with only 6,311 rows that are not duplicated and have minimum 1 real value.
# Because I can notice that there are still some rows that looks preatty empty and the few values that could have it might not be important to us and our investigation.

# %% [markdown]
# ### columns

# %% [markdown]
# passing throw the Data frame I notice that theres some columns that are not relevant to our investigation, that doesnt apport anything of value that we could could benefit

# %%
shark_attack.sample()
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 3485  1968.02.04  04-Feb-1968  1968.0  Unprovoked  AUSTRALIA  South Australia
#
#          Location      Activity            Name Sex   ...  \
# 3485  Cape Jervis  Spearfishing  Howard Forster    M  ...
#
#                              Species  Investigator or Source  \
# 3485  Bronze whaler shark, 3 m [10']   H.D. Baldridge, p.199
#
#                          pdf  \
# 3485  1968.02.04-Forster.pdf
#
#                                            href formula  \
# 3485  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 3485  http://sharkattackfile.net/spreadsheets/pdf_di...    1968.02.04
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 3485    1968.02.04         2818.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
shark_attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# There are some columns that makes me have some interest, in wich ones we could errase because of our lak of information for us, for example the las 2 columns 'Unnamed: 22', 'Unnamed: 23', seen the samples we could see that theres only non values and actually the tittle doesn´t give us any explanetion.
# We will erase them.

# %%
shark_attack[['Unnamed: 22', "Unnamed: 23"]].sample(5)
# Out:
#      Unnamed: 22 Unnamed: 23
# 4465         NaN         NaN
# 5585         NaN         NaN
# 5067         NaN         NaN
# 6152         NaN         NaN
# 3259         NaN         NaN

# %%
shark_attack.drop(columns =['Unnamed: 22', "Unnamed: 23"], inplace=True, axis=1)

# %%
shark_attack.sample()
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 4395  1952.12.21  21-Dec-1952  1952.0  Unprovoked  AUSTRALIA  South Australia
#
#           Location               Activity         Name Sex   ... Fatal (Y/N)  \
# 4395  Cape Douglas  Fishing, setting nets  John Holmes    M  ...           N
#
#               Time          Species   \
# 4395  "After dark"  2.4 m [8'] shark
#
#                                  Investigator or Source  \
# 4395  V.M. Coppleson (1958), p.178; V.M. Coppleson (...
#
#                         pdf  \
# 4395  1952.12.21-Holmes.pdf
#
#                                            href formula  \
# 4395  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 4395  http://sharkattackfile.net/spreadsheets/pdf_di...    1952.12.21
#
#      Case Number.2 original order
# 4395    1952.12.21         1908.0
#
# [1 rows x 22 columns]

# %% [markdown]
# more research in columns: lets see if the internet links could help us with our research.

# %%
shark_attack['href formula'].sample(5)
# Out:
# 1770    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1622    http://sharkattackfile.net/spreadsheets/pdf_di...
# 6136    http://sharkattackfile.net/spreadsheets/pdf_di...
# 5026    http://sharkattackfile.net/spreadsheets/pdf_di...
# 3886    http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href formula, dtype: object

# %%
shark_attack['href'].sample(5)
# Out:
# 5895    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4011    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4215    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4792    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2970    http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href, dtype: object

# %% [markdown]
# Exploring this 2 columns 'href formula' and 'href' we can realice that they apporr some internet links, but going throw them they the pages dont exist amymore.

# %%
shark_attack['Case Number.1'].sample(5)
# Out:
# 1180    2008.12.27.c
# 3484      1968.02.18
# 6305             NaN
# 1088      2009.09.18
# 1963      2001.04.10
# Name: Case Number.1, dtype: object

# %% [markdown]
# other columns that dont apport anything of value are 'Case Number.1', 'Case Number.2'  we can see that the information there is actually the same and its the date of the attack that we do have it already in other columns at the beginning, and 'original order' dont aport us anything.
# we´ll pass to some more drop cleaning.
# we also dont count with any extra file from the data page like the pdf files, so we could erase thata one to.

# %%
shark_attack.drop(columns =['Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order'], inplace=True, axis=1)

# %%
shark_attack.sample()
# Out:
#      Case Number         Date    Year        Type Country        Area  \
# 1080  2009.10.24  24-Oct-2009  2009.0  Unprovoked     USA  California
#
#                            Location Activity          Name Sex   Age  \
# 1080  San Onofre, San Diego County   Surfing  Scott Barton    M  NaN
#
#                                                  Injury Fatal (Y/N)   Time  \
# 1080  3 puncture wounds to big toe of left foot, and...           N  17h30
#
#      Species
# 1080      NaN

# %%
shark_attack.columns = [i.capitalize().replace(" ", "_") for i in list(shark_attack.columns)]
shark_attack.columns
# Out:
# Index(['Case_number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex_', 'Age', 'Injury', 'Fatal_(y/n)', 'Time',
#        'Species_'],
#       dtype='object')

# %%
#shark_attack.columns = [i.replace(" ", "") for i in list(shark_attack.columns) if i[-1]==" "]
#shark_attack.columns

# %%
#for i in list(shark_attack.columns):
 #   i[-1].replace(" ", "")
#shark_attack.columns

# %%
#for i in list(shark_attack.columns):
#    for e in range(len(i)):
#        if e == "_":
#            list(shark_attack.columns).append(e.replace("_", ""))
#shark_attack.columns

# %%
#for i in list(shark_attack.columns):
#    for e in len(i)if i[-1] == " ":
#        list(shark_attack.columns).append(i.replace(" ", ""))
#shark_attack.columns

# %%
shark_attack.head()
# Out:
#   Case_number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex_  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal_(y/n)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species_
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# 3            NaN        2 m shark
# 4            NaN  Tiger shark, 3m

# %% [markdown]
# For this analysis Im interested in some of the columns, I will need the 'Date', 'Country', 'Injury', 'Fatal_(y/n)', 'Time' and 'Species_', I will have to go throw them and cleaning them more deep so we would not have any bias.

# %% [markdown]
# ### Cleaning "Date"

# %% [markdown]
# For "Date" i will need to clean it and have it more organized, will nedd to make all data the same information, so i can calculate it the same way. will need to separate tin different columns the day, in another de month and in another the year, that we already have it.
# in this case I will need to create 2 more columns or just one and modified the others.

# %%
shark_attack['Date'].value_counts()
# Out:
# 1957                          11
# 1942                           9
# 1956                           8
# 1958                           7
# 1950                           7
#                               ..
# 01-Dec-1994                    1
# Reported      10-Dec-1994      1
# 11-Dec-1994                    1
# 13-Dec-1994                    1
# 1845-1853                      1
# Name: Date, Length: 5433, dtype: int64

# %%
shark_attack.dtypes
# Out:
# Case_number     object
# Date            object
# Year           float64
# Type            object
# Country         object
# Area            object
# Location        object
# Activity        object
# Name            object
# Sex_            object
# Age             object
# Injury          object
# Fatal_(y/n)     object
# Time            object
# Species_        object
# dtype: object

# %% [markdown]
# Se hizo el cambio de type de Date, aunque ya estaba como objeto, no me reconocia algunos cambios por que el error me aventaba que eran floats.

# %%
shark_attack["Date"] = shark_attack["Date"].astype("str")

# %%
shark_attack['Date'] = shark_attack['Date'].str.replace(r'\d', "").replace("-", "")
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_11712\3945705354.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   shark_attack['Date'] = shark_attack['Date'].str.replace(r'\d', "").replace("-", "")

# %%
shark_attack['Date'] = shark_attack['Date'].str.replace("-", "")

# %%
shark_attack['Date'] = shark_attack['Date'].str.replace("or", "")

# %%
shark_attack['Date'] = shark_attack['Date'].str.replace("Reported", "")

# %%
shark_attack['Date'] = shark_attack['Date'].str.replace("Late", "").replace("Early", "")

# %%
shark_attack['Date'] = shark_attack['Date'].str.replace(" ", "")

# %%
shark_attack['Date'] = shark_attack['Date'].str.replace("Mid", "")

# %%
shark_attack['Date'].value_counts()
# Out:
# Jul                       587
# Aug                       548
# Sep                       490
# Jan                       462
# Jun                       438
#                          ...
# SometimebetweenJan&Jan      1
# WoirldWarII                 1
# SeptoSep                    1
# MartoMar                    1
# SometimebetweenApr&Nov      1
# Name: Date, Length: 131, dtype: int64

# %%
list(shark_attack['Date'])
# Out:
# ['Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'ReptedApr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'ReptedApr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'ReptedNov',
#  'Nov',
#  'Nov',
#  'ReptedNov',
#  'Nov',
#  'Nov',
#  'ReptedOct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'ReptedSep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'ReptedJul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'ReptedJul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  '..',
#  'ReptedJun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'ReptedJun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'ReptedMay',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'ReptedMar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'ReptedJan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'ReptedJul',
#  'ReptedJul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'ReptedMar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'ReptedFeb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'ReptedJan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'ReptedJun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Jun',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'ReptedDec',
#  'Dec',
#  'ReptedDec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'ReptedNov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'ReptedSep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'ReptedAug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'ReptedJun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'ReptedJun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'ReptedMay',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'ReptedApr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'ReptedFeb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  '',
#  '',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'ReptedAug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'ReptedJul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'ReptedJun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'ReptedApr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'ReptedMar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'ReptedJan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'December',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'ReptedOct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'July',
#  'Jul',
#  'Jul',
#  'Jul',
#  'ReptedJun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'ReptedJan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'ReptedDec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'ReptedNov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'ReptedOct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'ReptedJun',
#  'Jun',
#  'ReptedJun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'ReptedMay',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'ReptedMar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'ReptedMar',
#  'Mar',
#  'ReptedFeb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'ReptedFeb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'ReptedJan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'ReptedDec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'ReptedNov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'ReptedNov',
#  'Oct',
#  'ReptedOct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'ReptedSep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  ...]

# %%
sns.countplot(x = shark_attack.Date);

# %%
condition_1 = shark_attack["Date"] == "Jan"
condition_2 = shark_attack["Date"] == "Feb"
condition_3 = shark_attack["Date"] == "Mar"
condition_4 = shark_attack["Date"] == "Apr"
condition_5 = shark_attack["Date"] == "May"
condition_6 = shark_attack["Date"] == "Jun"
condition_7 = shark_attack["Date"] == "Jul"
condition_8 = shark_attack["Date"] == "Aug"
condition_9 = shark_attack["Date"] == "Sep"
condition_10 = shark_attack["Date"] == "Oct"
condition_11 = shark_attack["Date"] == "Nov"
condition_12 = shark_attack["Date"] == "Dec"

# %%
shark_attack
shark_attack.Series[conditiona_1 & condition_2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 shark_attack.Series[conditiona_1 & condition_2]
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Series'

# %%
condis = shark_attack.loc[(shark_attack["Date"] == "Jan") & (shark_attack["Date"] == "Apr")]
condis.head()
# Out:
# Empty DataFrame
# Columns: [Case_number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex_, Age, Injury, Fatal_(y/n), Time, Species_]
# Index: []

# %%
print(shark_attack["Date"] =="Jan", "Feb", "Jun", "Aug")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 6306     False
# 6307     False
# 6308     False
# 6309     False
# 25722    False
# Name: Date, Length: 6311, dtype: bool Feb Jun Aug

# %%
new_boolean = shark_attack["Date"] == "Jan", "Feb", "Mar", "Oct", "Sep", "Apr", "May", "Jun", "Jul", "Aug", "Nov", "Dec"
new_boolean
# Out:
# (0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  6306     False
#  6307     False
#  6308     False
#  6309     False
#  25722    False
#  Name: Date, Length: 6311, dtype: bool,
#  'Feb',
#  'Mar',
#  'Oct',
#  'Sep',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Nov',
#  'Dec')

# %%
shark_attack.drop(shark_attack[shark_attack["Date"] != "Jan", "Feb", "Mar", "Oct", "Sep", 
                                "Apr", "May", "Jun", "Jul", "Aug", "Nov", "Dec"].index(0), inplace=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 6306     True
# 6307     True
# 6308     True
# 6309     True
# 25722    True
# Name: Date, Length: 6311, dtype: bool, 'Feb', 'Mar', 'Oct', 'Sep', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Nov', 'Dec')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [450], in <cell line: 1>()
# ----> 1 shark_attack.drop(shark_attack[shark_attack["Date"] != "Jan", "Feb", "Mar", "Oct", "Sep",
#       2                                 "Apr", "May", "Jun", "Jul", "Aug", "Nov", "Dec"].index(0), inplace=False)
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3810, in Index.get_loc(self, key, method, tolerance)
#    3805         raise KeyError(key) from err
#    3806     except TypeError:
#    3807         # If we have a listlike key, _check_indexing_error will raise
#    3808         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809         #  the TypeError.
# -> 3810         self._check_indexing_error(key)
#    3811         raise
#    3813 # GH#42269
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:5968, in Index._check_indexing_error(self, key)
#    5964 def _check_indexing_error(self, key):
#    5965     if not is_scalar(key):
#    5966         # if key is not a scalar, directly raise an error (the code below
#    5967         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5968         raise InvalidIndexError(key)
#
# InvalidIndexError: (0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 6306     True
# 6307     True
# 6308     True
# 6309     True
# 25722    True
# Name: Date, Length: 6311, dtype: bool, 'Feb', 'Mar', 'Oct', 'Sep', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Nov', 'Dec')

# %% [markdown]
# & condition_2 & condition_3 & condition_4 & condition_5 & condition_6

# %% [markdown]
# condition_7 & condition_8 & condition_9 & condition_10 & condition_11 & condition_12

# %% [markdown]
# shark_attack.sample()

# %% [markdown]
# shark_attack['Date'] = shark_attack['Date'].astype('str')

# %% [markdown]
# shark_attack.query("Date"=="Jan")

# %% [markdown]
# shark_attack['Date'] = shark_attack['Date'].astype('Bool')

# %%
shark_attack = shark_attack[shark_attack['Date'].str.contains("Jan", "Feb", "Mar")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [453], in <cell line: 1>()
# ----> 1 shark_attack = shark_attack[shark_attack['Date'].str.contains("Jan", "Feb", "Mar")]
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\strings\accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\strings\accessor.py:1260, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1252 if regex and re.compile(pat).groups:
#    1253     warnings.warn(
#    1254         "This pattern is interpreted as a regular expression, and has "
#    1255         "match groups. To actually get the groups, use str.extract.",
#    1256         UserWarning,
#    1257         stacklevel=find_stack_level(),
#    1258     )
# -> 1260 result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1261 return self._wrap_result(result, fill_value=na, returns_string=False)
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\strings\object_array.py:122, in ObjectStringArrayMixin._str_contains(self, pat, case, flags, na, regex)
#     119     if not case:
#     120         flags |= re.IGNORECASE
# --> 122     pat = re.compile(pat, flags=flags)
#     124     f = lambda x: pat.search(x) is not None
#     125 else:
#
# File ~\miniconda2\envs\ironhack\lib\re.py:251, in compile(pattern, flags)
#     249 def compile(pattern, flags=0):
#     250     "Compile a regular expression pattern, returning a Pattern object."
# --> 251     return _compile(pattern, flags)
#
# File ~\miniconda2\envs\ironhack\lib\re.py:303, in _compile(pattern, flags)
#     301 if not sre_compile.isstring(pattern):
#     302     raise TypeError("first argument must be string or compiled pattern")
# --> 303 p = sre_compile.compile(pattern, flags)
#     304 if not (flags & DEBUG):
#     305     if len(_cache) >= _MAXCACHE:
#     306         # Drop the oldest item
#
# File ~\miniconda2\envs\ironhack\lib\sre_compile.py:764, in compile(p, flags)
#     762 if isstring(p):
#     763     pattern = p
# --> 764     p = sre_parse.parse(p, flags)
#     765 else:
#     766     pattern = None
#
# File ~\miniconda2\envs\ironhack\lib\sre_parse.py:950, in parse(str, flags, state)
#     947 state.str = str
#     949 try:
# --> 950     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     951 except Verbose:
#     952     # the VERBOSE flag was switched on inside the pattern.  to be
#     953     # on the safe side, we'll parse the whole thing again...
#     954     state = State()
#
# TypeError: unsupported operand type(s) for &: 'str' and 'int'

# %%
shark_attack.sample()
# Out:
#     Case_number Date    Year        Type Country    Area  \
# 477  2014.11.13  Nov  2014.0  Unprovoked     USA  Hawaii
#
#                               Location    Activity         Name Sex_ Age  \
# 477  Airplane Beach, Lahina, West Maui  Snorkeling  Andrew Haas    M  53
#
#                            Injury Fatal_(y/n)   Time     Species_
# 477  Laceration to left upper leg           N  13h30  1.5 m shark

# %%
x = []
months = ["Jan", "Feb," "Mar", "Oct", "Sep", "Apr", "May", "Jun", "Jul", "Aug", "Nov", "Dec"]
for i in shark_attack["Date"]:
    if i in months:
        x.append(i)

# %%
se = pd.Series(x)

# %%
shark_attack["Months"] = se

# %%
se = pd.Series(x)

# %%
def limpia_num(x):
    months = "Jan", "Feb," "Mar", "Oct", "Sep", "Apr", "May", "Jun", "Jul", "Aug", "Nov", "Dec" 
    x = list(x)
    for i in range(len(x)):
        if i not in months:
            return x.append(i)
        else:
            return ""

# %%
shark_attack["meses"] = list(shark_attack["Date"].apply(limpia_num))

# %%
shark_attack.sample(50)
# Out:
#        Case_number       Date    Year          Type           Country  \
# 6108  1823.12.30.R  ReptedDec  1823.0       Invalid           JAMAICA
# 5560    1900.07.00        Jul  1900.0      Provoked               USA
# 146   2017.04.29.d        Apr  2017.0    Unprovoked               USA
# 6147    1767.00.00             1767.0       Invalid            FRANCE
# 4852    1937.03.26        Mar  1937.0       Invalid         AUSTRALIA
# 5559    1900.07.14        Jul  1900.0       Invalid               USA
# 5848    1878.02.02        Feb  1878.0  Sea Disaster            BRAZIL
# 283     2016.04.22        Apr  2016.0    Unprovoked      SOUTH AFRICA
# 1658  2004.07.02.b        Jul  2004.0    Unprovoked             EGYPT
# 1797    2003.02.11        Feb  2003.0    Unprovoked         AUSTRALIA
# 4393  1953.00.00.a             1953.0    Unprovoked               USA
# 2135  1999.02.26.R        Feb  1999.0       Boating               USA
# 1264  2008.04.28.a        Apr  2008.0    Unprovoked               USA
# 1828  2002.09.16.b        Sep  2002.0    Unprovoked            BRAZIL
# 40      2018.02.23        Feb  2018.0    Unprovoked         AUSTRALIA
# 1936  2001.07.06.a        Jul  2001.0    Unprovoked               USA
# 3374    1970.12.17        Dec  1970.0    Unprovoked        MOZAMBIQUE
# 938   2011.03.21.a        Mar  2011.0    Unprovoked              FIJI
# 5882    1874.07.15        Jul  1874.0    Unprovoked               USA
# 669   2013.06.06.b        Jun  2013.0      Provoked               USA
# 1170  2009.01.13.R  ReptedJan  2009.0    Unprovoked      SOUTH AFRICA
# 5715  1889.10.03.R  ReptedOct  1889.0    Unprovoked             INDIA
# 5542    1901.12.01        Dec  1901.0    Unprovoked         AUSTRALIA
# 2616  1990.10.30.a        Oct  1990.0    Unprovoked               USA
# 5647    1894.12.11        Dec  1894.0      Provoked               USA
# 4554    1948.01.25        Jan  1948.0    Unprovoked         AUSTRALIA
# 2641    1990.04.06        Apr  1990.0    Unprovoked         AUSTRALIA
# 3841    1962.01.26        Jan  1962.0    Unprovoked        MOZAMBIQUE
# 1142    2009.03.21        Mar  2009.0    Unprovoked      SOUTH AFRICA
# 6054  1845.09.10.R  ReptedSep  1845.0    Unprovoked               USA
# 1146  2009.03.18.a        Mar  2009.0    Unprovoked               USA
# 4001  1960.04.03.b        Apr  1960.0    Unprovoked         AUSTRALIA
# 1756    2003.07.09        Jul  2003.0    Unprovoked           BAHAMAS
# 4596  1946.07.18.b        Jul  1946.0    Unprovoked              IRAN
# 4797  1939.04.12.R        Apr  1939.0    Unprovoked  PAPUA NEW GUINEA
# 1612    2005.02.13        Feb  2005.0    Unprovoked               USA
# 954     2011.01.15        Jan  2011.0    Unprovoked      SOUTH AFRICA
# 1085    2009.10.09        Oct  2009.0    Unprovoked               USA
# 1532  2005.11.02.a        Nov  2005.0    Unprovoked               USA
# 6290       ND.0012    BefeJul     0.0    Unprovoked      SOUTH AFRICA
# 5040    1930.07.19        Jul  1930.0    Unprovoked              CUBA
# 2719    1988.08.19        Aug  1988.0    Unprovoked             JAPAN
# 78    2017.09.25.a        Sep  2017.0    Unprovoked         AUSTRALIA
# 4692    1942.11.25        Nov  1942.0    Unprovoked      SOUTH AFRICA
# 5985    1860.03.27        Mar  1860.0  Sea Disaster      COOK ISLANDS
# 476     2014.11.16        Nov  2014.0    Unprovoked               USA
# 466   2014.12.28.c        Dec  2014.0       Invalid      SOUTH AFRICA
# 4676    1943.05.14        May  1943.0  Sea Disaster         AUSTRALIA
# 3026    1981.05.24        May  1981.0    Unprovoked               USA
# 1106  2009.07.24.b        Jul  2009.0    Unprovoked               USA
#
#                        Area  \
# 6108                    NaN
# 5560            Connecticut
# 146              California
# 6147           Côte d'Azur
# 4852        New South Wales
# 5559                 Hawaii
# 5848                    NaN
# 283   Western Cape Province
# 1658        Sinai Peninsula
# 1797        New South Wales
# 4393                Florida
# 2135         North Carolina
# 1264                Florida
# 1828             Pernambuco
# 40          New South Wales
# 1936                Florida
# 3374       Inhambe Province
# 938                     NaN
# 5882               New York
# 669                 Florida
# 1170  Western Cape Province
# 5715             Tamil Nadu
# 5542             Queensland
# 2616                Florida
# 5647                Florida
# 4554        New South Wales
# 2641             Queensland
# 3841                   Gaza
# 1142  Eastern Cape Province
# 6054                Florida
# 1146                Florida
# 4001               Victoria
# 1756          Abaco Islands
# 4596     Khuzestan Province
# 4797        Morobe Province
# 1612                Florida
# 954   Eastern Cape Province
# 1085             California
# 1532             California
# 6290          KwaZulu-Natal
# 5040        Havana Province
# 2719       Tokyo Prefecture
# 78        Western Australia
# 4692          KwaZulu-Natal
# 5985         Mangaia Island
# 476                 Florida
# 466           KwaZulu-Natal
# 4676             Queensland
# 3026                 Hawaii
# 1106                  Texas
#
#                                                Location  \
# 6108                                                NaN
# 5560                       Bridgeport, Fairfield County
# 146                       San Onofre, San Diego County
# 6147                                         St. Tropez
# 4852                                     South Cronulla
# 5559                              Makapu'u Point, O'ahu
# 5848                                                NaN
# 283                      Robberg Beach, Plettenberg Bay
# 1658                                The lagoon at Dahab
# 1797                            Coogee Bay, near Sydney
# 4393                      Juno Beach, Palm Beach County
# 2135                                  Frying Pan Shoals
# 1264                   New Smyrna Beach, Volusia County
# 1828        Piedade Beach, Jaboatão dos Guararapes City
# 40                   Little Congwong Beach, La Perouse
# 1936                     Gulf Islands National Seashore
# 3374                              Inhasoka, Inhambe Bay
# 938                                           Nukudamu
# 5882                                       Coney Island
# 669        Off Snipe Point, Florida Keys, Monroe County
# 1170                          Shark Alley, off Gansbaai
# 5715                                             Madras
# 5542                                           Brisbane
# 2616                        Indialantic, Brevard County
# 5647                         North Beach, St. Augustine
# 4554                             Mona Vale, near Sydney
# 2641                                       Fingal Beach
# 3841                                    Praia Sepulveda
# 1142                      Second Beach, Port St. John's
# 6054                     Pensacola Bay, Escambia County
# 1146                        Ponce Inlet, Volusia County
# 4001  Canadian Bay near Mount Eliza, 30 miles from M...
# 1756                                         Bakers Bay
# 4596                       Dorquain, on the Karun River
# 4797                                            Bulolol
# 1612                                    Fort Lauderdale
# 954                       Second Beach, Port St. John's
# 1085           San Onofre State Beach, San Diego County
# 1532   Ocean Beach, San Francisco, San Francisco County
# 6290                                             Durban
# 5040                     LaPlaya Beach / Vedado, Havana
# 2719                                  Ogasawara Islands
# 78                                            Gracetown
# 4692                                           Umkomaas
# 5985                                                NaN
# 476                 Indian Harbor Beach, Brevard County
# 466                                              Durban
# 4676                                       Off Brisbane
# 3026                          Ha'ena Beach Park, Kaua'i
# 1106                                 South Padre Island
#
#                                                Activity  \
# 6108                                                NaN
# 5560
# 146                                            Swimming
# 6147                                            Bathing
# 4852                                            Bathing
# 5559                                  Hunting seashells
# 5848                                    Washed off raft
# 283                                         Surf-skiing
# 1658                                         Snorkeling
# 1797                                           Swimming
# 4393                                           Standing
# 2135                                           Cruising
# 1264                                            Surfing
# 1828                                           Swimming
# 40                                             Swimming
# 1936                                           Swimming
# 3374                                 Fishing for prawns
# 938                                    Diving / fishing
# 5882                                            Bathing
# 669                                  Fishing for sharks
# 1170                                                NaN
# 5715                                           Swimming
# 5542                                            Bathing
# 2616                                            Surfing
# 5647                                            Fishing
# 4554                                        Surf skiing
# 2641                                            Surfing
# 3841                                                NaN
# 1142                                            Surfing
# 6054                                      Seine netting
# 1146                                            Surfing
# 4001                                       Spearfishing
# 1756                                       Spearfishing
# 4596                       Fishing, probably with a net
# 4797                                   Dived for a coin
# 1612                                       Spearfishing
# 954                                             Surfing
# 1085                                            Surfing
# 1532                                            Surfing
# 6290                                             Wading
# 5040                                           Swimming
# 2719                                                NaN
# 78                                              Surfing
# 4692                                           Swimming
# 5985              43-ton schooner Irene capsized & sank
# 476                                             Surfing
# 466                                            Swimming
# 4676  Hospital Ship Centaur torpedoed & sunk by the ...
# 3026         Scuba diving, reportedly also spearfishing
# 1106                                             Wading
#
#                                                    Name Sex_   Age  \
# 6108                                               male  NaN   NaN
# 5560  skiff with Dr. William T. Healey, Dr. Henry Ca...  NaN   NaN
# 146                                     Leeanne Ericson    F   NaN
# 6147                                    Samuel Matthews    M   NaN
# 4852                                        Austin Shaw    M    16
# 5559               Emil Uhlbrecht & unidentified person    M   NaN
# 5848                                    escaped convict    M   NaN
# 283                                         Dave Manson    M   NaN
# 1658                      Mirjam Buser, a Swiss tourist    F  Teen
# 1797                                      Tom Plumridge    M    24
# 4393                                               girl    F   NaN
# 2135                   28' sport fishing boat, Bird Dog  NaN   NaN
# 1264                                        David Alger    M    18
# 1828                          Fabrício José de Carvalho    M    19
# 40                                       Anna Shurapey     F    55
# 1936                                     Jesse Arbogast    M     8
# 3374                                     Castigo Litura    M    18
# 938                                       Metereti Jeke    M    30
# 5882                                         Mr. Keatly    M   NaN
# 669                                     Walter Kefauver    M    58
# 1170                                        4 poachers   NaN   NaN
# 5715                         B, a young English officer    M   NaN
# 5542                                     William Quince    M    10
# 2616                                         Mark Evans    M    18
# 5647                                 Chatiles F. Brynes    M   NaN
# 4554                                       David Button    M   NaN
# 2641                                        Tony Patton    M    29
# 3841                            Domingos Zefanias Cumbe    M    16
# 1142                                     Luyolo Mangele    M    16
# 6054                                          Nickerson    M   NaN
# 1146                                             female    F    17
# 4001                                      William Black    M   NaN
# 1756                                     Richard Horton    M    58
# 4596                                   Khodadad, (male)    M    12
# 4797                                              child    M     9
# 1612                                               male    M   NaN
# 954                                        Zama Ndamase    M    16
# 1085                                      Bernard Wagor    M   NaN
# 1532                                       Jake Daneman    M    26
# 6290                                   a young Scotsman    M   NaN
# 5040                                     Emilio Grenet     M    29
# 2719                                               male    M   NaN
# 78                                    Catherine Vissers    M   NaN
# 4692                                        E.W. Bilton    M    38
# 5985                                  a Cook's Islander    M   NaN
# 476                                                male    M    44
# 466   5 people claimed to have been injured by a "ba...  NaN   NaN
# 4676                                            unknown    M     F
# 3026                                  Roger B. Garletts    M   NaN
# 1106                                       Deidre Casas    F    14
#
#                                                  Injury Fatal_(y/n)  \
# 6108                       Human remains found in shark         NaN
# 5560  No injury to occupants. They shot shark, then ...           N
# 146                     Major injury to posterior thigh           N
# 6147                           Lacerations to arm & leg         NaN
# 4852  His body was recovered 2 days later but shark ...         NaN
# 5559  Believed drowned. Uhlbrecht’s foot, and the pe...         NaN
# 5848                                              FATAL           Y
# 283                          No injury, surf-ski bitten           N
# 1658                                       Hand severed           N
# 1797         Puncture wounds on heel, legs and buttocks           N
# 4393                       Leg lacerated thigh to ankle           N
# 2135  No injury to occupants, boat sank after collid...           N
# 1264   3-inch laceration to dorsal surface of left foot           N
# 1828        Left thigh bitten, leg surgically amputated           N
# 40                       Laceratons to right leg & foot           N
# 1936                 Arm severed, surgically reattached           N
# 3374                               FATAL, arm severed             Y
# 938   Left forearm severely bitten, surgically amput...           N
# 5882                               Lacerations to groin           N
# 669   Left hand bitten as he attempted to remove hoo...           N
# 1170                                              FATAL           Y
# 5715                                              FATAL           Y
# 5542                       Lacerations to torso & thigh           N
# 2616                                 Cuts on left foot            N
# 5647                  Left leg bitten PROVOKED INCIDENT           N
# 4554                              No injury, ski bitten           N
# 2641                            No injury, board bitten           N
# 3841                                                NaN     UNKNOWN
# 1142                                              FATAL           Y
# 6054                                              FATAL           Y
# 1146                                Minor bite to ankle           N
# 4001                Minor cuts & bruises on face & neck           N
# 1756                                 Right thigh bitten           N
# 4596                                Radius & ulna bared           N
# 4797                                              FATAL           Y
# 1612                                        Hand bitten           N
# 954                                               FATAL           Y
# 1085                     Laceration to shin of left leg           N
# 1532                            No injury, board bumped           N
# 6290                     FATAL, leg stripped of flesh             Y
# 5040  Right arm & leg bitten, arm & leg surgically a...           N
# 2719                                           Survived           N
# 78                    No injury, board damaged by shark           N
# 4692              Calf bitten, leg surgically amputated           N
# 5985                                 Probable drowning            Y
# 476                             Laceration to left hand           N
# 466                                  Minor cuts on feet         NaN
# 4676                                              FATAL           Y
# 3026  FATAL, disappeared, dive gear & shredded tooth...           Y
# 1106             Lacerations to anterior left lower leg           N
#
#              Time                                           Species_ Months
# 6108          NaN       Shark involvement prior to death unconfirmed    NaN
# 5560          NaN                                                NaN    NaN
# 146         17h34                                                NaN    Jan
# 6147          NaN            Description of shark does not ring true    NaN
# 4852          NaN  Shark involvement prior to death was not confi...    NaN
# 5559          NaN                                       Questionable    NaN
# 5848          NaN                                                NaN    NaN
# 283         08h00                                        White shark    Oct
# 1658          NaN                               "black tipped" shark    Sep
# 1797           --  Thought to involve a 2 m [6.75'] grey nurse shark    Jun
# 4393          NaN                                                NaN    Aug
# 2135          NaN                                      Basking shark    Jun
# 1264        11h45                                           4' shark    Sep
# 1828        15h00                                Bull or tiger shark    Oct
# 40    19h00, Dusk                Juvenile white shark,  2.7 to 3.2 m    Dec
# 1936         Dusk                          Bull shark, 2.3 m [7.5']     Aug
# 3374        15h00                                                NaN    Apr
# 938         16h00                                                NaN    May
# 5882    Afternoon                                          68" shark    NaN
# 669           NaN                                    Lemon shark, 4'    May
# 1170          NaN                                       White sharks    Oct
# 5715          NaN                                                NaN    NaN
# 5542          NaN                                                NaN    NaN
# 2616        15h30                                                NaN    Jul
# 5647          NaN                                          12' shark    NaN
# 4554          NaN                                           6' shark    NaN
# 2641          NaN                                          3 m shark    Sep
# 3841          NaN                                                NaN    May
# 1142    Afternoon                                                NaN    May
# 6054          NaN                                                NaN    NaN
# 1146        17h30                                     3' to 4' shark    Apr
# 4001          NaN                                   1.5 m [5'] shark    Sep
# 1756        14h30                               Unidentified species    May
# 4596          NaN                                                NaN    NaN
# 4797          NaN                                                NaN    NaN
# 1612          NaN                    1.8 m [6'] Caribbean reef shark    May
# 954         12h30                                                NaN    Jan
# 1085        11h00                                                NaN    Sep
# 1532        07h15                             12' to 14' white shark    May
# 6290          NaN                                                NaN    NaN
# 5040      Evening                                                NaN    NaN
# 2719          NaN                                                NaN    Jun
# 78          18h00                                 White shark, 3.5 m    Aug
# 4692          NaN                                                NaN    NaN
# 5985          NaN                                                NaN    NaN
# 476         13h00                                           2' shark    May
# 466       Morning  Shark involvement not confirmed & highly unlikely    Jun
# 4676  After 04h00                                                NaN    NaN
# 3026          NaN                                                NaN    May
# 1106    Afternoon                                                NaN    Aug

# %%
shark_attack["Date"].value_counts()
# Out:
# Jul                       587
# Aug                       548
# Sep                       490
# Jan                       462
# Jun                       438
#                          ...
# SometimebetweenJan&Jan      1
# WoirldWarII                 1
# SeptoSep                    1
# MartoMar                    1
# SometimebetweenApr&Nov      1
# Name: Date, Length: 131, dtype: int64

# %%
def limpia_meses(values):
    x = "-"
    num = "1234567890"
    for i in values:
        if i.isdigit():
            return values.replace(i)

# %%
for i in values:
no_digits = []
    if not i.isdigit():
        no_digits.append(i)
# Out:
#   Input In [389]
#     no_digits = []
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
shark_attack["meses"] = shark_attack["Date"].apply(limpia_meses)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [390], in <cell line: 1>()
# ----> 1 shark_attack["meses"] = shark_attack["Date"].apply(limpia_meses)
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\_libs\lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Input In [388], in limpia_meses(values)
#       2 x = "-"
#       3 num = "1234567890"
# ----> 4 for i in values:
#       5     if i.isdigit():
#       6         return values.replace(i)
#
# TypeError: 'float' object is not iterable

# %% [markdown]
# ### Cleaning "Species_"

# %%
shark_attack['Species_'].value_counts().sample(50)
# Out:
# White_shark,__m_to__m_['_to_']_                                                                                                   2
# '_white_shark_or_-gill_shark                                                                                                      1
# _White_shark,_'_                                                                                                                  1
# ._m_to_._m_['_to_']_white_shark                                                                                                   5
# Said_to_involve_a_large_mako_shark                                                                                                1
# ._m_white_shark,_tooth_fragments_recovered                                                                                        1
# Possibly_a_._m_[']_blacktip_or_spinner_shark                                                                                      1
# ._m_[']_whaler_shark                                                                                                              1
# "small_sharks"                                                                                                                    3
# Believed_white_shark_and_other_smaller_species_of_sharks_involved.                                                                1
# Said_to_involve_a_grey_nurse_shark_that_leapt_out_of_the_water_and__seized_the_boy_but_species_identification_is_questionable     1
# Bull_shark?                                                                                                                       2
# Two_._m_[']_sharks                                                                                                                1
# White_shark,__m_[']_rk                                                                                                            1
# Basking_shark                                                                                                                     7
# Raggedtooth_shark,_-lb_                                                                                                           1
# small_blacktip_shark                                                                                                              2
# Tiger_shark_                                                                                                                      1
# Silvertip_shark                                                                                                                   1
# _Galapagos_shark,_'                                                                                                               1
# Tiger_shark,_'_to_'                                                                                                               3
# _'_to_'_shark                                                                                                                     1
# _m_to___m_shark                                                                                                                   1
# Raggedtooth_shark,_-kg_[-lb]_                                                                                                     1
# Bull_shark                                                                                                                       52
# Questionable_incident                                                                                                            35
# Tiger_shark,_'_                                                                                                                  11
# Two_sharks_seen_in_vicinity:_._m_&_._m__['_&_']_TL                                                                                1
# Bronze_whaler_shark,._m_[']_                                                                                                      1
# Wobbegong,_m                                                                                                                      1
# "A_pack_of__sharks"                                                                                                               1
# Bronze_whaler_shark?                                                                                                              3
# Nurse_shark,_m_                                                                                                                   1
# Blue_shark,_.m                                                                                                                    1
# ._m_[']_sandtiger_shark                                                                                                           2
# "a_school_of_sharks"                                                                                                              1
# _m_[.']_sevengill__shark                                                                                                          1
# Tiger_shark,__m_                                                                                                                  5
# No_shark_invovlement_-_it_ws_a_publicity_stunt                                                                                    1
# Tiger_shark,_._m_                                                                                                                 4
# White_shark,_',_identity_confirmed_by_tooth_fragment,_witness_and_photograph_of_captured_shark_                                   1
# Blue_sharks                                                                                                                       1
# ._m_[']__bull_shark_or_Caribbean_reef_shark                                                                                       1
# White_shark,_._m_                                                                                                                 8
# Small_shark                                                                                                                       1
# Possibly_a_broadnose_-gill_shark                                                                                                  1
# Raggedtooth_shark,__m_[.']_                                                                                                       1
# Tiger_shark,_.m__[']                                                                                                              1
# Bull_shark_or_lemon_shark                                                                                                         1
# Juvenile_nurse_shark                                                                                                              1
# Name: Species_, dtype: int64

# %%
list(shark_attack["Species_"])
# Out:
# ['White_shark',
#  nan,
#  nan,
#  '_m_shark',
#  'Tiger_shark,_m',
#  nan,
#  'Tiger_shark',
#  "Lemon_shark,_'",
#  "Bull_shark,_'",
#  nan,
#  'Grey_reef_shark',
#  nan,
#  nan,
#  'Invalid_incident',
#  'Tawny_nurse_shark,_m',
#  nan,
#  'Shark_involvement_not_confirmed',
#  nan,
#  'Tiger_shark',
#  nan,
#  'Questionable',
#  '_m_shark',
#  'White_shark,_._m',
#  'Tiger_shark',
#  'White_shark,_._m',
#  "'_shark",
#  'Juvenile_bull_shark',
#  nan,
#  nan,
#  nan,
#  'Tiger_shark',
#  'Shark_involvement_not_confirmed',
#  '_m_shark',
#  'Bull_shark',
#  'White_shark',
#  "Tiger_shark,_'",
#  'Wobbegong_shark',
#  '._m_shark',
#  '._m_shark',
#  'Blacktip_shark',
#  'Juvenile_white_shark,__._to_._m',
#  nan,
#  'Bull_shark,__m',
#  'Possibly_a_wobbegong',
#  'Injury_believed_caused_by_an_eel,_not_a_shark',
#  'Galapagos_shark?',
#  'm_shark',
#  'Bull_shark',
#  'Bull_shark,__m_',
#  'Grey_reef_shark.__m',
#  'White_shark,_._m',
#  'small_shark',
#  'Wobbegong_shark?',
#  'Tiger_shark',
#  nan,
#  'Juvenile_nurse_shark',
#  "Nurse_shark._'",
#  'Tiger_shark,_female',
#  'Tiger_shark,_female',
#  'Some_drowned_but_other_may_have_been_killed_by_blue_sharks',
#  'White_shark,_._m',
#  nan,
#  nan,
#  '_m_shark',
#  'Tiger_shark',
#  'Cookiecutter_shark',
#  'Wobbegong_shark,__m',
#  nan,
#  nan,
#  nan,
#  nan,
#  'White_shark,_._m',
#  '_m_shark',
#  'Spinner_shark,__to__feet',
#  'Tiger_shark,__to__feet',
#  "'_shark",
#  'Death_may_have_been_due_to_drowning',
#  "'_shark",
#  'White_shark,_._m',
#  'Questionable',
#  "'_to_'_shark",
#  nan,
#  'Porbeagle,_._m',
#  nan,
#  nan,
#  nan,
#  'White_shark,_.m',
#  "'_to_'_shark",
#  nan,
#  'White_shark,__to_.m_',
#  nan,
#  nan,
#  nan,
#  'Nurse_shark',
#  nan,
#  nan,
#  'White_shark,__m',
#  nan,
#  'Shark_involvement_questionable',
#  nan,
#  "White_shark,_'_to_'",
#  "'_shark",
#  'Possibly_a_juvenile_blacktip_shark',
#  'Oceanic_whitetip_shark,_._to__m',
#  "'_shark",
#  "White_shark,_'",
#  nan,
#  'A_small_shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  "Sandtiger_shark__'",
#  "Blue_shark_'",
#  '"A_small_shark"',
#  'Shark_involvement_not_confirmed',
#  "White_shark,_'_to_'",
#  "White_shark,_'_to_'",
#  "White_shark,_'",
#  nan,
#  'White_shark',
#  "Bull_shark,_'_to_'",
#  'Tiger_shark,__kg',
#  'White_shark,_._m',
#  'Shark_involvement_prior_to_death_not_confirmed',
#  'No_shark_invovlement_',
#  nan,
#  nan,
#  "Bull_shark,_'_to_'",
#  'Bull_shark,_m',
#  nan,
#  nan,
#  nan,
#  'White_shark,__m',
#  'Seven-gill_shark',
#  nan,
#  'm_shark,_probably_a_smooth_hound',
#  "'_shark",
#  'Tiger_shark',
#  "'_shark",
#  'Tiger_shark',
#  nan,
#  nan,
#  "'_shark",
#  nan,
#  'Shark_involvement_highly_doubtful',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No_shark_invovlement_-_it_ws_a_publicity_stunt',
#  nan,
#  'Shark_involvement_not_confirmed',
#  nan,
#  'White_shark',
#  "Tiger_shark,_'",
#  nan,
#  nan,
#  'Shark_involvement_prior_to_death_not_confirmed',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  "Bull_shark,_'_to_'",
#  nan,
#  nan,
#  'White_shark',
#  "'_shark",
#  'Lemon_shark',
#  'Bull_shark,_.',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Lemon_shark_pup',
#  'Tiger_shark',
#  "White_shark,_female,_'",
#  'Caribbean_reef_shark',
#  nan,
#  nan,
#  'Bull_shark,__m',
#  nan,
#  nan,
#  'Bull_shark,__m',
#  'Bull_shark',
#  nan,
#  'Shark_involvement_not_confirmed',
#  nan,
#  'a_small_shark',
#  'White_shark,__m',
#  nan,
#  nan,
#  'Shark_involvement_not_confirmed',
#  'Wobbegong_shark,_m',
#  'White_shark',
#  'Broadnose_sevengill_shark,_._m',
#  'Tiger_shark',
#  nan,
#  nan,
#  nan,
#  "_'_to_'_shark",
#  nan,
#  nan,
#  'White_shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'White_shark,_._m',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '_m_shark',
#  nan,
#  "'_to_'_shark",
#  "Tiger_shark,_'",
#  nan,
#  nan,
#  nan,
#  nan,
#  "White_shark,_'_to_'",
#  'Invalid',
#  "Bull_shark,_'",
#  nan,
#  'Bull_shark,_._m',
#  nan,
#  nan,
#  "Tiger_shark,_'_",
#  'Blacktip_shark',
#  'Blue_shark',
#  nan,
#  'White_shark',
#  "Nurse_shark,_'",
#  nan,
#  nan,
#  nan,
#  "Bull_shark,_'",
#  'reef_shark,_m',
#  "Tiger_shark,_'_",
#  nan,
#  nan,
#  "White_shark,_'_to_'",
#  nan,
#  "Lemon_shark,_'",
#  'Angel_shark',
#  'White_shark',
#  'dogfish_shark',
#  'White_shark',
#  nan,
#  'Tawny_nurse_shark',
#  "'_to_'_shark",
#  nan,
#  "Caribbean_reef_shark,_.'",
#  'White_shark',
#  "'_to_'_shark",
#  nan,
#  "'_to_'_shark",
#  "'_shark",
#  "'_to_'_shark",
#  "'_shark",
#  "Said_to_involve_an_'_shark_but_more_likely_damage_caused_by_debris",
#  nan,
#  '+_m_shark',
#  'Mako_shark',
#  'Bronze_whaler_sharks_x_',
#  '_m_shark',
#  'White_shark',
#  nan,
#  "'_shark",
#  nan,
#  "Bull_shark,_'_to_'",
#  nan,
#  "Blacktip_shark,_'",
#  "Nurse_shark,_'",
#  nan,
#  "Mako_shark,_._m_[']_",
#  "Bull_shark,_'",
#  nan,
#  'White_shark',
#  'Wobbegong_shark',
#  'Grey_reef_shark,__m',
#  'Grey_reef_shark,__m',
#  "Bull_shark,_'",
#  'Tiger_shark,_._m',
#  'Shark_involvement_not_confirmed',
#  "'_to_'_shark",
#  nan,
#  nan,
#  nan,
#  'Shark_involvement_not_confirmed',
#  nan,
#  'Nurse_shark,_.-ft',
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  nan,
#  'Bronze_whaler',
#  'Sandtiger_shark',
#  nan,
#  nan,
#  nan,
#  'No_shark_involvement',
#  'No_shark_involvement',
#  nan,
#  nan,
#  'Sandtiger_shark',
#  nan,
#  "Reef_shark,_'",
#  nan,
#  'Bull_sharks_x_',
#  'Mako_shark',
#  "Tiger_shark,_'",
#  'Wobbegong_shark',
#  'Blacktip_shark',
#  '_m_shark',
#  'White_shark,__m',
#  "Silky_shark,_.'",
#  "'_shark",
#  "Bronze_whaler_shark,_'",
#  'Tiger_shark,_._m_',
#  nan,
#  'White_shark,_._m',
#  'Bull_shark',
#  nan,
#  'Galapagos_shark',
#  nan,
#  nan,
#  "Spinner_shark,_'",
#  'Bull_shark,_._to_._m',
#  'Shark_involvement_not_confirmed',
#  nan,
#  "'_to_'_shark",
#  nan,
#  nan,
#  nan,
#  'White_shark,__to_.m_',
#  "'_shark",
#  "Spinner_shark,_'",
#  nan,
#  'No_shark_involvement',
#  "Tiger_shark,_'",
#  'Hammerhead_sp.',
#  nan,
#  "Tiger_shark,_'_",
#  nan,
#  nan,
#  nan,
#  "'_to_'_shark",
#  "Blacktip_shark,_'_to_'",
#  "Blacktip_shark,_'_to_'",
#  nan,
#  "White_shark,_'",
#  'juvenile_shark',
#  "Tiger_shark,_'",
#  "'_shark",
#  nan,
#  'Hammerhead_shark',
#  nan,
#  nan,
#  "'_shark",
#  "White_shark,_'_to_'",
#  'Hammerhead_shark.',
#  'White_shark,_._m',
#  "'_shark?",
#  'small_shark',
#  'Tiger_shark',
#  "White_shark,_'_to_'",
#  "White_shark,_'_to_'_",
#  'Shark_involvement_not_confirmed',
#  nan,
#  "'_shark",
#  "'_shark",
#  "White_shark,_'",
#  'Shark_involvement_not_confirmed',
#  "Hammerhead_shark._'_to_'",
#  'White_shark',
#  nan,
#  nan,
#  "Blacktip_or_spinner_shark,_'",
#  "Thought_to_involve_a_'_to_'_shark,_but_shark_involvement_not_confirmed",
#  'White_shark,_._to_._m',
#  'Mako_shark,_-lb',
#  'Bronze_whaler_shark,_.m',
#  'Bull_shark,_m',
#  'White_shark',
#  "White_shark,_'",
#  'Shark_involvement_not_cofirmed',
#  'No_shark_involvement',
#  "'_shark",
#  nan,
#  'White_shark',
#  'White_shark',
#  "'_to_'_shark",
#  nan,
#  "'_to_'_shark",
#  'Bull_shark',
#  'White_shark',
#  'Shark_involvement_not_confirmed',
#  'White_shark,_m_to__m',
#  "'_shark",
#  'Wobbegong_shark',
#  nan,
#  'Sandtiger_shark',
#  'White_shark',
#  'small_shark',
#  nan,
#  nan,
#  'Bull_shark',
#  'Bull_shark',
#  'Mako_shark',
#  "'_shark",
#  "Bull_shark,_'",
#  'small_nurse_shark',
#  'Bull_shark,_._m',
#  nan,
#  nan,
#  'm_to_._m_shark',
#  nan,
#  "'_shark",
#  "'_shark",
#  'Bull_shark,_._m',
#  nan,
#  'White_shark',
#  'White_shark,_._m',
#  nan,
#  '-_to_-foot_shark',
#  'White_shark,__m',
#  'White_shark,__m',
#  'Blue_shark,__to__feet',
#  'Bull_shark',
#  nan,
#  'Bull_shark',
#  'Shark_involvement_not_cofirmed',
#  'No_shark_involvement',
#  'White_shark,__m',
#  'Mako_shark',
#  'Tiger_shark,__to__feet',
#  'Blacktip_shark',
#  nan,
#  nan,
#  'Blacktip_Reef_shark_',
#  'White_shark',
#  'Tiger_shark,_._m',
#  '._to__m_shark',
#  '_m_to___m_shark',
#  '._m_shark',
#  'Bull_shark,_._m',
#  "'_shark",
#  nan,
#  nan,
#  'White_shark',
#  'Shark_involvement_not_confirmed',
#  '_m_shark',
#  '._m_shark',
#  'No_shark_involvement',
#  'White_shark_or_oceanic_whitetip_shark',
#  'Raggedtooth_shark,_._m',
#  '"A_small_shark"',
#  '_m_shark',
#  'White_shark,__to__m',
#  'Shark_involvement_prior_to_death_still_to_be_determined',
#  'Shark_involvement_not_confirmed_&_highly_unlikely',
#  "White_shark,_'_to_'",
#  '._m_shark',
#  'Goblin_shark',
#  'Tiger_shark',
#  nan,
#  nan,
#  nan,
#  'White_shark',
#  'White_shark',
#  "'_shark",
#  '._m_shark',
#  nan,
#  nan,
#  "Tiger_shark,_'",
#  nan,
#  'Tiger_shark',
#  nan,
#  nan,
#  "'_to_'_shark",
#  '_m_shark',
#  "Bull_shark,_'_to_'",
#  nan,
#  nan,
#  'Blacktip_shark',
#  nan,
#  'Blacktip_shark',
#  "White_shark,_'_to_'",
#  'White_shark',
#  "'_to_'_shark",
#  '_white_shark:_\'_&_""',
#  nan,
#  'Blacktip_shark',
#  'No_shark_involvement',
#  "'_shark",
#  'Bull_shark',
#  "White_shark,_'_to_'",
#  "'_to_'_shark",
#  nan,
#  'Spinner_shark',
#  'Spinner_shark_or_blacktip_shark',
#  'Shark_involvement_not_confirmed',
#  nan,
#  'small_shark',
#  "'_to_'_shark",
#  nan,
#  "Bull_shark,_.'_",
#  "'_shark",
#  'reef_shark',
#  "_Bull_shark,_'",
#  nan,
#  "Bull_shark,_'_to_'",
#  nan,
#  "_Bull_shark,_'",
#  "'_tp_'_shark",
#  nan,
#  nan,
#  nan,
#  'White_shark',
#  'Shark_involvement_not_confirmed',
#  'Possibly_juvenile_tiger_shark',
#  '._metre_shark',
#  nan,
#  'Angel_shark',
#  "'_to_'_shark",
#  "'_shark",
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  "_White_shark,_'_",
#  nan,
#  "'_to_'_shark",
#  "Oceanic_whitetip_shark'",
#  "Caribbean_reef_shark,_'_to_'",
#  nan,
#  nan,
#  '_Lemon_shark,_._m',
#  nan,
#  "_Sandbar_shark,_'_to_'",
#  'Bronze_whaler_shark,_.m',
#  nan,
#  nan,
#  'Bull_shark',
#  nan,
#  'Blacktip_Reef_shark_',
#  '_Bull_shark,_.m_',
#  'm_shark',
#  '_Tawney_nurse_shark,_m',
#  nan,
#  "_white_shark,_'_",
#  nan,
#  'Shark_involvement_not_confirmed',
#  'No_shark_involvement',
#  "'_to_'_shark",
#  'Cow_shark',
#  "'_shark",
#  'reef_shark?',
#  nan,
#  nan,
#  'White_shark',
#  '_Raggedtooth_shark,_m',
#  nan,
#  nan,
#  '_m_to__m_white_shark',
#  'Shark_involvement_prior_to_death_not_confirmed',
#  '_m_shark',
#  "'_to_'_shark",
#  nan,
#  nan,
#  nan,
#  'No_shark_involvement',
#  'Wobbegong_shark',
#  'Invalid',
#  'Blacktip_or_spinner_shark?',
#  'Blacktip_reef_shark_',
#  nan,
#  nan,
#  nan,
#  '-gill_shark?',
#  'm_shark',
#  '-gill_shark',
#  nan,
#  'Oceanic_whitetip_shark',
#  'White_shark,__m',
#  'Reported_to_involve_a_bull_shark',
#  'White_shark,_m_',
#  nan,
#  "Tiger_shark,_'_to_'",
#  "'_to_'_shark",
#  '_Wobbegong_shark,_._to_.m_',
#  nan,
#  'Tiger_shark,_m_',
#  nan,
#  'Thought_to_involve_a_white_shark',
#  "White_shark,__'",
#  'Reported_to_involve_a_white_shark',
#  nan,
#  nan,
#  nan,
#  'Tiger_shark',
#  'Blacktip_reef_shark,_m',
#  'Thought_to_involve_a_bull_shark',
#  'Reported_to_involve_a__m_white_shark',
#  'Wobbegong_shark',
#  "Whitetip_reef_shark,_'_to_'",
#  'Tiger_shark',
#  'Nurse_shark?',
#  'White_shark',
#  'White_shark',
#  "White_shark,_'_to_'",
#  'Small_bull_shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull_shark',
#  "'_shark",
#  nan,
#  "'_shark",
#  "'_shark",
#  nan,
#  'Nurse_shark',
#  nan,
#  "'_shark",
#  'Blacktip_shark',
#  'Salmon_shark',
#  'No_shark_involvement',
#  "Mako_shark,_'",
#  nan,
#  nan,
#  nan,
#  'White_shark',
#  'Tiger_shark?',
#  nan,
#  "Bull_shark,_'",
#  'Blacktip_shark',
#  "Bull_shark,_'_to_'",
#  nan,
#  nan,
#  "'_shark",
#  nan,
#  "Tiger_shark,_'_to_'_",
#  'Nurse_shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  'Shark_involvement_prior_to_death_not_confirmed',
#  'White_shark',
#  "Possibly_a_Bull_shark,_'",
#  "'_to_'_shark",
#  "Tiger_shark,_'",
#  nan,
#  nan,
#  nan,
#  "'_to_'_shark",
#  "Lemon_shark,_'",
#  "'_shark",
#  'Galapagos_shark',
#  nan,
#  nan,
#  nan,
#  'Galapagos_shark',
#  'Invalid',
#  'Bull_shark',
#  'a_small_shark',
#  'Wobbegong,_m',
#  'Tiger_shark',
#  'Grey_nurse_shark,_m',
#  "'_shark",
#  'Blue_shark',
#  'Bull_shark',
#  nan,
#  'Possibly_a_blacktip_reef_shark',
#  nan,
#  'shark_involvement_not_confirmed',
#  "'_shark",
#  'No_shark_involvement',
#  nan,
#  'Nurse_shark',
#  nan,
#  'Raggedtooth_shark,_._m',
#  nan,
#  'Tiger_shark,_._m',
#  'Bronze_whaler_shark,_.m',
#  '"small_sharks"',
#  nan,
#  'White_shark,_m',
#  'reef_shark?',
#  'reef_shark?',
#  "Blacktip_shark,_'_to_'",
#  'Lemon_shark',
#  nan,
#  'White_shark,_m',
#  nan,
#  nan,
#  "Tiger_shark,_'",
#  'Bronze_whaler_shark,_m',
#  nan,
#  nan,
#  '._m_shark',
#  'Bull_shark,_m_',
#  'Tiger_shark',
#  "Tiger_shark,_'",
#  "'_shark",
#  'Sandtiger_shark',
#  'Seven-gill_shark',
#  "Tiger_shark,_'",
#  'No_shark_involvement',
#  '._m_shark',
#  "'_to_'_shark",
#  "Tiger_shark,_'",
#  "Tiger_shark,_'",
#  'White_shark',
#  "Tiger_shark,_'_to_'_",
#  "White_shark,_'_to_'_",
#  nan,
#  nan,
#  "'_to_'_shark",
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  'm_shark',
#  "'_shark",
#  "'_shark",
#  nan,
#  'Possibly_a__m_bull_shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ".'_to_'_shark",
#  "Tiger_shark,_'_to_'_",
#  ".'_to_'_shark",
#  "Porbeagle_shark,_'",
#  nan,
#  nan,
#  nan,
#  '._m_shark',
#  "Lemon_shark,_'_to_'_",
#  'Bull_shark',
#  'Lemon_shark,_.m_to_m_',
#  nan,
#  'White_shark_or_bronze_whaler',
#  nan,
#  'Thought_to_involve_a_white_shark',
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  'Salmon_shark_suspected,_but_unlikely',
#  'White_shark,_m',
#  nan,
#  nan,
#  nan,
#  "'_to_'shark",
#  "'_shark",
#  'No_shark_involvement',
#  'possibly_a_bull_shark',
#  nan,
#  'a_small_reef_shark',
#  nan,
#  nan,
#  '_m_shark',
#  'No_shark_involvement',
#  nan,
#  'Nurse_shark',
#  'small_blacktip_shark?',
#  'Shark_involvement_not_confirmed',
#  'small_blacktip_shark?',
#  'Blacktip_shark_',
#  '._m_shark',
#  'Blue_shark,_.m',
#  'White_shark,__m',
#  nan,
#  nan,
#  '"_to_"_shark',
#  'Bull_shark,_m',
#  "'_to_'_shark",
#  "Tiger_shark,_'_to_'_",
#  nan,
#  'White_shark',
#  nan,
#  'White_shark',
#  "'_shark",
#  'White_shark,__m_to_m_',
#  'White_shark,_m_',
#  "Tiger_shark,_'__",
#  'a_small_shark',
#  'White_shark,_m_',
#  nan,
#  'White_shark',
#  'Possibly_a_bull_shark',
#  "Possibly_a_'_to_'_bull_shark",
#  "'_to_'_shark",
#  "'_to_'_shark",
#  nan,
#  'Tawny_nurse_shark,_cm',
#  nan,
#  "'_shark",
#  nan,
#  nan,
#  'Spinner_shark',
#  'Grey_nurse_shark',
#  'White_shark,_m',
#  nan,
#  "'_to_'_shark",
#  'Tiger_shark,_m',
#  'Tiger_shark',
#  'Blue_shark,_-kg_blue_shark',
#  'White_shark,_._m',
#  'Thought_to_involve_a_bull_shark',
#  'White_shark',
#  '_m_shark',
#  'Allegedly_a__m_tiger_shark',
#  nan,
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  "'_to_'_shark_",
#  nan,
#  'White_shark,_.m',
#  'Shark_involvement_not_confirmed',
#  'Wobbegong_shark',
#  nan,
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  'Wobbegong_shark?',
#  "White_shark,_'_to_'",
#  nan,
#  nan,
#  nan,
#  'White_shark',
#  "'_to_'_shark",
#  'Raggedtooth_shark',
#  "White_shark,_'",
#  "White_shark,_'",
#  'Port_Jackson_shark,_m',
#  "'_shark",
#  "'_to_'_shark",
#  nan,
#  '_to_._m_shark',
#  nan,
#  nan,
#  'No_shark_involvement',
#  nan,
#  'White_shark',
#  "Bull_shark,_'",
#  nan,
#  nan,
#  nan,
#  nan,
#  "'_to_'_shark",
#  nan,
#  'Tiger_shark,_m',
#  nan,
#  'White_shark',
#  "'_shark,_possibly_a_blactip_or_spinner_shark",
#  "'_shark",
#  'Shark_involvement_prior_to_death_not_confirmed',
#  nan,
#  nan,
#  nan,
#  nan,
#  "White_shark,_>'",
#  nan,
#  "Possibly_a_'_to_'_sandtiger_shark",
#  'Shark_involvement_not_confirmed',
#  '_m_shark',
#  'Grey_reef_shark_',
#  nan,
#  "Bull_shark,_'",
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  'Shark_involvement_prior_to_death_not_confirmed',
#  nan,
#  nan,
#  'White_shark,_m_to_m',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull_shark,_m_female',
#  "Bull_shark,_'",
#  "White_shark,_'_k",
#  nan,
#  "'_shark",
#  nan,
#  nan,
#  "Oceanic_whitetip_shark,_'",
#  "Blacktip_shark,_'",
#  nan,
#  "Sevengill_shark,_'_to_'",
#  "'_to_'_shark",
#  'Blacktip_reef_shark_',
#  nan,
#  'White_shark',
#  "Tiger_shark,_'",
#  'Tiger_shark',
#  'Zambesi_shark',
#  nan,
#  '_Tiger_shark,_.m',
#  nan,
#  "Sandbar_shark,_'",
#  'Invalid',
#  nan,
#  "Bull_shark,_'",
#  'reef_shark,_.m',
#  "'_to_'_shark",
#  'possibly_a_bronze_whaler_shark',
#  '_Bull_shark,_._m',
#  nan,
#  'Blacktip_shark_pup',
#  'Bull_shark',
#  'Bull_shark,_.m',
#  nan,
#  nan,
#  '_m_to__m_shark',
#  nan,
#  nan,
#  'Bull_shark,_m',
#  '._m_shark',
#  nan,
#  'White_shark_x_',
#  '_m_shark',
#  nan,
#  nan,
#  nan,
#  "'_shark",
#  nan,
#  'Caribbean_reef_shark',
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  'White_shark',
#  "'_shark",
#  nan,
#  nan,
#  'Oceanic_whitetip_shark,_.m_',
#  nan,
#  'Mako_shark_',
#  'Mako_shark',
#  'Oceanic_whitetip_shark,_.m,_female',
#  'Oceanic_whitetip_shark,_.m,_female',
#  nan,
#  'Shark_involvement_not_confirmed',
#  nan,
#  nan,
#  nan,
#  'White_shark',
#  'White_shark',
#  nan,
#  nan,
#  nan,
#  "Porbeagle_shark,_'_",
#  nan,
#  "White_shark,_'_to_'_",
#  nan,
#  'Bull_shark,_.m_',
#  'Lemon_shark',
#  "Possibly_a_'_lemon_shark",
#  nan,
#  'White_shark',
#  nan,
#  'White_shark',
#  'm_shark',
#  "'_shark",
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Shark_involvement_prior_to_death_was_not_confirmed',
#  nan,
#  'White_shark',
#  'White_shark',
#  nan,
#  nan,
#  ...]

# %%
shark_attack['Species_'] = shark_attack['Species_'].str.replace(" ", "_")

# %%
shark_attack['Species_'] = shark_attack['Species_'].str.replace("nan", "")

# %%
shark_attack['Species_'] = shark_attack['Species_'].str.replace(r'\d', "").replace("-", "")
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_18840\2025326055.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   shark_attack['Species_'] = shark_attack['Species_'].str.replace(r'\d', "").replace("-", "")

# %%
list(shark_attack["Species_"]).count_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [404], in <cell line: 1>()
# ----> 1 list(shark_attack["Species_"]).count_values()
#
# AttributeError: 'list' object has no attribute 'count_values'

# %%
def limpia_num(values):
    months = "Lemon_shark", "White shark", "Tiger shark", "Bull shark", "Wobbegong_shark", "Blue_shark", "Mako_shark", "Goblin_shark", "Spinner_shark" 
    monthsstr = str(months)
    for i in values:
        if i == months:
            return i
        else:
            return " "

# %%
shark_attack["Species"] = str(shark_attack["Species_"].apply(limpia_num))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [410], in <cell line: 1>()
# ----> 1 shark_attack["Species"] = str(shark_attack["Species_"].apply(limpia_num))
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\core\apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\miniconda2\envs\ironhack\lib\site-packages\pandas\_libs\lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Input In [409], in limpia_num(values)
#       2 months = "Lemon_shark", "White shark", "Tiger shark", "Bull shark", "Wobbegong_shark", "Blue_shark", "Mako_shark", "Goblin_shark", "Spinner_shark"
#       3 monthsstr = str(months)
# ----> 4 for i in values:
#       5     if i == months:
#       6         return i
#
# TypeError: 'float' object is not iterable
