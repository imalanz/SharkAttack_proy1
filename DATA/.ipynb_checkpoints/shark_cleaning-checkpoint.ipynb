# %% [markdown]
# # 1. Cleaning

# %% [markdown]
# ### importing data

# %%
import pandas as pd
import numpy as np
import openpyxl
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_file = "D:\\ironhack\\proyectos\\SharkAttack_proy1\DATA\\attacks_1.csv"
shark_attack = pd.read_csv(csv_file, encoding="cp1252")

# %%
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
shark_attack.sample(3)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 11120         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 13089         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6686            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 11120  ...      NaN                    NaN  NaN          NaN  NaN
# 13089  ...      NaN                    NaN  NaN          NaN  NaN
# 6686   ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 11120           NaN           NaN            NaN         NaN         NaN
# 13089           NaN           NaN            NaN         NaN         NaN
# 6686            NaN           NaN            NaN         NaN         NaN
#
# [3 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 25723

# %%
shark_attack.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %% [markdown]
# ### Null values

# %%
shark_attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
#revisar si necesito eliminar los NaN
#puedo meterme directo a explorar la columna a ver como se ven con los NaN
#llamando el key y poniendole .isna()

# %%
#pd.isnull(shark_attack).sum() same formula
shark_attack.isna().sum()
#for NaN, un promedio de 18000NaNs en una lista de 19803
#conclucion, demasiados NaN tendre que eliminar
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
shark_attack.notnull().sum()
# Out:
# Case Number               8702
# Date                      6302
# Year                      6300
# Type                      6298
# Country                   6252
# Area                      5847
# Location                  5762
# Activity                  5758
# Name                      6092
# Sex                       5737
# Age                       3471
# Injury                    6274
# Fatal (Y/N)               5763
# Time                      2948
# Species                   3464
# Investigator or Source    6285
# pdf                       6302
# href formula              6301
# href                      6302
# Case Number.1             6302
# Case Number.2             6302
# original order            6309
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %% [markdown]
# After this filter we can see that it has tons of null data, from 25723 original rows we can see that it will let us with almos 6,000 rows. Not much information and we can clean it.

# %% [markdown]
# next step it will be to drop (errase) the rows that dont apport nothing to the data.
# If we throw the formula od dropna with the fuction "any" its not an option, every single row has even one missed cell, we will be applying the function "all"

# %%
shark_attack.dropna(how="all",inplace=True)
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 8698               NaN                             NaN          NaN
# 8699               NaN                             NaN          NaN
# 8700               NaN                             NaN          NaN
# 8701               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 8698               NaN  NaN  ...              NaN
# 8699               NaN  NaN  ...              NaN
# 8700               NaN  NaN  ...              NaN
# 8701               NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 8698                              NaN                       NaN
# 8699                              NaN                       NaN
# 8700                              NaN                       NaN
# 8701                              NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 8698                                                 NaN
# 8699                                                 NaN
# 8700                                                 NaN
# 8701                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 8698                                                 NaN           NaN
# 8699                                                 NaN           NaN
# 8700                                                 NaN           NaN
# 8701                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 8698            NaN            NaN         NaN         NaN
# 8699            NaN            NaN         NaN         NaN
# 8700            NaN            NaN         NaN         NaN
# 8701            NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [8703 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 8703

# %% [markdown]
# it let us with only 8703 rows. But we still have some missing values in the cells thats wy apears in the formula below that we still have a lot of them, probably half of the columns have NANs.

# %%
shark_attack.isna().sum()
# Out:
# Case Number                  1
# Date                      2401
# Year                      2403
# Type                      2405
# Country                   2451
# Area                      2856
# Location                  2941
# Activity                  2945
# Name                      2611
# Sex                       2966
# Age                       5232
# Injury                    2429
# Fatal (Y/N)               2940
# Time                      5755
# Species                   5239
# Investigator or Source    2418
# pdf                       2401
# href formula              2402
# href                      2401
# Case Number.1             2401
# Case Number.2             2401
# original order            2394
# Unnamed: 22               8702
# Unnamed: 23               8701
# dtype: int64

# %% [markdown]
# ### Duplicated

# %%
shark_attack.shape[0]
# Out:
# 8703

# %%
shark_attack.duplicated().sum()
# Out:
# 2392

# %% [markdown]
# This tell us that we have 2,392 raws that are duplicated and will have to be removed, otherwise it will leave us with some false information.

# %%
shark_attack.drop_duplicates(inplace=True)
shark_attack.tail(5)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6306            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6307            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6308            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 6306   ...      NaN                    NaN  NaN          NaN  NaN
# 6307   ...      NaN                    NaN  NaN          NaN  NaN
# 6308   ...      NaN                    NaN  NaN          NaN  NaN
# 6309   ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 6306            NaN           NaN         6308.0         NaN         NaN
# 6307            NaN           NaN         6309.0         NaN         NaN
# 6308            NaN           NaN         6310.0         NaN         NaN
# 6309            NaN           NaN            NaN         NaN         NaN
# 25722           NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 24 columns]

# %%
shark_attack.shape[0]
# Out:
# 6311

# %% [markdown]
# This leave us with only 6,311 rows that are not duplicated and have minimum 1 real value.
# Because I can notice that there are still some rows that looks preatty empty and the few values that could have it might not be important to us and our investigation.

# %% [markdown]
# ### General column cleaning

# %% [markdown]
# passing throw the Data frame I notice that theres some columns that are not relevant to our investigation, that doesnt apport anything of value that we could could benefit

# %%
shark_attack.sample()
# Out:
#        Case Number         Date    Year        Type Country     Area  \
# 2189  1998.05.16.c  16-May-1998  1998.0  Unprovoked     USA  Florida
#
#                        Location  Activity               Name Sex   ...  \
# 2189  Pecks Lake, Martin County  Swimming  Janelle Dickinson    F  ...
#
#                                    Species            Investigator or Source  \
# 2189  1.8 m [6'] shark, possibly a blacktip  The Stuart (FL) News, 5/17/1998
#
#                              pdf  \
# 2189  1998.05.16.c-Dickinson.pdf
#
#                                            href formula  \
# 2189  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 2189  http://sharkattackfile.net/spreadsheets/pdf_di...  1998.05.16.c
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 2189  1998.05.16.c         4114.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
shark_attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# There are some columns that makes me have some interest, in wich ones we could errase because of our lak of information for us, for example the las 2 columns 'Unnamed: 22', 'Unnamed: 23', seen the samples we could see that theres only non values and actually the tittle doesn´t give us any explanetion.
# We will erase them.

# %%
shark_attack[['Unnamed: 22', "Unnamed: 23"]].sample(5)
# Out:
#      Unnamed: 22 Unnamed: 23
# 1681         NaN         NaN
# 1351         NaN         NaN
# 1875         NaN         NaN
# 4420         NaN         NaN
# 2830         NaN         NaN

# %%
shark_attack.drop(columns =['Unnamed: 22', "Unnamed: 23"], inplace=True, axis=1)

# %%
shark_attack.sample()
# Out:
#      Case Number         Date    Year        Type Country            Area  \
# 2778  1987.05.25  25-May-1987  1987.0  Unprovoked     USA  South Carolina
#
#                         Location Activity             Name Sex   ...  \
# 2778  Myrtle Beach, Horry County      NaN  Josia McSpadden    M  ...
#
#      Fatal (Y/N) Time                         Species   \
# 2778           N  NaN  1.5 m to 1.8 m [5' to 6'] shark
#
#               Investigator or Source                            pdf  \
# 2778  Charlotte Observer, 5/28/1987   1987.05.25-JosiaMcSpadden.pdf
#
#                                            href formula  \
# 2778  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 2778  http://sharkattackfile.net/spreadsheets/pdf_di...    1987.05.25
#
#      Case Number.2 original order
# 2778    1987.05.25         3525.0
#
# [1 rows x 22 columns]

# %% [markdown]
# more research in columns: lets see if the internet links could help us with our research.

# %%
shark_attack['href formula'].sample(5)
# Out:
# 5874    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4636    http://sharkattackfile.net/spreadsheets/pdf_di...
# 848     http://sharkattackfile.net/spreadsheets/pdf_di...
# 5213    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4847    http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href formula, dtype: object

# %%
shark_attack['href'].sample(5)
# Out:
# 3996    http://sharkattackfile.net/spreadsheets/pdf_di...
# 6136    http://sharkattackfile.net/spreadsheets/pdf_di...
# 466     http://sharkattackfile.net/spreadsheets/pdf_di...
# 5592    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2321    http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href, dtype: object

# %% [markdown]
# Exploring this 2 columns 'href formula' and 'href' we can realice that they apporr some internet links, but going throw them they the pages dont exist amymore.

# %%
shark_attack['Case Number.1'].sample(5)
# Out:
# 2721      1988.07.23
# 5423    1909.04.09.R
# 5309      1916.07.07
# 5669      1893.04.15
# 957       2010.12.26
# Name: Case Number.1, dtype: object

# %% [markdown]
# other columns that dont apport anything of value are 'Case Number.1', 'Case Number.2'  we can see that the information there is actually the same and its the date of the attack that we do have it already in other columns at the beginning, and 'original order' dont aport us anything.
# we´ll pass to some more drop cleaning.
# we also dont count with any extra file from the data page like the pdf files, so we could erase thata one to.

# %%
shark_attack.drop(columns =['Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order'], inplace=True, axis=1)

# %%
shark_attack.drop(columns =['Case Number'], inplace=True, axis=1)

# %%
shark_attack.sample()
# Out:
#             Date    Year        Type       Country                   Area  \
# 699  03-Mar-2013  2013.0  Unprovoked  SOUTH AFRICA  Eastern Cape Province
#
#             Location  Activity             Name Sex  Age  \
# 699  Port St. John's  Swimming  Fundile Nogumla    M  39
#
#                        Injury Fatal (Y/N) Time Species
# 699  Injuries to arms & hands           N  NaN      NaN

# %%
shark_attack.columns = [i.capitalize().replace(" ", "_") for i in list(shark_attack.columns)]
shark_attack.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex_', 'Age', 'Injury', 'Fatal_(y/n)', 'Time', 'Species_'],
#       dtype='object')

# %%
shark_attack.dropna(how="all",inplace=True)
shark_attack.tail(5)
# Out:
#              Date  Year        Type             Country               Area  \
# 6297  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 6300    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 6301    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 6297                          Roebuck Bay        Diving
# 6298                                  NaN  Pearl diving
# 6299                       Ocracoke Inlet      Swimming
# 6300                 Panama Bay 8ºN, 79ºW           NaN
# 6301  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex_  Age  \
# 6297                   male    M  NaN
# 6298                  Ahmun    M  NaN
# 6299  Coast Guard personnel    M  NaN
# 6300        Jules Patterson    M  NaN
# 6301                   male    M   15
#
#                                                  Injury Fatal_(y/n) Time  \
# 6297                                              FATAL           Y  NaN
# 6298                                              FATAL           Y  NaN
# 6299                                              FATAL           Y  NaN
# 6300                                              FATAL           Y  NaN
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y  NaN
#
#      Species_
# 6297      NaN
# 6298      NaN
# 6299      NaN
# 6300      NaN
# 6301      NaN

# %%
#for i in list(shark_attack.columns):
#    for e in range(len(i)):
#        if e == "_":
#            list(shark_attack.columns).append(e.replace("_", ""))
#shark_attack.columns

# %%
#for i in list(shark_attack.columns):
#    for e in len(i)if i[-1] == " ":
#        list(shark_attack.columns).append(i.replace(" ", ""))
#shark_attack.columns

# %%
shark_attack.head()
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex_  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal_(y/n)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species_
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# 3            NaN        2 m shark
# 4            NaN  Tiger shark, 3m

# %% [markdown]
# For this analysis Im interested in some of the columns, I will need the 'Date', 'Country', 'Injury', 'Fatal_(y/n)', 'Time' and 'Species_', I will have to go throw them and cleaning them more deep so we would not have any bias.

# %% [markdown]
# ### Date column

# %% [markdown]
# For "Date" i will need to clean it and have it more organized, will nedd to make all data the same information, so i can calculate it the same way. will need to separate tin different columns the day, in another de month and in another the year, that we already have it.
# in this case I will need to create 2 more columns or just one and modified the others.

# %%
shark_attack['Date'].value_counts()
# Out:
# 1957                          11
# 1942                           9
# 1956                           8
# 1958                           7
# 1950                           7
#                               ..
# 01-Dec-1994                    1
# Reported      10-Dec-1994      1
# 11-Dec-1994                    1
# 13-Dec-1994                    1
# 1845-1853                      1
# Name: Date, Length: 5433, dtype: int64

# %%
shark_attack.dtypes
# Out:
# Date            object
# Year           float64
# Type            object
# Country         object
# Area            object
# Location        object
# Activity        object
# Name            object
# Sex_            object
# Age             object
# Injury          object
# Fatal_(y/n)     object
# Time            object
# Species_        object
# dtype: object

# %% [markdown]
# Se hizo el cambio de type de Date, aunque ya estaba como objeto, no me reconocia algunos cambios por que el error me aventaba que eran floats.

# %% [markdown]
# Crear nueva columna

# %%
shark_attack["Months"] = shark_attack["Date"]

# %% [markdown]
# Create alll elements of column Months to strings.

# %%
for i in shark_attack["Months"]:
    i = str(i)

# %%
shark_attack["Months"] = shark_attack["Months"].astype("str")

# %%
shark_attack["Months"].dtype
# Out:
# dtype('O')

# %% [markdown]
# Filter and clean objects to make more readable the strings

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace(r'\d', "").replace("-", "")
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_12192\3293145955.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   shark_attack['Months'] = shark_attack['Months'].str.replace(r'\d', "").replace("-", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("-", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("or", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("Reported", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("Repted", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("Late", "").replace("Early", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace(" ", "")

# %%
shark_attack['Months'] = shark_attack['Months'].str.replace("Mid", "")

# %%
shark_attack['Months'].value_counts()
# Out:
# Jul                                            650
# Aug                                            597
# Sep                                            547
# Jan                                            513
# Jun                                            491
#                                               ...
# SometimebetweenApr&Nov                           1
# Between&Dec                                      1
# Mar"Bittenlastweekend                            1
# MarApr                                           1
# Nodate(daysafterprecedingincident)&pritoJul      1
# Name: Months, Length: 114, dtype: int64

# %% [markdown]
# Creating a loop to choose me the only strings that I want, after it is clean it works better.
# First have to make the column a list so I can work and iterate it.

# %%
Months_lst = list(shark_attack['Months'])

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
x = []
for i in Months_lst:
    if i in months:
        x.append(i)
    else:
        x.append("NaN")

# %% [markdown]
# Change the result that is in type list to a Panda Serie so I can add it to the data frame, that is what i whant.

# %%
mySeries = pd.Series(x)

# %%
shark_attack["Months"] = mySeries

# %%
list(shark_attack['Months'])
# Out:
# ['Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'NaN',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Jun',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'NaN',
#  'NaN',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'NaN',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'NaN',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  'Aug',
#  ...]

# %%
sns.countplot(x = shark_attack.Months);

# %%
shark_attack.sample(50)
# Out:
#                       Date    Year          Type           Country  \
# 5052           16-Jan-1930  1930.0    Unprovoked      SOUTH AFRICA
# 2111           05-Aug-1999  1999.0    Unprovoked           BAHAMAS
# 3842           21-Jan-1962  1962.0      Provoked         AUSTRALIA
# 2248           15-Jun-1997  1997.0    Unprovoked              FIJI
# 1117           21-Jun-2009  2009.0       Invalid               USA
# 5736  Reported 22-Dec-1887  1887.0    Unprovoked          HONDURAS
# 1211           30-Aug-2008  2008.0    Unprovoked         AUSTRALIA
# 5323  Reported 06-Jul-1915  1915.0    Unprovoked            MEXICO
# 2132           14-Mar-1999  1999.0      Provoked       NEW ZEALAND
# 2564           09-Feb-1992  1992.0       Invalid         AUSTRALIA
# 3364           11-Apr-1971  1971.0    Unprovoked      SOUTH AFRICA
# 881            17-Aug-2011  2011.0    Unprovoked               USA
# 5305           12-Jul-1916  1916.0    Unprovoked               USA
# 4931           22-Oct-1934  1934.0    Unprovoked         AUSTRALIA
# 504               Sep-2014  2014.0    Unprovoked             SPAIN
# 3118           27-Jul-1978  1978.0  Sea Disaster               USA
# 2214           09-Nov-1997  1997.0    Unprovoked         AUSTRALIA
# 3803         Late Aug-1962  1962.0    Unprovoked             ITALY
# 2163           22-Sep-1998  1998.0    Unprovoked               USA
# 3923           01-Feb-1961  1961.0    Unprovoked      SOUTH AFRICA
# 3133           31-Dec-1977  1977.0  Sea Disaster               USA
# 549            01-Jun-2014  2014.0    Unprovoked         AUSTRALIA
# 3402           23-Jan-1970  1970.0    Unprovoked        MOZAMBIQUE
# 649            28-Jul-2013  2013.0    Unprovoked           BAHAMAS
# 1731           06-Oct-2003  2003.0       Invalid               USA
# 3301           13-Jun-1973  1973.0    Unprovoked         HONG KONG
# 3543           26-Dec-1966  1966.0    Unprovoked         SINGAPORE
# 4991              May 1932  1932.0    Unprovoked         AUSTRALIA
# 3447           25-Dec-1968  1968.0    Unprovoked       NEW ZEALAND
# 419            29-May-2015  2015.0    Unprovoked               USA
# 1872           01-Apr-2002  2002.0    Unprovoked               USA
# 191            24-Dec-2016  2016.0    Unprovoked         AUSTRALIA
# 6075           09-Sep-1837  1837.0    Unprovoked               USA
# 5352           21-Sep-1913  1913.0    Unprovoked               USA
# 1579           13-Jun-2005  2005.0    Unprovoked       SOUTH KOREA
# 4319           04-Dec-1954  1954.0    Unprovoked      SOUTH AFRICA
# 3238           23-Feb-1975  1975.0    Unprovoked      SOUTH AFRICA
# 2283           02-Sep-1996  1996.0    Unprovoked               USA
# 2829           01-Feb-1986  1986.0    Unprovoked         AUSTRALIA
# 375            20-Aug-2015  2015.0    Unprovoked               USA
# 5955              Apr-1863  1863.0    Unprovoked         AUSTRALIA
# 3363  Reported 16-Apr-1971  1971.0    Unprovoked             KENYA
# 5281                  1918  1918.0    Unprovoked         AUSTRALIA
# 6084  Reported 15-Jul-1834  1834.0    Unprovoked  FRENCH POLYNESIA
# 2797           06-Dec-1986  1986.0    Unprovoked               USA
# 355            26-Sep-2015  2015.0    Unprovoked         AUSTRALIA
# 165            02-Apr-2017  2017.0    Unprovoked         AUSTRALIA
# 5974                  1862  1862.0    Unprovoked             JAPAN
# 4472           25-Jun-1950  1950.0    Unprovoked               USA
# 672            27-May-2013  2013.0    Unprovoked               USA
#
#                              Area  \
# 5052        Western Cape Province
# 2111                Abaco Islands
# 3842              New South Wales
# 2248                      Taveuni
# 1117                   California
# 5736                       Cortés
# 1211              New South Wales
# 5323                          NaN
# 2132                          NaN
# 2564                     Tasmania
# 3364        Western Cape Province
# 881                North Carolina
# 5305                   New Jersey
# 4931                Torres Strait
# 504                     Catalonia
# 3118               South Carolina
# 2214            Western Australia
# 3803               Tyrrhenian Sea
# 2163                      Florida
# 3923        Eastern Cape Province
# 3133                       Hawaii
# 549               New South Wales
# 3402                Limpopo River
# 649                 Exuma Islands
# 1731                      Florida
# 3301                          NaN
# 3543                          NaN
# 4991                Torres Strait
# 3447                 South Island
# 419                       Florida
# 1872                      Florida
# 191             Western Australia
# 6075               South Carolina
# 5352                      Florida
# 1579  South Ch'ungch'ong Province
# 4319                KwaZulu-Natal
# 3238                KwaZulu-Natal
# 2283                      Florida
# 2829                     Victoria
# 375                South Carolina
# 5955                   Queensland
# 3363               Coast Province
# 5281                   Queensland
# 6084              Society Islands
# 2797                   California
# 355                    Queensland
# 165                    Queensland
# 5974                Bonin Islands
# 4472                     New York
# 672                       Florida
#
#                                                Location  \
# 5052                                Melkbaai, False Bay
# 2111                                          Grand Cay
# 3842                                           Cronulla
# 2248  Off a small island 5 km from Garden Island Resort
# 1117                Shell Beach, San Luis Obispo County
# 5736                Off Puerto Cortez (Caribbean coast)
# 1211                            Tallow Beach, Byron Bay
# 5323                                    Santa Maria Bar
# 2132                                                NaN
# 2564                 Clifton Beach, southwest of Hobart
# 3364                                        Buffels Bay
# 881                      Kure Beach, New Hanover County
# 5305  Matawan Creek, 10 miles from the sea, Monmouth...
# 4931                                      Warrior Reefs
# 504                                               Salou
# 3118                                                NaN
# 2214                                             Albany
# 3803                             Circeo, Secca del Faro
# 2163                   New Smyrna Beach, Volusia County
# 3923                                             Nahoon
# 3133                        2 miles off Keahole Airport
# 549                            Seven Mile Beach, Gerroa
# 3402                              Gijana, 150 km inland
# 649                                         Compass Cay
# 1731                                        Palm Beach?
# 3301                                                NaN
# 3543                                          Singapore
# 4991                                    Thursday Island
# 3447                           St. Clair Beach, Dunedin
# 419                        Cocoa Beach, Brevard  County
# 1872              Lauderdale-By-The-Sea, Broward County
# 191                    Bundegi Sanctuary Zone, Ningaloo
# 6075  Magwoods Wharf, Charleston Harbor, Charleston ...
# 5352                 West Palm Beach, Palm Beach County
# 1579                                Dando/Kaeui Island
# 4319                           Rocket Hut Beach, Durban
# 3238                          Inyoni Rocks, Amanzimtoti
# 2283                       Behune Beach, Volusia County
# 2829                                      Jan Juc Beach
# 375                   Murrells Inlet, Georgetown County
# 5955                                    Caloundra Heads
# 3363                                             Watamu
# 5281                                        Near Cairns
# 6084                                             Tahiti
# 2797  Monastery Beach, Carmel River State Park, Mont...
# 355                      Russel Island, Frankland Group
# 165                                         Moreton Bay
# 5974                                                NaN
# 4472                      Beach 103rd Street, Rockaway
# 672                        Ormond Beach, Volusia County
#
#                                                Activity  \
# 5052                                           Swimming
# 2111                       Spearfishing & holding catch
# 3842                                       Spearfishing
# 2248                                         Snorkeling
# 1117                                            Surfing
# 5736                Fell oveboard from steamer Wanderer
# 1211                                            Surfing
# 5323                                             Wading
# 2132                                            Fishing
# 2564                                            Surfing
# 3364                                           Swimming
# 881                                              Wading
# 5305         Swimming (recovering remains of Stilwell)
# 4931           Freediving for trochus shell (submerged)
# 504                        Playing with an air mattress
# 3118  Explosion destroyed 28' boat, survivors in the...
# 2214          Scuba diving (submerged riding a scooter)
# 3803                                             Diving
# 2163                                            Surfing
# 3923                                           Swimming
# 3133  Swimming, after single-engine aircraft went do...
# 549                                             Surfing
# 3402                                           Swimming
# 649                                       Cleaning fish
# 1731               Swimming to shore from boat or kayak
# 3301                                   Freedom Swimming
# 3543                                             Wading
# 4991                                       Pearl diving
# 3447                                            Surfing
# 419                                            Standing
# 1872                                  Swimming / Wading
# 191                                          Snorkeling
# 6075                                            Bathing
# 5352                                                NaN
# 1579                                             Diving
# 4319                                           Swimming
# 3238                                            Surfing
# 2283                                           Standing
# 2829                                            Surfing
# 375                                             Surfing
# 5955                                   Launching a boat
# 3363                                           Swimming
# 5281                                             Diving
# 6084                                           Swimming
# 2797            Free diving  & spearfishing (submerged)
# 355                                          Snorkeling
# 165                                            Kakaying
# 5974     Boat of a Hawaiian brig was stove in by  whale
# 4472                                          Swimming
# 672                                            Swimming
#
#                                        Name Sex_  Age  \
# 5052                           Servy LeRoux    M   23
# 2111                             Kevin King    M   35
# 3842                           Robert Smith    M   19
# 2248                             Liz Rogers    F   47
# 1117                                   male    M   26
# 5736                          Carl Luhudahl    M   33
# 1211                             Ben Vining    M   29
# 5323                          J.W. McDonald    M  NaN
# 2132                              Mr. Spain    M   28
# 2564                      Wayne Fitzpatrick    M   19
# 3364                             Theo Klein    M  >50
# 881                           Trang Aronian    F  20s
# 5305                         Stanley Fisher    M   24
# 4931  David Younger, Torres Strait Islander    M  NaN
# 504                                    male    M   16
# 3118                              Sam Boger    M   39
# 2214                           Kevin Hulkes    M   42
# 3803                      Dante Matacchione    M  NaN
# 2163                        Jade Blackstock    M   18
# 3923                     Geoffrey Zimmerman    M   14
# 3133                         Harold Corbett    M   49
# 549                               Bob Smith    M  NaN
# 3402                         Mabua Mogadura    M   12
# 649                                    male    M   64
# 1731                                   male    M  NaN
# 3301                               2 youths    M  NaN
# 3543                            Hussain Ali    M   39
# 4991                  Nishi, Japanese diver    M  NaN
# 3447                            Gary Barton    M   17
# 419                           Ashlyn Gilpin    F   14
# 1872                            Matthew May    M   29
# 191                                  female    F  NaN
# 6075          a young boy from the Plymouth    M  NaN
# 5352                                   male    M  NaN
# 1579                                    Lee    F   38
# 4319                           Graham Scott    M   16
# 3238                  Bretton Russell Jones    M   16
# 2283           William (or Richard) Schwall    M    5
# 2829                            David Adams    M   29
# 375                            Dylan Peyton    M   15
# 5955                         Mr. Barnsfield    M  NaN
# 3363                       a German tourist    M   16
# 5281                              Iona Asai    M  NaN
# 6084                      Kaugatava Orurutm    F  NaN
# 2797                            Frank Gallo    M   27
# 355                                  female    F    7
# 165                           Gavin Kleiden    M   39
# 5974                              boat crew    M  NaN
# 4472                         Joseph Salengo    M   16
# 672                        Kyle Kirkpatrick    M   11
#
#                                                  Injury Fatal_(y/n)  \
# 5052                                 Torso & arm bitten           N
# 2111                                   Right arm bitten           N
# 3842  Suffered from shock & immersion after being dr...           N
# 2248    Bitten on inner thigh, leg surgically amputated           N
# 1117                            Puncture wounds to foot         NaN
# 5736                                              FATAL           Y
# 1211           No injury, bumped off board by the shark           N
# 5323                                              FATAL           Y
# 2132               Right thigh bitten PROVOKED INCIDENT           N
# 2564  No injury, shark allegedly took his surfboard ...         NaN
# 3364                             FATAL, multiple bites            Y
# 881                                 Lacerations to foot           N
# 5305                               FATAL, thigh bitten            Y
# 4931  FATAL, forearm lacerated & surgically amputate...           Y
# 504                           Lacerations to right hand           N
# 3118  No injury, his foot was bumped by a shark biti...           N
# 2214      Left arm lacerated when shark grabbed scooter           N
# 3803                                          No injury           N
# 2163                                 Left arm lacerated           N
# 3923  FATAL, multiple injuries to both legs, feet & ...           Y
# 3133                                     Feet lacerated           N
# 549     Lacerations & puncture wounds to ankle and foot           N
# 3402                          Arm severed, thigh bitten           N
# 649                                 Bitten on left hand           N
# 1731  Fatal, drowning or scavenging.  Two hours late...           Y
# 3301  One man was killed by a shark, the other was i...           N
# 3543                                       Thigh bitten           N
# 4991                Severe injury to forearm near elbow           N
# 3447  Hit in face by shark, arm abraded, surfboard b...           N
# 419                                    Left foot bitten           N
# 1872                              Upper left arm bitten           N
# 191                                      Buttock bitten           N
# 6075                                 Right foot bittten           N
# 5352                        Major injuries but survived           N
# 1579                                        Knee bitten           N
# 4319                       Shallow lacerations on torso           N
# 3238                                       Foot severed           N
# 2283                                  Right foot bitten           N
# 2829       No injury, knocked into water & board bitten           N
# 375                 Injuries to left calf, arm and hand           N
# 5955                                              FATAL           Y
# 3363                                  Right foot bitten           N
# 5281                                           Survived           N
# 6084                                              FATAL           Y
# 2797  Punctured lung, lacerations to shoulder, face,...           N
# 355                                   Laceration to leg           N
# 165             No injury, shark bit off stern of kayak           N
# 5974                                              FATAL           Y
# 4472      Gashes & lacerations on legs, foot lacerated.           N
# 672                                   Right foot bitten           N
#
#            Time                                           Species_ Months
# 5052      17h30  White shark, 4.5 m [14'9"], identity confirmed...    Jan
# 2111      17h00     2.7 m [9']  bull shark or Caribbean reef shark    Aug
# 3842        NaN                    Bronze whaler shark,  3m [10']     Jan
# 2248      14h30                            Tiger shark, 2.7m  [9']    Jun
# 1117        NaN                    Shark involvement not confirmed    Jun
# 5736        NaN                                                NaN    Dec
# 1211        NaN                                                NaN    Aug
# 5323        NaN                                                NaN    Jul
# 2132        NaN                          Mako shark, 1.3 m gaffed     Mar
# 2564      19h30                              Questionable incident    Feb
# 3364      11h30  White shark according to tooth pattern and wit...    Apr
# 881       17h00                Possibly a 5' to 6' sandtiger shark    Aug
# 5305        NaN                                    3 m [10'] shark    Jul
# 4931        NaN                                                NaN    Oct
# 504         NaN                                                NaN    Sep
# 3118        NaN                                                NaN    Jul
# 2214    Morning                                        White shark    Nov
# 3803        NaN                                        White shark    Aug
# 2163      15h35                                                NaN    Sep
# 3923      14h50                            2.1 m [7'], 90-kg shark    Feb
# 3133      Night                                                NaN    Dec
# 549     Morning                                                NaN    Jun
# 3402        NaN                                      Zambesi shark    Jan
# 649       16h45                                        Nurse shark    Jul
# 1731         --  Shark involvement prior to death was not confi...    Oct
# 3301        NaN                                                NaN    Jun
# 3543  Afternoon                                                NaN    Dec
# 4991        NaN                                                NaN    May
# 3447      17h45                                        White shark    Dec
# 419       15h00                                                NaN    May
# 1872      11h30                                   0.9 m [3'] shark    Apr
# 191     Morning                                      a small shark    Dec
# 6075        NaN                                                NaN    Sep
# 5352        NaN      Said to involve a 2.4 m [8'] hammerhead shark    Sep
# 1579        NaN                              3 m [10'] white shark    Jun
# 4319      11h00                                                NaN    Dec
# 3238      10h55                                   1.5 m [5'] shark    Feb
# 2283      18h05                                                NaN    Sep
# 2829      06j00                        Bronze whaler shark, 3.5 m     Feb
# 375       12h30                                           4' shark    Aug
# 5955        NaN                                           2 sharks    Apr
# 3363        NaN                                   2 m [6'9"] shark    Apr
# 5281        NaN                                                NaN    NaN
# 6084        NaN             Reported to involve a hammerhead shark    Jul
# 2797      10h00              5 m to 6 m [16.5' to 20'] white shark    Dec
# 355   Afternoon                                                NaN    Sep
# 165   Afternoon                                                NaN    Apr
# 5974        NaN                                                NaN    NaN
# 4472        NaN                                       "sand shark"    Jun
# 672   Afternoon                                                NaN    May

# %%
#condition_1 = shark_attack["Date"] == "Jan"
#condition_2 = shark_attack["Date"] == "Feb"
#condition_3 = shark_attack["Date"] == "Mar"
#condition_4 = shark_attack["Date"] == "Apr"
#condition_5 = shark_attack["Date"] == "May"
#condition_6 = shark_attack["Date"] == "Jun"
#condition_7 = shark_attack["Date"] == "Jul"
#condition_8 = shark_attack["Date"] == "Aug"
#condition_9 = shark_attack["Date"] == "Sep"
#condition_10 = shark_attack["Date"] == "Oct"
#condition_11 = shark_attack["Date"] == "Nov"
#condition_12 = shark_attack["Date"] == "Dec"

# %%
#condis = shark_attack.loc[(shark_attack["Date"] == "Jan") & (shark_attack["Date"] == "Apr")]
#condis.head()

# %%
shark_attack.sample()
# Out:
#       Date    Year        Type    Country        Area     Location  \
# 6010  1853  1853.0  Unprovoked  AUSTRALIA  Queensland  Moreton Bay
#
#                  Activity                 Name Sex_  Age Injury Fatal_(y/n)  \
# 6010  Fell into the water  James Hexton, pilot    M  NaN  FATAL           Y
#
#      Time Species_ Months
# 6010  NaN      NaN    NaN

# %%
shark_attack["Months"].value_counts()
# Out:
# Jul    650
# NaN    598
# Aug    597
# Sep    547
# Jan    513
# Jun    491
# Apr    450
# Oct    441
# Dec    435
# Mar    406
# Nov    403
# May    392
# Feb    379
# Name: Months, dtype: int64

# %% [markdown]
# ### Species column

# %%
shark_attack['Species_'].value_counts().sample(5)
# Out:
# 4' shark                                                40
# Reef shark, 5'                                           1
# White shark, 4.3 m [14'], (tooth fragment recovered)     1
# 1.5 m [5'] "whaler shark"                                1
# Possibly a broadnose 7-gill shark                        1
# Name: Species_, dtype: int64

# %% [markdown]
# Create a new copy of the column Species_

# %%
shark_attack["Species"] = shark_attack["Species_"]

# %% [markdown]
# Create all the elements inside the column strings.

# %%
for i in shark_attack["Species"]:
    i = str(i)

# %%
shark_attack["Species"] = shark_attack["Species"].astype("str")

# %%
shark_attack["Species"].dtype
# Out:
# dtype('O')

# %%
list(shark_attack["Species"])
# Out:
# ['White shark',
#  'nan',
#  'nan',
#  '2 m shark',
#  'Tiger shark, 3m',
#  'nan',
#  'Tiger shark',
#  "Lemon shark, 3'",
#  "Bull shark, 6'",
#  'nan',
#  'Grey reef shark',
#  'nan',
#  'nan',
#  'Invalid incident',
#  'Tawny nurse shark, 2m',
#  'nan',
#  'Shark involvement not confirmed',
#  'nan',
#  'Tiger shark',
#  'nan',
#  'Questionable',
#  '3 m shark',
#  'White shark, 3.5 m',
#  'Tiger shark',
#  'White shark, 2.5 m',
#  "6' shark",
#  'Juvenile bull shark',
#  'nan',
#  'nan',
#  'nan',
#  'Tiger shark',
#  'Shark involvement not confirmed',
#  '2 m shark',
#  'Bull shark',
#  'White shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Blacktip shark',
#  'Juvenile white shark,  2.7 to 3.2 m',
#  'nan',
#  'Bull shark, 2 m',
#  'Possibly a wobbegong',
#  'Injury believed caused by an eel, not a shark',
#  'Galapagos shark?',
#  '2m shark',
#  'Bull shark',
#  'Bull shark, 3 m ',
#  'Grey reef shark. 2 m',
#  'White shark, 3.5 m',
#  'small shark',
#  'Wobbegong shark?',
#  'Tiger shark',
#  'nan',
#  'Juvenile nurse shark',
#  "Nurse shark. 5'",
#  'Tiger shark, female',
#  'Tiger shark, female',
#  'Some drowned but other may have been killed by blue sharks',
#  'White shark, 4.6 m',
#  'nan',
#  'nan',
#  '2 m shark',
#  'Tiger shark',
#  'Cookiecutter shark',
#  'Wobbegong shark, 1 m',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'White shark, 4.5 m',
#  '2 m shark',
#  'Spinner shark, 4 to 5 feet',
#  'Tiger shark, 8 to 10 feet',
#  "8' shark",
#  'Death may have been due to drowning',
#  "5' shark",
#  'White shark, 3.5 m',
#  'Questionable',
#  "4' to 5' shark",
#  'nan',
#  'Porbeagle, 1.5 m',
#  'nan',
#  'nan',
#  'nan',
#  'White shark, 3.5m',
#  "5' to 6' shark",
#  'nan',
#  'White shark, 3 to 3.5m ',
#  'nan',
#  'nan',
#  'nan',
#  'Nurse shark',
#  'nan',
#  'nan',
#  'White shark, 3 m',
#  'nan',
#  'Shark involvement questionable',
#  'nan',
#  "White shark, 5' to 7'",
#  "5' shark",
#  'Possibly a juvenile blacktip shark',
#  'Oceanic whitetip shark, 1.8 to 2 m',
#  "4' shark",
#  "White shark, 10'",
#  'nan',
#  'A small shark',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "Sandtiger shark  2'",
#  "Blue shark 6'",
#  '"A small shark"',
#  'Shark involvement not confirmed',
#  "White shark, 11' to 13'",
#  "White shark, 8' to 10'",
#  "White shark, 9'",
#  'nan',
#  'White shark',
#  "Bull shark, 4' to 5'",
#  'Tiger shark, 100 kg',
#  'White shark, 2.5 m',
#  'Shark involvement prior to death not confirmed',
#  'No shark invovlement ',
#  'nan',
#  'nan',
#  "Bull shark, 4' to 5'",
#  'Bull shark, 2m',
#  'nan',
#  'nan',
#  'nan',
#  'White shark, 4 m',
#  'Seven-gill shark',
#  'nan',
#  '3m shark, probably a smooth hound',
#  "8' shark",
#  'Tiger shark',
#  "3' shark",
#  'Tiger shark',
#  'nan',
#  'nan',
#  "9' shark",
#  'nan',
#  'Shark involvement highly doubtful',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'No shark invovlement - it ws a publicity stunt',
#  'nan',
#  'Shark involvement not confirmed',
#  'nan',
#  'White shark',
#  "Tiger shark, 12'",
#  'nan',
#  'nan',
#  'Shark involvement prior to death not confirmed',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "Bull shark, 5' to 7'",
#  'nan',
#  'nan',
#  'White shark',
#  "10' shark",
#  'Lemon shark',
#  'Bull shark, 1.5',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'Lemon shark pup',
#  'Tiger shark',
#  "White shark, female, 14'",
#  'Caribbean reef shark',
#  'nan',
#  'nan',
#  'Bull shark, 4 m',
#  'nan',
#  'nan',
#  'Bull shark, 1 m',
#  'Bull shark',
#  'nan',
#  'Shark involvement not confirmed',
#  'nan',
#  'a small shark',
#  'White shark, 4 m',
#  'nan',
#  'nan',
#  'Shark involvement not confirmed',
#  'Wobbegong shark, 2m',
#  'White shark',
#  'Broadnose sevengill shark, 1.5 m',
#  'Tiger shark',
#  'nan',
#  'nan',
#  'nan',
#  " 6' to 8' shark",
#  'nan',
#  'nan',
#  'White shark',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'White shark, 3.5 m',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  '2 m shark',
#  'nan',
#  "3' to 4' shark",
#  "Tiger shark, 10'",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "White shark, 8' to 10'",
#  'Invalid',
#  "Bull shark, 6'",
#  'nan',
#  'Bull shark, 3.5 m',
#  'nan',
#  'nan',
#  "Tiger shark, 10' ",
#  'Blacktip shark',
#  'Blue shark',
#  'nan',
#  'White shark',
#  "Nurse shark, 4'",
#  'nan',
#  'nan',
#  'nan',
#  "Bull shark, 6'",
#  'reef shark, 1m',
#  "Tiger shark, 10' ",
#  'nan',
#  'nan',
#  "White shark, 10' to 12'",
#  'nan',
#  "Lemon shark, 9'",
#  'Angel shark',
#  'White shark',
#  'dogfish shark',
#  'White shark',
#  'nan',
#  'Tawny nurse shark',
#  "3' to 4' shark",
#  'nan',
#  "Caribbean reef shark, 4.5'",
#  'White shark',
#  "3' to 5' shark",
#  'nan',
#  "3' to 4' shark",
#  "5' shark",
#  "3' to 4' shark",
#  "3' shark",
#  "Said to involve an 8' shark but more likely damage caused by debris",
#  'nan',
#  '3+ m shark',
#  'Mako shark',
#  'Bronze whaler sharks x 3',
#  '3 m shark',
#  'White shark',
#  'nan',
#  "5' shark",
#  'nan',
#  "Bull shark, 4' to 5'",
#  'nan',
#  "Blacktip shark, 4'",
#  "Nurse shark, 2'",
#  'nan',
#  "Mako shark, 1.5 m [5'] ",
#  "Bull shark, 6'",
#  'nan',
#  'White shark',
#  'Wobbegong shark',
#  'Grey reef shark, 2 m',
#  'Grey reef shark, 2 m',
#  "Bull shark, 7'",
#  'Tiger shark, 2.5 m',
#  'Shark involvement not confirmed',
#  "5' to 6' shark",
#  'nan',
#  'nan',
#  'nan',
#  'Shark involvement not confirmed',
#  'nan',
#  'Nurse shark, 2.5-ft',
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  'nan',
#  'Bronze whaler',
#  'Sandtiger shark',
#  'nan',
#  'nan',
#  'nan',
#  'No shark involvement',
#  'No shark involvement',
#  'nan',
#  'nan',
#  'Sandtiger shark',
#  'nan',
#  "Reef shark, 5'",
#  'nan',
#  'Bull sharks x 2',
#  'Mako shark',
#  "Tiger shark, 14'",
#  'Wobbegong shark',
#  'Blacktip shark',
#  '3 m shark',
#  'White shark, 3 m',
#  "Silky shark, 6.5'",
#  "9' shark",
#  "Bronze whaler shark, 6'",
#  'Tiger shark, 1.5 m ',
#  'nan',
#  'White shark, 3.5 m',
#  'Bull shark',
#  'nan',
#  'Galapagos shark',
#  'nan',
#  'nan',
#  "Spinner shark, 7'",
#  'Bull shark, 2.8 to 3.1 m',
#  'Shark involvement not confirmed',
#  'nan',
#  "3' to 5' shark",
#  'nan',
#  'nan',
#  'nan',
#  'White shark, 3 to 3.5m ',
#  "5' shark",
#  "Spinner shark, 5'",
#  'nan',
#  'No shark involvement',
#  "Tiger shark, 7'",
#  'Hammerhead sp.',
#  'nan',
#  "Tiger shark, 13' ",
#  'nan',
#  'nan',
#  'nan',
#  "4' to 5' shark",
#  "Blacktip shark, 4' to 5'",
#  "Blacktip shark, 5' to 6'",
#  'nan',
#  "White shark, 19'",
#  'juvenile shark',
#  "Tiger shark, 13'",
#  "4' shark",
#  'nan',
#  'Hammerhead shark',
#  'nan',
#  'nan',
#  "6' shark",
#  "White shark, 11' to 12'",
#  'Hammerhead shark.',
#  'White shark, 2.5 m',
#  "4' shark?",
#  'small shark',
#  'Tiger shark',
#  "White shark, 11' to 12'",
#  "White shark, 10' to 12' ",
#  'Shark involvement not confirmed',
#  'nan',
#  "4' shark",
#  "3' shark",
#  "White shark, 13'",
#  'Shark involvement not confirmed',
#  "Hammerhead shark. 6' to 7'",
#  'White shark',
#  'nan',
#  'nan',
#  "Blacktip or spinner shark, 4'",
#  "Thought to involve a 3' to 4' shark, but shark involvement not confirmed",
#  'White shark, 3.9 to 4.2 m',
#  'Mako shark, 100-lb',
#  'Bronze whaler shark, 1.5m',
#  'Bull shark, 2m',
#  'White shark',
#  "White shark, 7'",
#  'Shark involvement not cofirmed',
#  'No shark involvement',
#  "6' shark",
#  'nan',
#  'White shark',
#  'White shark',
#  "6' to 7' shark",
#  'nan',
#  "4' to 5' shark",
#  'Bull shark',
#  'White shark',
#  'Shark involvement not confirmed',
#  'White shark, 2m to 3 m',
#  "4' shark",
#  'Wobbegong shark',
#  'nan',
#  'Sandtiger shark',
#  'White shark',
#  'small shark',
#  'nan',
#  'nan',
#  'Bull shark',
#  'Bull shark',
#  'Mako shark',
#  "4' shark",
#  "Bull shark, 5'",
#  'small nurse shark',
#  'Bull shark, 2.5 m',
#  'nan',
#  'nan',
#  '1m to 1.2 m shark',
#  'nan',
#  "5' shark",
#  "6' shark",
#  'Bull shark, 3.5 m',
#  'nan',
#  'White shark',
#  'White shark, 3.5 m',
#  'nan',
#  '3- to 4-foot shark',
#  'White shark, 6 m',
#  'White shark, 3 m',
#  'Blue shark, 8 to 9 feet',
#  'Bull shark',
#  'nan',
#  'Bull shark',
#  'Shark involvement not cofirmed',
#  'No shark involvement',
#  'White shark, 4 m',
#  'Mako shark',
#  'Tiger shark, 8 to 12 feet',
#  'Blacktip shark',
#  'nan',
#  'nan',
#  'Blacktip Reef shark ',
#  'White shark',
#  'Tiger shark, 3.5 m',
#  '3.5 to 4 m shark',
#  '2 m to  3 m shark',
#  '1.8 m shark',
#  'Bull shark, 1.3 m',
#  "4' shark",
#  'nan',
#  'nan',
#  'White shark',
#  'Shark involvement not confirmed',
#  '5 m shark',
#  '1.5 m shark',
#  'No shark involvement',
#  'White shark or oceanic whitetip shark',
#  'Raggedtooth shark, 1.3 m',
#  '"A small shark"',
#  '2 m shark',
#  'White shark, 4 to 5 m',
#  'Shark involvement prior to death still to be determined',
#  'Shark involvement not confirmed & highly unlikely',
#  "White shark, 8' to 10'",
#  '1.5 m shark',
#  'Goblin shark',
#  'Tiger shark',
#  'nan',
#  'nan',
#  'nan',
#  'White shark',
#  'White shark',
#  "2' shark",
#  '1.5 m shark',
#  'nan',
#  'nan',
#  "Tiger shark, 12'",
#  'nan',
#  'Tiger shark',
#  'nan',
#  'nan',
#  "12' to 14' shark",
#  '1 m shark',
#  "Bull shark, 3' to 4'",
#  'nan',
#  'nan',
#  'Blacktip shark',
#  'nan',
#  'Blacktip shark',
#  "White shark, 18' to 20'",
#  'White shark',
#  "8' to 10' shark",
#  '2 white shark: 13\' & 9"8"',
#  'nan',
#  'Blacktip shark',
#  'No shark involvement',
#  "7' shark",
#  'Bull shark',
#  "White shark, 12' to 14'",
#  "3' to 4' shark",
#  'nan',
#  'Spinner shark',
#  'Spinner shark or blacktip shark',
#  'Shark involvement not confirmed',
#  'nan',
#  'small shark',
#  "4' to 6' shark",
#  'nan',
#  "Bull shark, 4.5' ",
#  "4' shark",
#  'reef shark',
#  " Bull shark, 8'",
#  'nan',
#  "Bull shark, 9' to 10'",
#  'nan',
#  " Bull shark, 5'",
#  "4' tp 5' shark",
#  'nan',
#  'nan',
#  'nan',
#  'White shark',
#  'Shark involvement not confirmed',
#  'Possibly juvenile tiger shark',
#  '1.8 metre shark',
#  'nan',
#  'Angel shark',
#  "6' to 8' shark",
#  "4' shark",
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  " White shark, 7' ",
#  'nan',
#  "4' to 5' shark",
#  "Oceanic whitetip shark'",
#  "Caribbean reef shark, 7' to 8'",
#  'nan',
#  'nan',
#  ' Lemon shark, 3.5 m',
#  'nan',
#  " Sandbar shark, 3' to 4'",
#  'Bronze whaler shark, 1.5m',
#  'nan',
#  'nan',
#  'Bull shark',
#  'nan',
#  'Blacktip Reef shark ',
#  ' Bull shark, 1.2m ',
#  '3m shark',
#  ' Tawney nurse shark, 1m',
#  'nan',
#  " white shark, 15' ",
#  'nan',
#  'Shark involvement not confirmed',
#  'No shark involvement',
#  "4' to 5' shark",
#  'Cow shark',
#  "3' shark",
#  'reef shark?',
#  'nan',
#  'nan',
#  'White shark',
#  ' Raggedtooth shark, 2m',
#  'nan',
#  'nan',
#  '3 m to 4 m white shark',
#  'Shark involvement prior to death not confirmed',
#  '2 m shark',
#  "4' to 5' shark",
#  'nan',
#  'nan',
#  'nan',
#  'No shark involvement',
#  'Wobbegong shark',
#  'Invalid',
#  'Blacktip or spinner shark?',
#  'Blacktip reef shark ',
#  'nan',
#  'nan',
#  'nan',
#  '7-gill shark?',
#  '1m shark',
#  '7-gill shark',
#  'nan',
#  'Oceanic whitetip shark',
#  'White shark, 6 m',
#  'Reported to involve a bull shark',
#  'White shark, 3m ',
#  'nan',
#  "Tiger shark, 10' to 12'",
#  "4' to 6' shark",
#  ' Wobbegong shark, 1.6 to 1.8m ',
#  'nan',
#  'Tiger shark, 3m ',
#  'nan',
#  'Thought to involve a white shark',
#  "White shark, 10 '",
#  'Reported to involve a white shark',
#  'nan',
#  'nan',
#  'nan',
#  'Tiger shark',
#  'Blacktip reef shark, 1m',
#  'Thought to involve a bull shark',
#  'Reported to involve a 4 m white shark',
#  'Wobbegong shark',
#  "Whitetip reef shark, 4' to 6'",
#  'Tiger shark',
#  'Nurse shark?',
#  'White shark',
#  'White shark',
#  "White shark, 8' to 10'",
#  'Small bull shark',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'Bull shark',
#  "3' shark",
#  'nan',
#  "3' shark",
#  "3' shark",
#  'nan',
#  'Nurse shark',
#  'nan',
#  "4' shark",
#  'Blacktip shark',
#  'Salmon shark',
#  'No shark involvement',
#  "Mako shark, 5'",
#  'nan',
#  'nan',
#  'nan',
#  'White shark',
#  'Tiger shark?',
#  'nan',
#  "Bull shark, 8'",
#  'Blacktip shark',
#  "Bull shark, 6' to 8'",
#  'nan',
#  'nan',
#  "6' shark",
#  'nan',
#  "Tiger shark, 8' to 10' ",
#  'Nurse shark',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  'Shark involvement prior to death not confirmed',
#  'White shark',
#  "Possibly a Bull shark, 3'",
#  "4' to 5' shark",
#  "Tiger shark, 14'",
#  'nan',
#  'nan',
#  'nan',
#  "4' to 5' shark",
#  "Lemon shark, 4'",
#  "6' shark",
#  'Galapagos shark',
#  'nan',
#  'nan',
#  'nan',
#  'Galapagos shark',
#  'Invalid',
#  'Bull shark',
#  'a small shark',
#  'Wobbegong, 2m',
#  'Tiger shark',
#  'Grey nurse shark, 3m',
#  "3' shark",
#  'Blue shark',
#  'Bull shark',
#  'nan',
#  'Possibly a blacktip reef shark',
#  'nan',
#  'shark involvement not confirmed',
#  "4' shark",
#  'No shark involvement',
#  'nan',
#  'Nurse shark',
#  'nan',
#  'Raggedtooth shark, 1.5 m',
#  'nan',
#  'Tiger shark, 4.8 m',
#  'Bronze whaler shark, 2.5m',
#  '"small sharks"',
#  'nan',
#  'White shark, 4m',
#  'reef shark?',
#  'reef shark?',
#  "Blacktip shark, 4' to 5'",
#  'Lemon shark',
#  'nan',
#  'White shark, 5m',
#  'nan',
#  'nan',
#  "Tiger shark, 15'",
#  'Bronze whaler shark, 3m',
#  'nan',
#  'nan',
#  '2.5 m shark',
#  'Bull shark, 2m ',
#  'Tiger shark',
#  "Tiger shark, 6'",
#  "10' shark",
#  'Sandtiger shark',
#  'Seven-gill shark',
#  "Tiger shark, 10'",
#  'No shark involvement',
#  '2.5 m shark',
#  "2' to 3' shark",
#  "Tiger shark, 15'",
#  "Tiger shark, 8'",
#  'White shark',
#  "Tiger shark, 10' to 12' ",
#  "White shark, 15' to 16' ",
#  'nan',
#  'nan',
#  "6' to 8' shark",
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  '2m shark',
#  "5' shark",
#  "4' shark",
#  'nan',
#  'Possibly a 3 m bull shark',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "3.5' to 4' shark",
#  "Tiger shark, 10' to 12' ",
#  "3.5' to 4' shark",
#  "Porbeagle shark, 7'",
#  'nan',
#  'nan',
#  'nan',
#  '4.5 m shark',
#  "Lemon shark, 4' to 5' ",
#  'Bull shark',
#  'Lemon shark, 2.5m to 3m ',
#  'nan',
#  'White shark or bronze whaler',
#  'nan',
#  'Thought to involve a white shark',
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  'Salmon shark suspected, but unlikely',
#  'White shark, 5m',
#  'nan',
#  'nan',
#  'nan',
#  "14' to 18'shark",
#  "15' shark",
#  'No shark involvement',
#  'possibly a bull shark',
#  'nan',
#  'a small reef shark',
#  'nan',
#  'nan',
#  '3 m shark',
#  'No shark involvement',
#  'nan',
#  'Nurse shark',
#  'small blacktip shark?',
#  'Shark involvement not confirmed',
#  'small blacktip shark?',
#  'Blacktip shark ',
#  '1.5 m shark',
#  'Blue shark, 2.5m',
#  'White shark, 2 m',
#  'nan',
#  'nan',
#  '18" to 24" shark',
#  'Bull shark, 3m',
#  "4' to 5' shark",
#  "Tiger shark, 8' to 9' ",
#  'nan',
#  'White shark',
#  'nan',
#  'White shark',
#  "5' shark",
#  'White shark, 4 m to 5m ',
#  'White shark, 6m ',
#  "Tiger shark, 10'  ",
#  'a small shark',
#  'White shark, 4m ',
#  'nan',
#  'White shark',
#  'Possibly a bull shark',
#  "Possibly a 5' to 6' bull shark",
#  "4' to 5' shark",
#  "4' to 5' shark",
#  'nan',
#  'Tawny nurse shark, 40cm',
#  'nan',
#  "4' shark",
#  'nan',
#  'nan',
#  'Spinner shark',
#  'Grey nurse shark',
#  'White shark, 7m',
#  'nan',
#  "6' to 8' shark",
#  'Tiger shark, 3m',
#  'Tiger shark',
#  'Blue shark, 70-kg blue shark',
#  'White shark, 2.7 m',
#  'Thought to involve a bull shark',
#  'White shark',
#  '2 m shark',
#  'Allegedly a 4 m tiger shark',
#  'nan',
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  "7' to 8' shark ",
#  'nan',
#  'White shark, 2.5m',
#  'Shark involvement not confirmed',
#  'Wobbegong shark',
#  'nan',
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  'Wobbegong shark?',
#  "White shark, 15' to 16'",
#  'nan',
#  'nan',
#  'nan',
#  'White shark',
#  "8' to 10' shark",
#  'Raggedtooth shark',
#  "White shark, 10'",
#  "White shark, 15'",
#  'Port Jackson shark, 1m',
#  "3' shark",
#  "10' to 12' shark",
#  'nan',
#  '2 to 2.5 m shark',
#  'nan',
#  'nan',
#  'No shark involvement',
#  'nan',
#  'White shark',
#  "Bull shark, 6'",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "4' to 6' shark",
#  'nan',
#  'Tiger shark, 2m',
#  'nan',
#  'White shark',
#  "6' shark, possibly a blactip or spinner shark",
#  "6' shark",
#  'Shark involvement prior to death not confirmed',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "White shark, >6'",
#  'nan',
#  "Possibly a 5' to 6' sandtiger shark",
#  'Shark involvement not confirmed',
#  '4 m shark',
#  'Grey reef shark ',
#  'nan',
#  "Bull shark, 6'",
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  'Shark involvement prior to death not confirmed',
#  'nan',
#  'nan',
#  'White shark, 3m to 4m',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'Bull shark, 3m female',
#  "Bull shark, 6'",
#  "White shark, 5' k",
#  'nan',
#  "5' shark",
#  'nan',
#  'nan',
#  "Oceanic whitetip shark, 7'",
#  "Blacktip shark, 4'",
#  'nan',
#  "Sevengill shark, 6' to 8'",
#  "3' to 4' shark",
#  'Blacktip reef shark ',
#  'nan',
#  'White shark',
#  "Tiger shark, 10'",
#  'Tiger shark',
#  'Zambesi shark',
#  'nan',
#  ' Tiger shark, 2.8m',
#  'nan',
#  "Sandbar shark, 8'",
#  'Invalid',
#  'nan',
#  "Bull shark, 12'",
#  'reef shark, 1.5m',
#  "1' to 2' shark",
#  'possibly a bronze whaler shark',
#  ' Bull shark, 2.5 m',
#  'nan',
#  'Blacktip shark pup',
#  'Bull shark',
#  'Bull shark, 2.5m',
#  'nan',
#  'nan',
#  '3 m to 4 m shark',
#  'nan',
#  'nan',
#  'Bull shark, 2m',
#  '1.5 m shark',
#  'nan',
#  'White shark x 2',
#  '1 m shark',
#  'nan',
#  'nan',
#  'nan',
#  "6' shark",
#  'nan',
#  'Caribbean reef shark',
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  'White shark',
#  "6' shark",
#  'nan',
#  'nan',
#  'Oceanic whitetip shark, 2.5m ',
#  'nan',
#  'Mako shark ',
#  'Mako shark',
#  'Oceanic whitetip shark, 2.5m, female',
#  'Oceanic whitetip shark, 2.5m, female',
#  'nan',
#  'Shark involvement not confirmed',
#  'nan',
#  'nan',
#  'nan',
#  'White shark',
#  'White shark',
#  'nan',
#  'nan',
#  'nan',
#  "Porbeagle shark, 8' ",
#  'nan',
#  "White shark, 14' to 18' ",
#  'nan',
#  'Bull shark, 1.4m ',
#  'Lemon shark',
#  "Possibly a 6' lemon shark",
#  'nan',
#  'White shark',
#  'nan',
#  'White shark',
#  '2m shark',
#  "3' shark",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'Shark involvement prior to death was not confirmed',
#  'nan',
#  'White shark',
#  'White shark',
#  'nan',
#  'nan',
#  ...]

# %% [markdown]
# Start making a cleanning of the strings, making some filters to be easier after.

# %%
shark_attack['Species'] = shark_attack['Species'].str.lower()

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace(" ", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace(".", "")
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_12192\1078038443.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   shark_attack['Species'] = shark_attack['Species'].str.replace(".", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace("to", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace(",", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace("'", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace('"', "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace("m", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace("juvenile", "")

# %%
shark_attack['Species'] = shark_attack['Species'].str.replace(r'\d', "").replace("-", "")
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_12192\260194922.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   shark_attack['Species'] = shark_attack['Species'].str.replace(r'\d', "").replace("-", "")

# %%
shark_attack['Species'].value_counts()
# Out:
# nan                                                                                                  2838
# shark                                                                                                 465
# whiteshark                                                                                            312
# []shark                                                                                               293
# tigershark                                                                                            138
#                                                                                                      ...
# thoughinvolveatigershark                                                                                1
# tigershark-kg[-lb]                                                                                      1
# possiblyatigershark                                                                                     1
# cc[]blacktiporspinnershark                                                                              1
# saidinvolveagreynursesharkthatleapufthewaterandseizedtheboybutspeciesidentificationisquestionable       1
# Name: Species, Length: 686, dtype: int64

# %% [markdown]
# Create a loop to change all the elements in the column for the ones that i really need.
# Have to change the column into a list so i can work with them.

# %%
species_lst = list(shark_attack['Species'])

# %%
spc = ["whiteshark", "tigershark", "bullshark", "wobbegongshark", "blacktipshark", "nurseshark", "spinnershark", "reefshark", "galapagosshark", "blueshark", "porbeagleshark", "goblinshark"]
x = []
for i in species_lst:
    if i in spc:
        x.append(i)
    else:
        x.append("NaN")

# %% [markdown]
# Result is saved as a list, have to change it to a panda series so it can be added to the data frame.

# %%
spc_serie = pd.Series(x)

# %%
shark_attack['Species'] = spc_serie

# %%
sns.countplot(y = shark_attack.Species);

# %% [markdown]
# ### Mating season

# %% [markdown]
# For this operation had to keep the same values that I used in the dictionary below, had to put a filter in the data frame so I could only see the information of the type of species that I chose tu put in the dictionary and still are the most relevant species in the attacks.

# %%
shark_attack.drop(columns =['Species_', 'Date'], inplace=True, axis=1)

# %%
white = shark_attack[(shark_attack.Species=="whiteshark") | (shark_attack.Species=="tigershark") | (shark_attack.Species=="bullshark") | (shark_attack.Species=="blacktipshark") | (shark_attack.Species=="wobbegongshark") | (shark_attack.Species=="spinnershark")]
white.sample(3)
# Out:
#         Year        Type       Country                   Area  \
# 3044  1981.0  Unprovoked           USA                Florida
# 340   2015.0  Unprovoked  SOUTH AFRICA  Western Cape Province
# 3410  1970.0        Boat         ITALY               Sardinia
#
#                    Location                 Activity             Name Sex_  \
# 3044  20 miles from Mayport  Commercial spearfishing       Carey Ford    M
# 340                Stil Bay                  Surfing  Stuart Anderson    M
# 3410      Golfo di Oristano        Fishing on a boat             male    M
#
#       Age                                       Injury Fatal_(y/n)   Time  \
# 3044   25  3 small punctures in scalp & ripped nostril           N    NaN
# 340    42        Lacerations to right calf, knee & hip           N  15h00
# 3410  NaN                                    No injury           N    NaN
#
#      Months     Species
# 3044    Jan  tigershark
# 340     Oct  whiteshark
# 3410    NaN  whiteshark

# %% [markdown]
# Start by creating a new column with boolean information, for that we would have to get information of 2 other columns, "Species" and "Months" and depending of the time of the attack it will have to throw us the result if its True, for if it was in their mating season or a False.

# %%
mating_ = {"whiteshark":["Nov", "Dec", "Jan"], "tigershark":["Aug", "Sep", "Oct"], "bullshark":["May", "Jun", "Jul"], "blacktipshark":["Nov", "Dic", "Jan", "Feb"], "wobbegongshark":["Oct", "Nov", "Dic", "Jan", "Feb"], "spinnershark":["Jun", "Jul"] }

# %%
# matching the values in the dictionary, otherwise it had throw me an error.

# %%
def mating (esp, mes):
    if mes in mating_[esp]:
        return True
    else:
        return False
#if key == Species and Months in mating_.values():

# %% [markdown]
# Creating new Data frame filtering the information of only the most relevant shark species in the attack, for now on it will be the only data frame we will use in next operations and for exporting.

# %%
white["mating"] = list(map(mating, white["Species"], white["Months"]))
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_12192\1907746515.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   white["mating"] = list(map(mating, white["Species"], white["Months"]))

# %%
white.sample()
# Out:
#         Year        Type    Country            Area             Location  \
# 4791  1939.0  Unprovoked  AUSTRALIA  Torres Strait   Near Mabuiag Island
#
#           Activity        Name Sex_  Age  \
# 4791  Pearl diving  Sammy Mira    M  NaN
#
#                                          Injury Fatal_(y/n) Time Months  \
# 4791  Leg severely bitten, surgically amputated           N  NaN    Sep
#
#          Species  mating
# 4791  tigershark    True

# %%
#Formula con lambda que arrojo error, servia para lo mismo que la formula de arriba, maps.
# white["mating"] = white.apply(lambda row: mating (row["Species"], row["Months"], axis=1))

# %%
#lst = list(shark_attack["Time"])
#x = []
#regex = re.compile(r"\d+h")
#for i in lst:
#    if i == regex:
#        x.append(i)
#    else: 
#        x.append("NaN")

# %% [markdown]
# ### Country column

# %% [markdown]
# Nothing to be clean here, still had to use the white data frame for now on.

# %%
white.sample(50)
# Out:
#         Year        Type          Country                   Area  \
# 696   2013.0  Unprovoked          JAMAICA          St. Catherine
# 1098  2009.0  Unprovoked     SOUTH AFRICA          KwaZulu-Natal
# 641   2013.0  Unprovoked              USA         South Carolina
# 1588  2005.0     Boating              USA                 Hawaii
# 920   2011.0  Unprovoked              USA                 Hawaii
# 120   2017.0     Boating              USA             California
# 3087  1979.0    Provoked     SOUTH AFRICA  Western Cape Province
# 1315  2007.0  Unprovoked              USA                 Hawaii
# 133   2017.0  Unprovoked        AUSTRALIA      Western Australia
# 1484  2006.0    Provoked        AUSTRALIA             Queensland
# 2813  1986.0  Unprovoked        AUSTRALIA        New South Wales
# 1680  2004.0  Unprovoked              USA                 Hawaii
# 128   2017.0  Unprovoked              USA         South Carolina
# 4767  1940.0  Unprovoked        AUSTRALIA        New South Wales
# 1259  2008.0  Unprovoked        AUSTRALIA      Western Australia
# 39    2018.0  Unprovoked     SOUTH AFRICA          KwaZulu-Natal
# 2787  1987.0  Unprovoked              USA                Florida
# 595   2013.0  Unprovoked        AUSTRALIA        New South Wales
# 2751  1988.0  Unprovoked             Fiji             Vanua Levu
# 1858  2002.0    Provoked              USA                Florida
# 30    2018.0  Unprovoked          BAHAMAS         New Providence
# 535   2014.0    Provoked              USA             California
# 6240     0.0  Unprovoked       SEYCHELLES       Amirante Islands
# 664   2013.0  Unprovoked              USA                 Hawaii
# 1040  2010.0  Unprovoked        AUSTRALIA        New South Wales
# 3027  1981.0  Unprovoked      SOUTH KOREA               Chungnam
# 4465  1950.0     Boating        AUSTRALIA        South Australia
# 716   2012.0  Unprovoked        AUSTRALIA      Western Australia
# 2997  1982.0        Boat            ITALY         Tyrrhenian Sea
# 577   2014.0  Unprovoked        AUSTRALIA        New South Wales
# 439   2015.0     Boating     SOUTH AFRICA  Eastern Cape Province
# 2885  1984.0    Provoked           MEXICO        Baja California
# 233   2016.0  Unprovoked              USA                Florida
# 1181  2008.0     Boating        AUSTRALIA        New South Wales
# 1420  2006.0  Unprovoked              USA                 Oregon
# 709   2013.0  Unprovoked              USA                 Hawaii
# 3078  1980.0  Unprovoked            CHILE              Los Vilos
# 2182  1998.0  Unprovoked     SOUTH AFRICA  Eastern Cape Province
# 117   2017.0  Unprovoked              USA             California
# 3396  1970.0  Unprovoked  SOLOMON ISLANDS                    NaN
# 818   2012.0        Boat     SOUTH AFRICA  Western Cape Province
# 123   2017.0  Unprovoked     SOUTH AFRICA  Eastern Cape Province
# 3371  1971.0  Unprovoked        AUSTRALIA        South Australia
# 480   2014.0  Unprovoked              USA                 Hawaii
# 631   2013.0  Unprovoked          BAHAMAS                    NaN
# 1437  2006.0  Unprovoked     SOUTH AFRICA  Western Cape Province
# 53    2017.0  Unprovoked              USA                 Hawaii
# 1722  2003.0  Unprovoked     SOUTH AFRICA          KwaZulu-Natal
# 467   2014.0  Unprovoked              USA             California
# 4267  1956.0  Unprovoked           GREECE           Corfu Island
#
#                                                Location  \
# 696                            Pillikin Red Light area
# 1098                                      Alkantstrand
# 641                                         Folly Beach
# 1588                                  North Kihei, Maui
# 920                            Lyman Beach, Kailua-Kona
# 120                       Santa Cruz, Santa Cruz County
# 3087                                           Macassar
# 1315                                       Wailea, Maui
# 133                            Point Casuarina, Bunbury
# 1484                            Moffat Beach, Caloundra
# 2813                         North Head, Sydney Harbour
# 1680                                 Kahana Beach, Maui
# 128          Burkes Beach, Hilton Head, Beaufort County
# 4767                                         Gerringong
# 1259                                             Albany
# 39                                               Durban
# 2787    Singer Island, Riviera Beach, Palm Beach County
# 595                   Shelly Beach, near Port Macquarie
# 2751                                                NaN
# 1858  a pier at the end of Caxambas Drive, Marco Isl...
# 30                                        Nirvana Beach
# 535                 Manhattan Beach, Los Angeles County
# 6240                                Marie Louise Island
# 664                               Kona Coast State Park
# 1040                            Mona Vale Beach, Sydney
# 3027                                    Wae-yeon Island
# 4465                                        Streaky Bay
# 716                                         Trigg Beach
# 2997                              Biodola, Isola d'Elba
# 577                                    Lighthouse Beach
# 439                                  Yellow Sands Point
# 2885                                   Guadalupe Island
# 233                    New Smyrna Beach, Volusia County
# 1181                         Long Reef, north of Sydney
# 1420                 Siletz River mouth, Lincoln County
# 709                                          Kiholo Bay
# 3078                           Punta Negra, Pichidangui
# 2182            Gonubie, 13 km northeast of East London
# 117              Seal Rock, Goleta Beach, Santa Barbara
# 3396                                                NaN
# 818                                       Strandfontein
# 123                            Nahoon Reef, East London
# 3371                                          Southport
# 480                         North Kohala, Hawaii County
# 631                                      Freetown Beach
# 1437                                          Noordhoek
# 53                                 Hultin's Beach, Oahu
# 1722                                          Karridene
# 467   Montaña de Oro State Park, San Luis Obispo Cou...
# 4267                                            Kérkira
#
#                                        Activity  \
# 696                                Spearfishing
# 1098                              Body boarding
# 641                                     Surfing
# 1588                                   Kayaking
# 920                             Paddle boarding
# 120                                    Kayaking
# 3087                              Shark fishing
# 1315                                   Floating
# 133                               Body boarding
# 1484                                 Snorkeling
# 2813                               Scuba diving
# 1680                                    Surfing
# 128                                    Swimming
# 4767                    Free diving for lobster
# 1259                                   Swimming
# 39                                 Scuba Diving
# 2787                                Windsurfing
# 595                                     Surfing
# 2751                                     Diving
# 1858  Fishing, removing the shark from his line
# 30                                      Surfing
# 535                                    Swimming
# 6240             Swimming from capsized pirogue
# 664                                    Swimming
# 1040                                    Surfing
# 3027                               Shell diving
# 4465                                    Fishing
# 716                                     Surfing
# 2997                          Fishing on a boat
# 577                                    Swimming
# 439                               Kayak Fishing
# 2885                               Spearfishing
# 233                                     Surfing
# 1181                                   Kayaking
# 1420                                    Surfing
# 709                                     Surfing
# 3078                              Hookah Diving
# 2182                              Body Boarding
# 117                                         SUP
# 3396                                   Swimming
# 818                                     Fishing
# 123                                     Surfing
# 3371                                    Surfing
# 480                                     Surfing
# 631                                Spearfishing
# 1437                                    Surfing
# 53                                      Surfing
# 1722                                Surf skiing
# 467                                     Surfing
# 4267                         Swimming off yacht
#
#                                                    Name Sex_  Age  \
# 696                                        George Facey    M   68
# 1098                                      Jeandre Nagel    M  NaN
# 641                                       Tyson Royston    M   10
# 1588                                          J. Bailey  NaN  NaN
# 920                                       Alaina DeBina    F  NaN
# 120                                        Steve Lawson    M  NaN
# 3087  skiboat, occupants: Gustav Boettger, Clive Mas...  NaN  NaN
# 1315                                       Aaron Finley    M   32
# 133                                           Paul Goff    M   48
# 1484                                               male    M   46
# 2813                               Margaret Bowen Jones    F  NaN
# 1680                                     Willis McInnis    M   57
# 128                                      Regan Readnour    F   14
# 4767                                      Smiles Walker    M  NaN
# 1259                                         Jason Cull    M   37
# 39                                          Elton Polly    M   38
# 2787                                     Gary Landwirth    M  NaN
# 595                                                male    M   26
# 2751                                      Qalo Moceyawa    M   22
# 1858                                               male    M   55
# 30                                          Bruce Rowan    M  NaN
# 535                                        Steve Robles    M  NaN
# 6240                                           Aristede    M  NaN
# 664                                      James Kerrigan    M   28
# 1040                                         Paul Welsh    M   46
# 3027                                     Pak Kyong-sun     F   27
# 4465                                 40' fishing cutter  NaN  NaN
# 716                                       Richard Wands    M   32
# 2997                               Giuseppe Campodonico    M  NaN
# 577                                         Mike Porter    M  NaN
# 439            Kayak: Occupant Kelly Janse van Rensburg    M   36
# 2885                                       Harry Ingram    M  NaN
# 233                                         Nolan Tyler    M   22
# 1181                                      Steve Kulcsar    M   29
# 1420                                         Tony Perez    M   22
# 709                                         Paul Santos    M   43
# 3078                               Jose Larenas-Miranda    M  NaN
# 2182                                        Anton deVos    M   20
# 117                                        Rolf Geyling    M   50
# 3396                                         David Vota    M  NaN
# 818   8m inflatable boat. Occupants: Bhad Battle & K...  NaN  NaN
# 123                                           Zoe Stein    F   13
# 3371                                       Tim Franklin    M   15
# 480                                      McKenzie Clark    F   34
# 631                                       Bryan Collins    M  NaN
# 1437                               Steven Harcourt-Wood    M   37
# 53                                     Marjorie Mariano    F   54
# 1722                                    2 people on ski  NaN  NaN
# 467                                       Kevin Swanson    M   50
# 4267                                          Margoulis    F   15
#
#                                                  Injury Fatal_(y/n)  \
# 696                                               FATAL           Y
# 1098                     No injury, shark bit bodyboard           N
# 641   No injury, shark became entangled in his surfb...           N
# 1588                         No injury, shark bit kayak           N
# 920                             No injury, board bitten           N
# 120                             No injury, kayak bitten           N
# 3087  No injury to occupants; hooked shark tore out ...           N
# 1315                      Lacerations to left lower leg           N
# 133                             No injury, board bitten           N
# 1484  Abrasion & 6 puncture wounds on chest after gr...           N
# 2813                                           Survived           N
# 1680           FATAL Severe wound to right thigh & calf           Y
# 128                                          Leg bitten           N
# 4767                             Minor injuries to foot           N
# 1259                     Severe lacerations to left leg           N
# 39     The shark & man simply collided; neither were...           N
# 2787     Lacerations to toe, heel & ankle of right foot           N
# 595          Puncture wounds to hand, laceration to leg           N
# 2751                    Lacerations to left arm & waist           N
# 1858       Leg bitten by hooked shark PROVOKED INCIDENT           N
# 30       No Injury. Shark swam away with the surf board           N
# 535   PROVOKED INCIDENT Torso bitten by shark hooked...           N
# 6240                                              FATAL           Y
# 664                           Right thigh & calf bitten           N
# 1040        Minor injury, lacerations to left lower leg           N
# 3027                                              FATAL           Y
# 4465                             No injury to occupants           N
# 716                                           No injury           N
# 2997                                          No injury           N
# 577                           Minor lacerations to foot           N
# 439                          No injury but kayak bitten           N
# 2885                       No Injury, PROVOKED INCIDENT           N
# 233                                      Big toe bitten           N
# 1181  No injury, shark struck kayak, catapulting him...           N
# 1420                        No injury, surfboard bitten           N
# 709                                Left forearm bitten            N
# 3078                                            FATAL             Y
# 2182                       FATAL, hands & calf bitten             Y
# 117                    No injury, shark bit paddleboard           N
# 3396                                         No details     UNKNOWN
# 818                No injury to occupants, boat damaged           N
# 123                      No injury, shark bit surfboard           N
# 3371                        Severe lacerations to thigh           N
# 480                              Lacerations to fingers           N
# 631                               Lower left leg bitten           N
# 1437                  No injury, shark rammed surfboard           N
# 53              Severe lacerations to left thigh & knee           N
# 1722         No injury to occupants, hull of ski bitten           N
# 467                                   Injury to hip/leg           N
# 4267                                              FATAL           Y
#
#                      Time Months         Species  mating
# 696                 09h00    Mar      tigershark   False
# 1098            Lunchtime    Aug      whiteshark   False
# 641                 17h30    Aug       bullshark   False
# 1588                11h00    May      tigershark   False
# 920                 12h00    May      tigershark   False
# 120                 11h00    Jul      whiteshark   False
# 3087                  NaN    Nov      whiteshark    True
# 1315                15h30    Oct      tigershark    True
# 133                 08h30    Jun      whiteshark   False
# 1484                16h30    May  wobbegongshark   False
# 2813                  NaN    Aug  wobbegongshark   False
# 1680                07h08    Apr      tigershark   False
# 128                   NaN    Jun       bullshark    True
# 4767                  NaN    Mar  wobbegongshark   False
# 1259                07h30    May      whiteshark   False
# 39                    NaN    Feb   blacktipshark    True
# 2787                  NaN    Feb    spinnershark   False
# 595                 18h15    Dec  wobbegongshark   False
# 2751                  NaN    Feb      tigershark   False
# 1858                17h15    May   blacktipshark   False
# 30                  09h30    Apr      tigershark   False
# 535                 09h30    Jul      whiteshark   False
# 6240                  NaN    NaN      tigershark   False
# 664                 12h50    Jun      tigershark   False
# 1040                08h00    Feb  wobbegongshark    True
# 3027                12h30    May      whiteshark   False
# 4465                  NaN    Jul      whiteshark   False
# 716                  0830    Dec      tigershark   False
# 2997                  NaN    NaN      whiteshark   False
# 577                 18h00    Mar  wobbegongshark   False
# 439                   NaN    Mar      whiteshark   False
# 2885                17h50    Sep      whiteshark   False
# 233                   NaN    Aug   blacktipshark   False
# 1181                11h00    Dec      whiteshark    True
# 1420  Just before sundown    Oct      whiteshark   False
# 709                 16h30    Jan      tigershark   False
# 3078                11h00    Jan      whiteshark    True
# 2182                09h55    Jun      whiteshark   False
# 117                 07h45    Jul      whiteshark   False
# 3396                  NaN    Apr  wobbegongshark   False
# 818                   NaN    Feb      whiteshark   False
# 123                 15h00    Jul      whiteshark   False
# 3371                  NaN    NaN      whiteshark   False
# 480                 11h00    Oct      tigershark    True
# 631                   NaN    Aug   blacktipshark   False
# 1437                  NaN    Sep      whiteshark   False
# 53                  18h00    Dec      tigershark   False
# 1722                  NaN    Nov      whiteshark    True
# 467                 11h30    Dec      whiteshark    True
# 4267                  NaN    NaN      whiteshark   False

# %%
white.Country.value_counts()
# Out:
# USA                               222
# AUSTRALIA                         181
# SOUTH AFRICA                       75
# BAHAMAS                            15
# NEW CALEDONIA                      11
# REUNION                            11
# BRAZIL                             10
# ITALY                              10
# NEW ZEALAND                         9
# MEXICO                              9
# CROATIA                             7
# PAPUA NEW GUINEA                    6
# IRAQ                                5
# IRAN                                4
# GREECE                              4
# SEYCHELLES                          3
# INDONESIA                           3
# FIJI                                3
# CUBA                                3
# CHILE                               3
# EGYPT                               2
# FRANCE                              2
# SPAIN                               2
# MALTA                               2
# SOUTH ATLANTIC OCEAN                2
# OKINAWA                             2
# COSTA RICA                          2
# FRENCH POLYNESIA                    2
# MICRONESIA                          1
# CARIBBEAN SEA                       1
# BAHREIN                             1
# CANADA                              1
# CURACAO                             1
# SLOVENIA                            1
# MALDIVES                            1
# SENEGAL                             1
# MONTENEGRO                          1
# THAILAND                            1
# MAYOTTE                             1
# AMERICAN SAMOA                      1
# TURKEY                              1
# FEDERATED STATES OF MICRONESIA      1
# NEW BRITAIN                         1
# SOLOMON ISLANDS                     1
# ATLANTIC OCEAN                      1
# PALAU                               1
# JAMAICA                             1
# SOUTH KOREA                         1
# VIETNAM                             1
# GUAM                                1
# TONGA                               1
# Fiji                                1
# RUSSIA                              1
# MAURITIUS                           1
# PHILIPPINES                         1
# BELIZE                              1
# Name: Country, dtype: int64

# %% [markdown]
# ### Exporting the data Frame

# %% [markdown]
# Export the final work, cleaned and filtered data frame with the information need it.

# %%
white.to_csv("D:\\ironhack\\proyectos\\SharkAttack_proy1\DATA\\cleaning.csv")

# %%
white.sample()
# Out:
#        Year        Type  Country Area      Location       Activity    Name  \
# 129  2017.0  Unprovoked  REUNION  NaN  Roches Noire  Body boarding  Julien
#
#     Sex_ Age                           Injury Fatal_(y/n)   Time Months  \
# 129    M  34  No injury, shark bit surfboard            N  10h00    Jun
#
#        Species  mating
# 129  bullshark    True
