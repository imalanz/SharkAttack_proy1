# %%
import pandas as pd
import openpyxl

# %%
shark_attack = pd.read_csv(r"D:\\ironhack\\proyecto\\proy_1\\attacks.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 shark_attack = pd.read_csv(r"D:\\ironhack\\proyecto\\proy_1\\attacks.csv")
#
# File ~\miniconda2\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\miniconda2\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
attacks = pd.read_excel(r'D:\\ironhack\\proyecto\\proy_1\\attackss.xlsx', engine="openpyxl")

# %%
attacks
# Out:
#       Case Number,Date,Year,Type,Country,Area,Location,Activity,Name,Sex ,Age,Injury,Fatal (Y/N),Time,Species ,Investigator or Source,pdf,href formula,href,Case Number,Case Number,original order,,  \
# 0      2018.06.25,25-Jun-2018,2018,Boating,USA,Califo...
# 1      2018.06.18,18-Jun-2018,2018,Unprovoked,USA,Geo...
# 2      2018.06.09,09-Jun-2018,2018,Invalid,USA,Hawaii...
# 3      2018.06.08,08-Jun-2018,2018,Unprovoked,AUSTRAL...
# 4      2018.06.04,04-Jun-2018,2018,Provoked,MEXICO,Co...
# ...                                                  ...
# 25711                            ,,,,,,,,,,,,,,,,,,,,,,,
# 25712                            ,,,,,,,,,,,,,,,,,,,,,,,
# 25713                            ,,,,,,,,,,,,,,,,,,,,,,,
# 25714                            ,,,,,,,,,,,,,,,,,,,,,,,
# 25715                          xx,,,,,,,,,,,,,,,,,,,,,,,
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# ...
