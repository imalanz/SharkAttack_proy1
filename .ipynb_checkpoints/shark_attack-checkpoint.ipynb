# %%
import pandas as pd
import openpyxl

# %%
csv_file = "D:\\ironhack\\proyectos\\proy_1\\attacks.csv"
shark_attack = pd.read_csv(csv_file, encoding= 'unicode_escape', error_bad_lines=False, engine='python')
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_10784\2999928344.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   shark_attack = pd.read_csv(csv_file, encoding= 'unicode_escape', error_bad_lines=False, engine='python')
# Skipping line 2: ',' expected after '"'
# Skipping line 3: ',' expected after '"'
# Skipping line 4: ',' expected after '"'
# Skipping line 5: ',' expected after '"'
# Skipping line 6: ',' expected after '"'
# Skipping line 7: ',' expected after '"'
# Skipping line 8: ',' expected after '"'
# Skipping line 9: ',' expected after '"'
# Skipping line 10: ',' expected after '"'
# Skipping line 11: ',' expected after '"'
# Skipping line 12: ',' expected after '"'
# Skipping line 13: ',' expected after '"'
# Skipping line 14: ',' expected after '"'
# Skipping line 15: ',' expected after '"'
# Skipping line 16: ',' expected after '"'
# Skipping line 17: ',' expected after '"'
# ...

# %%
shark_attack
# Out:
#         Case Number                  Date    Year        Type  \
# 0        2018.01.12           12-Jan-2018  2018.0  Unprovoked
# 1      2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked
# 2        2017.11.04           04-Nov-2017  2017.0  Unprovoked
# 3      2017.09.06.R  Reported 06-Sep-2017  2017.0  Unprovoked
# 4      2017.07.23.b           23-Jul-2017  2017.0  Unprovoked
# ...             ...                   ...     ...         ...
# 19798           NaN                   NaN     NaN         NaN
# 19799           NaN                   NaN     NaN         NaN
# 19800           NaN                   NaN     NaN         NaN
# 19801           NaN                   NaN     NaN         NaN
# 19802            xx                   NaN     NaN         NaN
#
#                Country                 Area            Location  \
# 0               BRAZIL  Fernando de Noronha     Conceicao Beach
# 1                  NaN                  NaN                 NaN
# ...

# %%
shark_attack.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22               float64
# ;;;;;;                     object
# dtype: object

# %%
shark_attack.sample()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 10777         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 10777  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22  ;;;;;;
# 10777           NaN           NaN            NaN         NaN  ;;;;;;
#
# [1 rows x 24 columns]

# %%
shark_attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19803 entries, 0 to 19802
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             2783 non-null   object
#  1   Date                    381 non-null    object
#  2   Year                    381 non-null    float64
#  3   Type                    380 non-null    object
#  4   Country                 370 non-null    object
#  5   Area                    311 non-null    object
#  6   Location                291 non-null    object
#  7   Activity                308 non-null    object
#  8   Name                    362 non-null    object
#  9   Sex                     332 non-null    object
#  10  Age                     156 non-null    object
#  11  Injury                  377 non-null    object
#  12  Fatal (Y/N)             339 non-null    object
#  13  Time                    122 non-null    object
# ...

# %%
#revisar si necesito eliminar los NaN
#puedo meterme directo a explorar la columna a ver como se ven con los NaN
#llamando el key y poniendole .isna()

# %%
#pd.isnull(shark_attack).sum() same formula
shark_attack.isna().sum()
#for NaN, un promedio de 18000NaNs en una lista de 19803
#conclucion, demasiados NaN tendre que eliminar
# Out:
# Case Number               17020
# Date                      19422
# Year                      19422
# Type                      19423
# Country                   19433
# Area                      19492
# Location                  19512
# Activity                  19495
# Name                      19441
# Sex                       19471
# Age                       19647
# Injury                    19426
# Fatal (Y/N)               19464
# Time                      19681
# Species                   19619
# Investigator or Source    19427
# pdf                       19422
# href formula              19422
# href                      19422
# Case Number.1             19422
# Case Number.2             19422
# original order            19415
# Unnamed: 22               19803
# ;;;;;;                        2
# dtype: int64

# %%
shark_attack.notnull().sum()
# Out:
# Case Number                2783
# Date                        381
# Year                        381
# Type                        380
# Country                     370
# Area                        311
# Location                    291
# Activity                    308
# Name                        362
# Sex                         332
# Age                         156
# Injury                      377
# Fatal (Y/N)                 339
# Time                        122
# Species                     184
# Investigator or Source      376
# pdf                         381
# href formula                381
# href                        381
# Case Number.1               381
# Case Number.2               381
# original order              388
# Unnamed: 22                   0
# ;;;;;;                    19801
# dtype: int64

# %%
#No sirve de nada
#eliminar los NaN con "any", se eliminaria toda la lista
#eliminarlos con "all" no se elimina nada.
shark_attack.dropna(how="all",inplace=True)
shark_attack
# Out:
#         Case Number                  Date    Year        Type  \
# 0        2018.01.12           12-Jan-2018  2018.0  Unprovoked
# 1      2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked
# 2        2017.11.04           04-Nov-2017  2017.0  Unprovoked
# 3      2017.09.06.R  Reported 06-Sep-2017  2017.0  Unprovoked
# 4      2017.07.23.b           23-Jul-2017  2017.0  Unprovoked
# ...             ...                   ...     ...         ...
# 19798           NaN                   NaN     NaN         NaN
# 19799           NaN                   NaN     NaN         NaN
# 19800           NaN                   NaN     NaN         NaN
# 19801           NaN                   NaN     NaN         NaN
# 19802            xx                   NaN     NaN         NaN
#
#                Country                 Area            Location  \
# 0               BRAZIL  Fernando de Noronha     Conceicao Beach
# 1                  NaN                  NaN                 NaN
# ...

# %%
shark_attack.isna().sum()
# Out:
# Case Number               17020
# Date                      19422
# Year                      19422
# Type                      19423
# Country                   19433
# Area                      19492
# Location                  19512
# Activity                  19495
# Name                      19441
# Sex                       19471
# Age                       19647
# Injury                    19426
# Fatal (Y/N)               19464
# Time                      19681
# Species                   19619
# Investigator or Source    19427
# pdf                       19422
# href formula              19422
# href                      19422
# Case Number.1             19422
# Case Number.2             19422
# original order            19415
# Unnamed: 22               19803
# ;;;;;;                        2
# dtype: int64

# %%
shark_attack.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19798     True
# 19799     True
# 19800     True
# 19801     True
# 19802    False
# Length: 19803, dtype: bool

# %%
shark_attack.shape[0]
# Out:
# 19803

# %%
shark_attack.drop_duplicates(inplace=False)
# se eliminaron de 19803 a 392 rows
# Out:
#         Case Number                  Date    Year        Type  \
# 0        2018.01.12           12-Jan-2018  2018.0  Unprovoked
# 1      2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked
# 2        2017.11.04           04-Nov-2017  2017.0  Unprovoked
# 3      2017.09.06.R  Reported 06-Sep-2017  2017.0  Unprovoked
# 4      2017.07.23.b           23-Jul-2017  2017.0  Unprovoked
# ...             ...                   ...     ...         ...
# 387               0                   NaN     NaN         NaN
# 388               0                   NaN     NaN         NaN
# 389               0                   NaN     NaN         NaN
# 2782            NaN                   NaN     NaN         NaN
# 19802            xx                   NaN     NaN         NaN
#
#                Country                 Area            Location  \
# 0               BRAZIL  Fernando de Noronha     Conceicao Beach
# 1                  NaN                  NaN                 NaN
# ...

# %%
#unnamed:22 column has alll with NaN
#la lista se va a reducir a menos de 5mil rows por tantos NaN que hay.

# %%
shark_attack.columns.coun
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        ';;;;;;'],
#       dtype='object')

# %%
shark_attack[['Unnamed: 22',
       ';;;;;;']].sample(20)
# Out:
#        Unnamed: 22  ;;;;;;
# 14003          NaN  ;;;;;;
# 13449          NaN  ;;;;;;
# 1160           NaN  ;;;;;;
# 610            NaN  ;;;;;;
# 11947          NaN  ;;;;;;
# 12093          NaN  ;;;;;;
# 9139           NaN  ;;;;;;
# 12896          NaN  ;;;;;;
# 15431          NaN  ;;;;;;
# 9351           NaN  ;;;;;;
# 12827          NaN  ;;;;;;
# 6831           NaN  ;;;;;;
# 1971           NaN  ;;;;;;
# 6857           NaN  ;;;;;;
# 10327          NaN  ;;;;;;
# 7282           NaN  ;;;;;;
# 3679           NaN  ;;;;;;
# 18802          NaN  ;;;;;;
# 3112           NaN  ;;;;;;
# 5963           NaN  ;;;;;;

# %%
#para ver una columna con puros NaNs
shark_attack[shark_attack["Country"].isna()]
# Out:
#         Case Number                  Date    Year        Type Country  \
# 1      2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked     NaN
# 10           ;;;;;;                  None     NaN        None    None
# 195      1970.02.05            5-Feb-1970  1970.0  Unprovoked     NaN
# 202      1969.08.00              Aug-1969  1969.0  Unprovoked     NaN
# 266      1956.09.13           13-Sep-1956  1956.0  Unprovoked     NaN
# ...             ...                   ...     ...         ...     ...
# 19798           NaN                   NaN     NaN         NaN     NaN
# 19799           NaN                   NaN     NaN         NaN     NaN
# 19800           NaN                   NaN     NaN         NaN     NaN
# 19801           NaN                   NaN     NaN         NaN     NaN
# 19802            xx                   NaN     NaN         NaN     NaN
#
#                                      Area Location               Activity  \
# ...

# %%
#no proprciona mucha informacion, o nula.
shark_attack.describe()
# Out:
#               Year  original order  Unnamed: 22
# count   381.000000      388.000000          0.0
# mean   1840.283465     2991.554124          NaN
# std     476.153468     1743.585094          NaN
# min       0.000000       25.000000          NaN
# 25%    1944.000000     1661.500000          NaN
# 50%    1970.000000     2961.500000          NaN
# 75%    2000.000000     4356.250000          NaN
# max    2018.000000     6310.000000          NaN

# %%
shark_attack.sample()
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8380         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       ... Species  Investigator or Source  pdf href formula href  \
# 8380  ...      NaN                    NaN  NaN          NaN  NaN
#
#      Case Number.1 Case Number.2 original order Unnamed: 22  ;;;;;;
# 8380           NaN           NaN            NaN         NaN  ;;;;;;
#
# [1 rows x 24 columns]

# %%
shark_attack["Country"].value_counts()
# Out:
# USA                  51
# AUSTRALIA            32
# REUNION              24
# SOUTH AFRICA         23
# BRAZIL               17
#                      ..
# ADMIRALTY ISLANDS     1
# TANZANIA              1
# NICARAGUA             1
# MAYOTTE               1
# MARSHALL ISLANDS      1
# Name: Country, Length: 83, dtype: int64

# %%
shark_attack["Country"].fillna("NaN", inplacae=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [205], in <cell line: 1>()
# ----> 1 shark_attack["Country"].fillna("NaN", inplacae=True)
#
# File ~\miniconda2\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: Series.fillna() got an unexpected keyword argument 'inplacae'
